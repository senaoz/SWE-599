# %% [markdown]
# # Week 2: Dataset for Embedding  Evaluation & Embedding Comparison
#
# This notebook implements the similarity pipeline and evaluates different embedding methods for the academic paper recommendation system.
#
# **Tasks:**
#
# 1. Cross-Corpus Similarity (External ↔ BOUN)
# 2. Embedding Method Comparison (TF-IDF, Sentence Embeddings, Gemini API)
# 3. Intra-Paper Similarity (Same-Author & Cited Paper sanity checks)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import ast
import os
import warnings
warnings.filterwarnings('ignore')

from dotenv import load_dotenv
load_dotenv()

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from collections import defaultdict

pd.set_option('display.max_colwidth', 80)

GEMINI_API_KEY = 'XXXX'

# %% [markdown]
# ## Load & Prepare Data

# %%
import pickle

PARSED_CACHE = "data/cleaned"
os.makedirs(PARSED_CACHE, exist_ok=True)

boun_cache = os.path.join(PARSED_CACHE, "boun.pkl")
followed_cache = os.path.join(PARSED_CACHE, "priority_followed.pkl")

if os.path.exists(boun_cache) and os.path.exists(followed_cache):
    print("Loading pre-parsed data from cache...")
    with open(boun_cache, 'rb') as f:
        boun_data = pickle.load(f)
    with open(followed_cache, 'rb') as f:
        priority_followed_data = pickle.load(f)
else:
    boun_data = pd.read_csv("data/cleaned/boun.csv")
    priority_followed_data = pd.read_csv("data/cleaned/priority_followed.csv")

    def safe_parse(x):
        """Safely parse stringified JSON/lists using ast.literal_eval with fallback."""
        if pd.isna(x):
            return None
        if isinstance(x, str):
            x = x.strip()
            if x.startswith(('[{', '[', '{', '(')):
                try:
                    return ast.literal_eval(x)
                except (ValueError, SyntaxError):
                    try:
                        return json.loads(x)
                    except:
                        return x
        return x

    print("Parsing BOUN data...")
    for col in boun_data.columns:
        boun_data[col] = boun_data[col].map(safe_parse)

    print("Parsing priority_followed data...")
    for col in priority_followed_data.columns:
        priority_followed_data[col] = priority_followed_data[col].map(safe_parse)

    with open(boun_cache, 'wb') as f:
        pickle.dump(boun_data, f)
    with open(followed_cache, 'wb') as f:
        pickle.dump(priority_followed_data, f)
    print("Saved parsed data to cache.")

print(f"BOUN: {len(boun_data)} rows, Followed: {len(priority_followed_data)} rows")
# Out:
# Loading pre-parsed data from cache...
# BOUN: 4608 rows, Followed: 9946 rows

# %%
print(f"BOUN papers: {len(boun_data)}")
print(f"Followed institution papers: {len(priority_followed_data)}")

# Filter to papers with abstracts (FULL corpus — used for Task 2 benchmark & Task 3)
boun_df_full = boun_data[boun_data['abstract'].notna() & (boun_data['abstract'].str.len() > 20)].reset_index(drop=True)
followed_df_full = priority_followed_data[priority_followed_data['abstract'].notna() & (priority_followed_data['abstract'].str.len() > 20)].reset_index(drop=True)

# Subsample for Task 1 (cross-corpus exploration) — keeps iteration fast
TASK1_CORPUS_SIZE = 500
boun_df = boun_df_full.sample(TASK1_CORPUS_SIZE, random_state=42).reset_index(drop=True)
followed_df = followed_df_full.sample(TASK1_CORPUS_SIZE, random_state=42).reset_index(drop=True)

print(f"\nFull corpus (for benchmark & sanity checks):")
print(f"  BOUN papers: {len(boun_df_full)}")
print(f"  Followed institution papers: {len(followed_df_full)}")
print(f"\nSubsampled (for Task 1 cross-corpus):")
print(f"  BOUN papers: {len(boun_df)}")
print(f"  Followed institution papers: {len(followed_df)}")
# Out:
# BOUN papers: 4608
# Followed institution papers: 9946
#
# Full corpus (for benchmark & sanity checks):
#   BOUN papers: 3000
#   Followed institution papers: 5851
#
# Subsampled (for Task 1 cross-corpus):
#   BOUN papers: 500
#   Followed institution papers: 500

# %%
from src.text_utils import extract_concept_names, build_text

# Pre-build combined text for all dataframes
for df in [boun_df, followed_df, boun_df_full, followed_df_full]:
    df['text'] = df.apply(lambda r: build_text(r), axis=1)

# %%
print("Sample combined text:")
boun_df['text'].head()
# Out:
# Sample combined text:
# 0    Intertemporal and cross-sectional contrasts in effects of trade: Significanc...
# 1    Cyclic double punch test as a novel approach to reduce variation in concrete...
# 2    Modeling the Organizational Agility in the Architecture, Engineering, and Co...
# 3    Fling amplitude inventory of near-fault strong motion recordings in Turkiye ...
# 4    A Place under the Sun: Chinese Muslim (Hui) Identity and the Constitutional ...
# Name: text, dtype: str

# %% [markdown]
# ## Similarity Methods
#
# Each method implements the same interface: given query texts and corpus texts, return a similarity matrix.

# %% [markdown]
# ### Method 1: TF-IDF + Cosine Similarity

# %%
from src.similarity import tfidf_similarity

# %% [markdown]
# ### Method 1b: BM25 (Best Matching 25)
#
# BM25 improves on TF-IDF by adding document length normalization and term frequency saturation via `k1` and `b` parameters. It is the strongest sparse retrieval baseline in information retrieval.

# %%
from src.similarity import bm25_similarity

print("BM25 method ready.")
# Out:
# BM25 method ready.

# %% [markdown]
# ### Method 2: Sentence Embeddings (all-MiniLM-L6-v2 & SPECTER2)

# %%
from src.similarity import (
    DEVICE, MAX_TEXT_CHARS, BATCH_SIZES,
    _get_model, _cache_path, _corpus_hash, _truncate_texts,
    sentence_embedding_similarity,
)

print(f"Using device: {DEVICE}")
print("Embedding methods ready.")
# Out:
# Using device: mps
# Embedding methods ready.

# %% [markdown]
# ### Method 3: Gemini API Similarity Scoring
#
# Uses the Gemini API to directly score semantic similarity between paper pairs. Due to API rate limits, this is applied only to the top candidates pre-filtered by a fast method.

# %%
import google.generativeai as genai
import time

from src.similarity import gemini_score_pair

if not GEMINI_API_KEY:
    print("⚠ GEMINI_API_KEY not set — Gemini methods will fail.")
else:
    genai.configure(api_key=GEMINI_API_KEY)
    print("Gemini API configured.")


def gemini_rerank(query_text, candidate_texts, candidate_indices, top_k=3):
    """Re-rank top candidates using Gemini scoring.

    Returns list of (index, score) tuples sorted by Gemini score descending.
    """
    scored = []
    for idx, cand_text in zip(candidate_indices, candidate_texts):
        score = gemini_score_pair(query_text, cand_text)
        if score:
            scored.append((idx, score))
        time.sleep(0.5)  # Rate limit
    scored.sort(key=lambda x: x[1], reverse=True)
    return scored[:top_k]
# Out:
# Gemini API configured.

# %% [markdown]
# ### Retrieval Helper
#
# Generic function to retrieve top-K similar papers using any method.

# %%
from src.similarity import MODEL_MAP
from src.metrics import reciprocal_rank_fusion


def retrieve_top_k(query_texts, corpus_texts, method, top_k=3, **kwargs):
    """Retrieve top-K similar corpus papers for each query.

    Parameters
    ----------
    method : str — 'tfidf', 'bm25', 'minilm', 'specter2', 'qwen', 'gemini', or 'hybrid'
    Returns: list of list of (corpus_index, score)
    """
    if method == 'tfidf':
        sim_matrix = tfidf_similarity(query_texts, corpus_texts)
    elif method == 'bm25':
        sim_matrix = bm25_similarity(query_texts, corpus_texts)
    elif method in ('minilm', 'specter2', 'qwen'):
        sim_matrix = sentence_embedding_similarity(query_texts, corpus_texts, model_name=MODEL_MAP[method])
    elif method == 'gemini_embed':
        sim_matrix = gemini_embedding_similarity(query_texts, corpus_texts)
    elif method == 'gemini':
        pre_k = kwargs.get('pre_filter_k', 10)
        sim_matrix = tfidf_similarity(query_texts, corpus_texts)
        results = []
        for i in range(len(query_texts)):
            top_indices = np.argsort(sim_matrix[i])[::-1][:pre_k]
            cand_texts = [corpus_texts[j] for j in top_indices]
            reranked = gemini_rerank(query_texts[i], cand_texts, top_indices, top_k=top_k)
            results.append(reranked)
        return results
    elif method == 'hybrid':
        pre_k = kwargs.get('pre_filter_k', 50)
        bm25_matrix = bm25_similarity(query_texts, corpus_texts)
        spec_matrix = sentence_embedding_similarity(query_texts, corpus_texts, model_name='allenai/specter2_base')
        results = []
        for i in range(len(query_texts)):
            bm25_top = np.argsort(bm25_matrix[i])[::-1][:pre_k]
            bm25_ranked = [(idx, bm25_matrix[i, idx]) for idx in bm25_top]
            spec_top = np.argsort(spec_matrix[i])[::-1][:pre_k]
            spec_ranked = [(idx, spec_matrix[i, idx]) for idx in spec_top]
            fused = reciprocal_rank_fusion([bm25_ranked, spec_ranked], top_k=top_k)
            results.append(fused)
        return results
    else:
        raise ValueError(f"Unknown method: {method}")

    results = []
    for i in range(sim_matrix.shape[0]):
        top_indices = np.argsort(sim_matrix[i])[::-1][:top_k]
        results.append([(idx, sim_matrix[i, idx]) for idx in top_indices])
    return results


print("retrieve_top_k() ready — supports: tfidf, bm25, minilm, specter2, qwen, gemini, hybrid")
# Out:
# retrieve_top_k() ready — supports: tfidf, bm25, minilm, specter2, qwen, gemini, hybrid

# %% [markdown]
# ## Task 1 — Cross-Corpus Similarity
#
# **1a.** 50 followed-institution papers → top-3 similar BOUN papers
# **1b.** 50 BOUN papers → top-3 similar followed-institution papers

# %%
import pickle

CACHE_DIR = "data/results_cache"
os.makedirs(CACHE_DIR, exist_ok=True)

np.random.seed(42)
sample_followed = followed_df.sample(50).reset_index(drop=True)
sample_boun = boun_df.sample(50).reset_index(drop=True)

METHODS = ['tfidf', 'bm25', 'minilm', 'specter2', 'hybrid'] # 'qwen', 'gemini_embed', 'gemini',
method_labels = {
    'tfidf': 'TF-IDF', 'bm25': 'BM25', 'minilm': 'MiniLM', 'specter2': 'SPECTER2',
    'qwen': 'Qwen3-Emb', 'gemini_embed': 'Gemini Embed', 'gemini': 'Gemini',
    'hybrid': 'Hybrid (BM25+SPECTER2)'
}
colors = {
    'tfidf': '#e74c3c', 'bm25': '#f39c12', 'minilm': '#3498db', 'specter2': '#2ecc71',
    'qwen': '#8e44ad', 'gemini_embed': '#9b59b6', 'gemini': '#e67e22', 'hybrid': '#1abc9c'
}

# --- Task 1a: External → BOUN ---
cache_1a = os.path.join(CACHE_DIR, "results_1a.pkl")

if os.path.exists(cache_1a):
    print(f"Loading cached Task 1a results from {cache_1a}")
    with open(cache_1a, 'rb') as f:
        results_1a = pickle.load(f)
    # Check if all methods are cached, compute missing ones
    missing = [m for m in METHODS if m not in results_1a]
    if missing:
        print(f"  Computing missing methods: {missing}")
        for method in missing:
            print(f"  ▶ Running {method}...")
            results_1a[method] = retrieve_top_k(
                list(sample_followed['text']), list(boun_df['text']),
                method=method, top_k=3
            )
        with open(cache_1a, 'wb') as f:
            pickle.dump(results_1a, f)
        print(f"  Updated cache with new methods")
else:
    print("=" * 80)
    print("TASK 1a: External → BOUN (50 followed-institution queries → BOUN corpus)")
    print("=" * 80)

    results_1a = {}
    for method in METHODS:
        print(f"\n▶ Running {method}...")
        results_1a[method] = retrieve_top_k(
            list(sample_followed['text']),
            list(boun_df['text']),
            method=method,
            top_k=3
        )
    with open(cache_1a, 'wb') as f:
        pickle.dump(results_1a, f)
    print(f"\nSaved Task 1a results to {cache_1a}")

# Display side-by-side comparison for first 3 queries
for i in range(3):
    query_title = str(sample_followed.iloc[i]['title'])[:80]
    print(f"\n{'─'*80}")
    print(f"Query {i+1}: {query_title}")
    for method in METHODS:
        hits = results_1a[method][i]
        print(f"  [{method_labels[method]:>20}]")
        for rank, (idx, score) in enumerate(hits, 1):
            match_title = str(boun_df.iloc[idx]['title'])[:60]
            print(f"    #{rank} ({score:.3f}) {match_title}")
# Out:
# Loading cached Task 1a results from data/results_cache/results_1a.pkl
#
# ────────────────────────────────────────────────────────────────────────────────
# Query 1: Can N95 Respirators Be Reused after Disinfection? How Many Times?
#   [              TF-IDF]
#     #1 (0.110) The Buffering Effects of Social Insurance for the Spread of
#     #2 (0.092) Fiscal stimulus packages to COVID‐19: The role of informalit
#     #3 (0.069) Evaluation of Knowledge, Behavior, and Attitudes of Construc
#   [                BM25]
#     #1 (0.693) Evaluation of Knowledge, Behavior, and Attitudes of Construc
#     #2 (0.664) The Buffering Effects of Social Insurance for the Spread of
#     #3 (0.651) Screening of Clinically Approved and Investigation Drugs as
#   [              MiniLM]
#     #1 (0.273) Numerical Optimization of Gas Cooler Geometry in Transcritic
#     #2 (0.271) Scalable Yielding of Highly Stable Polyelectrolyte‐Coated Co
#     #3 (0.268) Microfluidic contact lenses for ocular diagnostics and drug
#   [            SPECTER2]
#     #1 (0.893) Microfluidic contact lenses for ocular diagnostics and drug
#     #2 (0.890) Evaluation of Knowledge, Behavior, and Attitudes of Construc
#     #3 (0.887) Engineered biodegradable nanopesticides for efficient leaf d
#   [Hybrid (BM25+SPECTER2)]
#     #1 (0.033) Evaluation of Knowledge, Behavior, and Attitudes of Construc
#     #2 (0.031) The Buffering Effects of Social Insurance for the Spread of
#     #3 (0.026) How We Found Our IMU: Guidelines to IMU Selection and a Comp
#
# ────────────────────────────────────────────────────────────────────────────────
# Query 2: The clustering of DESI-like luminous red galaxies using photometric redshifts
#   [              TF-IDF]
#     #1 (0.115) Analysis of clustering and degree index in random graphs and
#     #2 (0.102) Clustering Event Streams With Low Rank Hawkes Processes
#     #3 (0.080) Experimental validation of a multiple wavelength Photo-Magne
#   [                BM25]
#     #1 (0.649) The NANOGrav 12.5 yr Data Set: A Computationally Efficient E
#     #2 (0.639) Analysis of clustering and degree index in random graphs and
#     #3 (0.630) Excitons in strained and suspended monolayer WSe <sub>2</sub
#   [              MiniLM]
#     #1 (0.368) The Dark Universe Is Not Invisible
#     #2 (0.351) The NANOGrav 12.5 yr Data Set: A Computationally Efficient E
#     #3 (0.310) Solar Flare Activity, 1937–2024: Introducing the New Hemisph
#   [            SPECTER2]
#     #1 (0.843) Operation and performance of the ATLAS semiconductor tracker
#     #2 (0.842) nan
#     #3 (0.841) Clustering Event Streams With Low Rank Hawkes Processes
#   [Hybrid (BM25+SPECTER2)]
#     #1 (0.031) Clustering Event Streams With Low Rank Hawkes Processes
#     #2 (0.030) Analysis of clustering and degree index in random graphs and
#     #3 (0.028) Handling Concept Drift in Fraud Detection: A Replication Stu
#
# ────────────────────────────────────────────────────────────────────────────────
# Query 3: Structure of the lysosomal mTORC1–TFEB–Rag–Ragulator megacomplex
#   [              TF-IDF]
#     #1 (0.069) Evaluating GPT and BERT models for protein–protein interacti
#     #2 (0.044) Impact of Poly(dimethylsiloxane) Surface Modification with C
#     #3 (0.040) “Clickable” bacterial poly(γ-glutamic acid)
#   [                BM25]
#     #1 (0.688) Distinct interaction modes orchestrate the polymerization of
#     #2 (0.669) Abstract 2771: CRISPR/Cas9 essentiality screens identify sta
#     #3 (0.656) Modeling the discharge behavior of a lithium‐sulfur battery
#   [              MiniLM]
#     #1 (0.350) Time-dependent re-organization of biological processes by th
#     #2 (0.328) Distinct interaction modes orchestrate the polymerization of
#     #3 (0.306) Cholesterol biogenesis is a PTEN‐dependent actionable node f
#   [            SPECTER2]
#     #1 (0.829) Computational analysis of missense filamin-A variants, inclu
#     #2 (0.814) A Computational Software for Training Robust Drug–Target Aff
#     #3 (0.808) Leading quantum correction to the classical free energy
#   [Hybrid (BM25+SPECTER2)]
#     #1 (0.030) Leading quantum correction to the classical free energy
#     #2 (0.027) Using Atomic Charges to Describe the p <i>K</i> <sub>a</sub>
#     #3 (0.025) Efficient Delivering of a Photodynamic Therapy Drug into Cel

# %%
# --- Task 1b: BOUN → External ---
cache_1b = os.path.join(CACHE_DIR, "results_1b.pkl")

if os.path.exists(cache_1b):
    print(f"Loading cached Task 1b results from {cache_1b}")
    with open(cache_1b, 'rb') as f:
        results_1b = pickle.load(f)
    missing = [m for m in METHODS if m not in results_1b]
    if missing:
        print(f"  Computing missing methods: {missing}")
        for method in missing:
            print(f"  ▶ Running {method}...")
            results_1b[method] = retrieve_top_k(
                list(sample_boun['text']), list(followed_df['text']),
                method=method, top_k=3
            )
        with open(cache_1b, 'wb') as f:
            pickle.dump(results_1b, f)
        print(f"  Updated cache with new methods")
else:
    print("=" * 80)
    print("TASK 1b: BOUN → External (50 BOUN queries → followed-institution corpus)")
    print("=" * 80)

    results_1b = {}
    for method in METHODS:
        print(f"\n▶ Running {method}...")
        results_1b[method] = retrieve_top_k(
            list(sample_boun['text']),
            list(followed_df['text']),
            method=method,
            top_k=3
        )
    with open(cache_1b, 'wb') as f:
        pickle.dump(results_1b, f)
    print(f"\nSaved Task 1b results to {cache_1b}")

# Display side-by-side comparison for first 3 queries
for i in range(3):
    query_title = str(sample_boun.iloc[i]['title'])[:80]
    print(f"\n{'─'*80}")
    print(f"Query {i+1}: {query_title}")
    for method in METHODS:
        hits = results_1b[method][i]
        print(f"  [{method_labels[method]:>20}]")
        for rank, (idx, score) in enumerate(hits, 1):
            match_title = str(followed_df.iloc[idx]['title'])[:60]
            print(f"    #{rank} ({score:.3f}) {match_title}")
# Out:
# Loading cached Task 1b results from data/results_cache/results_1b.pkl
#
# ────────────────────────────────────────────────────────────────────────────────
# Query 1: A local earthquake tomography on the EAF shows dipping fault structure
#   [              TF-IDF]
#     #1 (0.078) Urban Seismic Site Characterization by Fiber‐Optic Seismolog
#     #2 (0.063) A Phase 2/3 Prospective Multicenter Study of the Diagnostic
#     #3 (0.060) Relativistic kinematics of a magnetic soliton
#   [                BM25]
#     #1 (0.674) Relativistic kinematics of a magnetic soliton
#     #2 (0.672) DeepMIP: model intercomparison of early Eocene climatic opti
#     #3 (0.672) UNETR++: Delving Into Efficient and Accurate 3D Medical Imag
#   [              MiniLM]
#     #1 (0.359) Urban Seismic Site Characterization by Fiber‐Optic Seismolog
#     #2 (0.261) <i>Gaia</i>Early Data Release 3
#     #3 (0.219) First Sagittarius A* Event Horizon Telescope Results. IV. Va
#   [            SPECTER2]
#     #1 (0.857) Urban Seismic Site Characterization by Fiber‐Optic Seismolog
#     #2 (0.842) High-frequency monitoring of anomalous methane point sources
#     #3 (0.835) Improved SMAP Dual-Channel Algorithm for the Retrieval of So
#   [Hybrid (BM25+SPECTER2)]
#     #1 (0.031) Urban Seismic Site Characterization by Fiber‐Optic Seismolog
#     #2 (0.030) On the Evolution of the Hubble Constant with the SNe Ia Pant
#     #3 (0.029) Probing cosmic isotropy with a new X-ray galaxy cluster samp
#
# ────────────────────────────────────────────────────────────────────────────────
# Query 2: The effect of business administration students’ individual values on their entre
#   [              TF-IDF]
#     #1 (0.236) Context, time, and change: Historical approaches to entrepre
#     #2 (0.081) The COVID-19 pandemic as a game changer for public administr
#     #3 (0.061) On the Evolution of the Hubble Constant with the SNe Ia Pant
#   [                BM25]
#     #1 (0.601) Context, time, and change: Historical approaches to entrepre
#     #2 (0.510) On the Evolution of the Hubble Constant with the SNe Ia Pant
#     #3 (0.502) The COVID-19 pandemic as a game changer for public administr
#   [              MiniLM]
#     #1 (0.400) Context, time, and change: Historical approaches to entrepre
#     #2 (0.272) Working on my own: Measuring the challenges of gig work
#     #3 (0.269) Corporate Strategy and the Theory of the Firm in the Digital
#   [            SPECTER2]
#     #1 (0.878) Understanding inclusion in collaborative governance: a mixed
#     #2 (0.878) Working on my own: Measuring the challenges of gig work
#     #3 (0.876) Strategy and Uncertainty: Resource-Based View, Strategy-Crea
#   [Hybrid (BM25+SPECTER2)]
#     #1 (0.032) Context, time, and change: Historical approaches to entrepre
#     #2 (0.030) The COVID-19 pandemic as a game changer for public administr
#     #3 (0.029) A CHecklist for statistical Assessment of Medical Papers (th
#
# ────────────────────────────────────────────────────────────────────────────────
# Query 3: Pre-Service Mathematics and Physics Teachers’ Experiences of Implementing Peer-A
#   [              TF-IDF]
#     #1 (0.190) A CHecklist for statistical Assessment of Medical Papers (th
#     #2 (0.123) ACG Clinical Guideline: Gastroparesis
#     #3 (0.115) Composite grading algorithm for the National Cancer Institut
#   [                BM25]
#     #1 (0.589) A CHecklist for statistical Assessment of Medical Papers (th
#     #2 (0.520) To explain or not to explain?—Artificial intelligence explai
#     #3 (0.517) Minimum Reporting Standards for in vivo Magnetic Resonance S
#   [              MiniLM]
#     #1 (0.251) A CHecklist for statistical Assessment of Medical Papers (th
#     #2 (0.206) Increasing stability, efficiency, and fundamental understand
#     #3 (0.204) Medical Student Mobilization During a Crisis: Lessons From a
#   [            SPECTER2]
#     #1 (0.890) A CHecklist for statistical Assessment of Medical Papers (th
#     #2 (0.865) Performance of GPT-3.5 and GPT-4 on the Japanese Medical Lic
#     #3 (0.861) Minimum Reporting Standards for in vivo Magnetic Resonance S
#   [Hybrid (BM25+SPECTER2)]
#     #1 (0.033) A CHecklist for statistical Assessment of Medical Papers (th
#     #2 (0.032) Minimum Reporting Standards for in vivo Magnetic Resonance S
#     #3 (0.031) To explain or not to explain?—Artificial intelligence explai

# %%
# --- Task 1a: Compact Top-1 comparison table ---
rows = []
for i in range(len(sample_followed)):
    row = {'Query Paper': str(sample_followed.iloc[i]['title'])}
    for method in METHODS:
        idx, score = results_1a[method][i][0]
        title = str(boun_df.iloc[idx]['title'])
        pct = int(round(score * 100))
        row[f'{method_labels[method]} #1'] = f"[{pct}%] - {title}"
    rows.append(row)

df_1a_top1 = pd.DataFrame(rows)
pd.set_option('display.max_colwidth', 80)
print(f"Task 1a — External → BOUN: Top-1 per method ({len(df_1a_top1)} queries)")
df_1a_top1
# Out:
# Task 1a — External → BOUN: Top-1 per method (50 queries)
#                                                                         Query Paper  \
# 0                 Can N95 Respirators Be Reused after Disinfection? How Many Times?
# 1     The clustering of DESI-like luminous red galaxies using photometric redshifts
# 2                  Structure of the lysosomal mTORC1–TFEB–Rag–Ragulator megacomplex
# 3                 The Human Phenotype Ontology in 2024: phenotypes around the world
# 4   The primary mechanism of cytotoxicity of the chemotherapeutic agent CX-5461 ...
# 5   National Response to COVID-19 in the Republic of Korea and Lessons Learned f...
# 6        UNETR++: Delving Into Efficient and Accurate 3D Medical Image Segmentation
# 7   Head and Neck Cancers, Version 2.2020, NCCN Clinical Practice Guidelines in ...
# 8   Rapid implementation of mobile technology for real-time epidemiology of COVI...
# 9                                                 Are Ideas Getting Harder to Find?
# 10                      A unifying, eco‐physiological framework for animal dormancy
# 11                  Pitavastatin to Prevent Cardiovascular Disease in HIV Infection
# 12  Long-term Outcomes of Adding Lutein/Zeaxanthin and ω-3 Fatty Acids to the AR...
# 13  Effect of Nanoparticle Composition, Size, Shape, and Stiffness on Penetratio...
# 14  COVID‐19 Outcomes in Patients With Systemic Autoimmune Rheumatic Diseases Co...
# 15  Single-Agent Divarasib (GDC-6036) in Solid Tumors with a <i>KRAS</i> G12C Mu...
# 16  Diffuse alveolar damage (DAD) resulting from coronavirus disease 2019 Infect...
# 17                                                     Natural Adversarial Examples
# 18  Contribution of plasma cells and B cells to hidradenitis suppurativa pathoge...
# 19  Safety and Glycemic Outcomes During the MiniMed™ Advanced Hybrid Closed-Loop...
# 20               Assessment of three‐dimensional RNA structure prediction in CASP15
# 21  NRG-BR002: A phase IIR/III trial of standard of care systemic therapy with o...
# 22  Independent Drug Action in Combination Therapy: Implications for Precision O...
# 23  Polaron Delocalization in Donor–Acceptor Polymers and its Impact on Organic ...
# 24                               Self-Contained Neuromusculoskeletal Arm Prostheses
# 25   Blinded, randomized trial of sonographer versus AI cardiac function assessment
# 26  A Useful Guide to Lectin Binding: Machine-Learning Directed Annotation of 57...
# 27  Hydrogen-powered aircraft: Fundamental concepts, key technologies, and envir...
# 28  Performance of GPT-3.5 and GPT-4 on the Japanese Medical Licensing Examinati...
# 29                              Nursing Homes Are Ground Zero for COVID-19 Pandemic
# 30                 Inherited human IFN-γ deficiency underlies mycobacterial disease
# 31           Action Genome: Actions As Compositions of Spatio-Temporal Scene Graphs
# 32  Composite grading algorithm for the National Cancer Institute’s Patient-Repo...
# 33  Dark Energy Survey Year 3 results: Cosmology from cosmic shear and robustnes...
# 34  Information Technology–Based Tracing Strategy in Response to COVID-19 in Sou...
# 35  High-frequency monitoring of anomalous methane point sources with multispect...
# 36                               Surface hydration for antifouling and bio-adhesion
# 37  A Streaming On-Device End-To-End Model Surpassing Server-Side Conventional M...
# 38  Adjuvant Pertuzumab and Trastuzumab in Early HER2-Positive Breast Cancer in ...
# 39           Using gross ecosystem product (GEP) to value nature in decision making
# 40             Scalability in Perception for Autonomous Driving: Waymo Open Dataset
# 41  Triglyceride-glucose index variability and incident cardiovascular disease: ...
# 42  A Phase 2/3 Prospective Multicenter Study of the Diagnostic Accuracy of Pros...
# 43      Appropriate Use Criteria for Prostate-Specific Membrane Antigen PET Imaging
# 44  Clinical sensitivity and interpretation of PCR and serological COVID‐19 diag...
# 45  Consolidation in a crisis: Patterns of international collaboration in early ...
# 46                                                           The PHANGS-MUSE survey
# 47  Hydra: A Real-time Spatial Perception System for 3D Scene Graph Construction...
# 48  On the Evolution of the Hubble Constant with the SNe Ia Pantheon Sample and ...
# 49                                     Stiff neural ordinary differential equations
#
#                                                                           TF-IDF #1  \
# 0      [11%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 1   [12%] - Analysis of clustering and degree index in random graphs and complex...
# 2   [7%] - Evaluating GPT and BERT models for protein–protein interaction identi...
# 3   [6%] - The Complex Genetic Landscape of Hereditary Ataxias in Turkey and Imp...
# 4   [14%] - Time-dependent re-organization of biological processes by the analys...
# 5      [26%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 6   [26%] - On the Use of a Convolutional Block Attention Module in Deep Learnin...
# 7   [11%] - FPGA implementation of double-head SalsaNext: a CNN-based model for ...
# 8      [27%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 9   [12%] - Coexistence of proprietary and open‐source firms under product diffe...
# 10  [6%] - Exploring the relations between the physiological factors and the lik...
# 11  [14%] - Assessment of Carotid Stiffness and Strain Parameters Using Speckle ...
# 12   [9%] - Applications of Exosome Vesicles in Different Cancer Types asBiomarkers
# 13  [20%] - Long‐Lasting Simultaneous Epidermal and Dermal Microneedle‐Enabled D...
# 14     [23%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 15  [18%] - Applications of Exosome Vesicles in Different Cancer Types asBiomarkers
# 16     [12%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 17  [32%] - Perturbation Augmentation for Adversarial Training with Diverse Attacks
# 18  [8%] - Characterization of zika virus infection of human fetal cardiac mesen...
# 19  [11%] - The YouTube Effect on Adolescence: Exploring the Influences of Youtu...
# 20  [12%] - A Framework for Improving the Generalizability of Drug–Target Affini...
# 21  [11%] - Swelling of star polymer thin films exposed to supercritical carbon ...
# 22  [32%] - Efficient Delivering of a Photodynamic Therapy Drug into Cellular Me...
# 23  [13%] - Benzothiazole-disulfide based redox-responsive polymers: facile acce...
# 24  [13%] - Decoding sensorimotor information from somatosensory cortex by flexi...
# 25                                       [34%] - Quo vadis artificial intelligence?
# 26  [7%] - Overcoming the challenges in morphological annotation of Turkish in u...
# 27  [17%] - Enhancing Charge Transfer in Photocatalytic Hydrogen Production over...
# 28  [13%] - Evaluating GPT and BERT models for protein–protein interaction ident...
# 29     [25%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 30  [7%] - Abstract 2771: CRISPR/Cas9 essentiality screens identify stand-alone ...
# 31  [17%] - Discovering Predictive Relational Object Symbols With Symbolic Atten...
# 32  [14%] - Pre-Service Mathematics and Physics Teachers’ Experiences of Impleme...
# 33  [45%] - Equivalence of matter-type modified gravity theories to general rela...
# 34     [18%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 35  [13%] - Enhancing biomethane production from cattle manure by integrating ru...
# 36  [18%] - Injectable and Biocompatible Mussel‐Inspired Adhesive for Enhanced R...
# 37  [16%] - Edge-Compatible Deep Learning for Biometric Identification from Wris...
# 38  [19%] - Applications of Exosome Vesicles in Different Cancer Types asBiomarkers
# 39   [24%] - OurMED D3.3 Report on the Nature's Contribution to People. Version 1.1
# 40  [14%] - FPGA implementation of double-head SalsaNext: a CNN-based model for ...
# 41  [18%] - MRI pathway for small volume prostate gland index lesions: a single-...
# 42  [34%] - MRI pathway for small volume prostate gland index lesions: a single-...
# 43  [34%] - MRI pathway for small volume prostate gland index lesions: a single-...
# 44  [11%] - Screening of Clinically Approved and Investigation Drugs as Potentia...
# 45     [28%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 46  [12%] - Swelling of star polymer thin films exposed to supercritical carbon ...
# 47             [20%] - Generation of random chordal graphs using subtrees of a tree
# 48  [18%] - Analytic solutions of Brans–Dicke cosmology: Early inflation and lat...
# 49  [14%] - Special issue on advances and applications of artificial intelligenc...
#
#                                                                             BM25 #1  \
# 0   [69%] - Evaluation of Knowledge, Behavior, and Attitudes of Construction Wor...
# 1   [65%] - The NANOGrav 12.5 yr Data Set: A Computationally Efficient Eccentric...
# 2   [69%] - Distinct interaction modes orchestrate the polymerization of <scp>AS...
# 3                        [63%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 4   [68%] - Time-dependent re-organization of biological processes by the analys...
# 5      [74%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 6   [72%] - FPGA implementation of double-head SalsaNext: a CNN-based model for ...
# 7   [51%] - Cholesterol biogenesis is a PTEN‐dependent actionable node for the t...
# 8   [69%] - Screening of Clinically Approved and Investigation Drugs as Potentia...
# 9   [46%] - Stay in solidarity and share equally: An open access journal in chil...
# 10                  [63%] - Atomic Event Concepts in Perception, Action, and Belief
# 11  [44%] - Characterization of zika virus infection of human fetal cardiac mese...
# 12  [35%] - BIMG-14. IDENTIFICATION OF IDH MUTATION STATUS USING PROTON MR SPECT...
# 13  [71%] - Ceramide 3 Effect on the Physical Properties of Ambora Extract and C...
# 14     [50%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 15  [28%] - Scalable Yielding of Highly Stable Polyelectrolyte‐Coated Copper Sul...
# 16     [40%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 17  [57%] - Perturbation Augmentation for Adversarial Training with Diverse Attacks
# 18  [58%] - Characterization of zika virus infection of human fetal cardiac mese...
# 19  [66%] - Comparative genomics of Lentilactobacillus buchneri reveals strain-l...
# 20  [64%] - Abstract 2771: CRISPR/Cas9 essentiality screens identify stand-alone...
# 21  [75%] - Cross-section measurements for the production of a $$W$$-boson in as...
# 22  [61%] - Efficient Delivering of a Photodynamic Therapy Drug into Cellular Me...
# 23  [55%] - Swelling of star polymer thin films exposed to supercritical carbon ...
# 24  [61%] - Decoding sensorimotor information from somatosensory cortex by flexi...
# 25                                       [68%] - Quo vadis artificial intelligence?
# 26  [63%] - Plug-and-Play Biointerfaces: Harnessing Host–Guest Interactions for ...
# 27  [62%] - Enhancing Charge Transfer in Photocatalytic Hydrogen Production over...
# 28                   [34%] - Teaching self-regulation through role modeling in K-12
# 29  [48%] - Screening of Clinically Approved and Investigation Drugs as Potentia...
# 30  [65%] - A novel homozygous loss-of-function variant in SOD1 causing progress...
# 31  [67%] - Discovering Predictive Relational Object Symbols With Symbolic Atten...
# 32  [45%] - Pre-Service Mathematics and Physics Teachers’ Experiences of Impleme...
# 33  [71%] - Analytic solutions of Brans–Dicke cosmology: Early inflation and lat...
# 34  [47%] - Screening of Clinically Approved and Investigation Drugs as Potentia...
# 35                  [68%] - Clustering Event Streams With Low Rank Hawkes Processes
# 36  [70%] - Plug-and-Play Biointerfaces: Harnessing Host–Guest Interactions for ...
# 37  [66%] - Edge-Compatible Deep Learning for Biometric Identification from Wris...
# 38  [37%] - Cholesterol biogenesis is a PTEN‐dependent actionable node for the t...
# 39   [73%] - OurMED D3.3 Report on the Nature's Contribution to People. Version 1.1
# 40  [59%] - Preserving the Knowledge of the Past Through Virtual Visits: From 3D...
# 41  [37%] - MRI pathway for small volume prostate gland index lesions: a single-...
# 42  [56%] - MRI pathway for small volume prostate gland index lesions: a single-...
# 43  [71%] - Cholesterol biogenesis is a PTEN‐dependent actionable node for the t...
# 44  [66%] - Screening of Clinically Approved and Investigation Drugs as Potentia...
# 45     [76%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 46                  [68%] - A new joint IAG-IASPEI sub-commission for Seismogeodesy
# 47       [46%] - Cooperative Caching and Video Characteristics in D2D Edge Networks
# 48  [79%] - Analytic solutions of Brans–Dicke cosmology: Early inflation and lat...
# 49  [65%] - Robust Feature Learning for Remaining Useful Life Estimation Using S...
#
#                                                                           MiniLM #1  \
# 0   [27%] - Numerical Optimization of Gas Cooler Geometry in Transcritical Refri...
# 1                                        [37%] - The Dark Universe Is Not Invisible
# 2   [35%] - Time-dependent re-organization of biological processes by the analys...
# 3              [44%] - Cluster-based mention typing for named entity disambiguation
# 4   [45%] - Time-dependent re-organization of biological processes by the analys...
# 5      [49%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 6   [44%] - ISNAS-DIP: Image-Specific Neural Architecture Search for Deep Image ...
# 7                        [32%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 8      [46%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 9   [41%] - Coexistence of proprietary and open‐source firms under product diffe...
# 10  [30%] - Understanding the adaptive laboratory evolution of multiple stress‐r...
# 11     [32%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 12  [31%] - Targeting mitochondrial DNA polymerase gamma for selective inhibitio...
# 13  [50%] - Polymeric pH-Responsive Metal-Supramolecular Nanoparticles for Syner...
# 14     [39%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 15  [39%] - Targeting mitochondrial DNA polymerase gamma for selective inhibitio...
# 16  [31%] - Characterization of zika virus infection of human fetal cardiac mese...
# 17  [71%] - Perturbation Augmentation for Adversarial Training with Diverse Attacks
# 18  [35%] - Abstract 2771: CRISPR/Cas9 essentiality screens identify stand-alone...
# 19  [33%] - A Comparison of Wearable Heart Rate Sensors for HRV Biofeedback in t...
# 20  [40%] - A Framework for Improving the Generalizability of Drug–Target Affini...
# 21  [31%] - Screening of Clinically Approved and Investigation Drugs as Potentia...
# 22  [50%] - A Framework for Improving the Generalizability of Drug–Target Affini...
# 23  [50%] - Expanding the versatility of poly(dimethylsiloxane) through polymeri...
# 24  [56%] - The use of nonnormalized surface EMG and feature inputs for LSTM-bas...
# 25  [38%] - Integrated particle image velocimetry and fluid–structure interactio...
# 26  [47%] - A Computational Software for Training Robust Drug–Target Affinity Pr...
# 27  [32%] - Numerical Optimization of Gas Cooler Geometry in Transcritical Refri...
# 28  [35%] - Enhancing Immersion in Virtual Reality–Based Advanced Life Support T...
# 29     [39%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 30  [37%] - Abstract 2771: CRISPR/Cas9 essentiality screens identify stand-alone...
# 31  [48%] - Discovering Predictive Relational Object Symbols With Symbolic Atten...
# 32  [39%] - Can artificial intelligence models predict hospital stays following ...
# 33                                       [52%] - The Dark Universe Is Not Invisible
# 34  [38%] - Turkish Competition Board (“TCB”) Has Launched an Investigation agai...
# 35  [32%] - Lightweight high output power C-band FMCW SIMO radar system for smal...
# 36  [51%] - Injectable and Biocompatible Mussel‐Inspired Adhesive for Enhanced R...
# 37          [57%] - Uncertainty-Aware Representations for Spoken Question Answering
# 38  [24%] - PHOTODYNAMIC THERAPY FOR PERI-IMPLANTITIS: COMPARATIVE ANALYSES ON I...
# 39   [61%] - OurMED D3.3 Report on the Nature's Contribution to People. Version 1.1
# 40  [57%] - FPGA implementation of double-head SalsaNext: a CNN-based model for ...
# 41  [34%] - Assessment of Carotid Stiffness and Strain Parameters Using Speckle ...
# 42  [52%] - MRI pathway for small volume prostate gland index lesions: a single-...
# 43  [54%] - MRI pathway for small volume prostate gland index lesions: a single-...
# 44             [36%] - Time Varying Spillovers of COVID-19 on the Financial Markets
# 45     [46%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 46                                                                      [42%] - nan
# 47  [47%] - Learning Object Affordances from Sensory-Motor Interaction via Bayes...
# 48  [48%] - Analytic solutions of Brans–Dicke cosmology: Early inflation and lat...
# 49  [36%] - Robust Feature Learning for Remaining Useful Life Estimation Using S...
#
#                                                                         SPECTER2 #1  \
# 0      [89%] - Microfluidic contact lenses for ocular diagnostics and drug delivery
# 1   [84%] - Operation and performance of the ATLAS semiconductor tracker in LHC ...
# 2   [83%] - Computational analysis of missense filamin-A variants, including the...
# 3                        [90%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 4                        [93%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 5      [91%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 6   [91%] - Edge-Compatible Deep Learning for Biometric Identification from Wris...
# 7                        [89%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 8      [92%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 9   [88%] - The Replication Database: Documenting the Replicability of Psycholog...
# 10                       [89%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 11     [88%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 12  [87%] - Comparing the impact of wild type and derived DBP allelic variants d...
# 13  [92%] - Efficient Delivering of a Photodynamic Therapy Drug into Cellular Me...
# 14     [89%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 15  [89%] - A Computational Software for Training Robust Drug–Target Affinity Pr...
# 16  [85%] - Can artificial intelligence models predict hospital stays following ...
# 17  [93%] - Improving Robustness of Deep Learning Systems with Fast and Customiz...
# 18                       [88%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 19  [85%] - Enhancing Sales Prediction Accuracy Through Incorporation of Expert ...
# 20  [90%] - A Computational Software for Training Robust Drug–Target Affinity Pr...
# 21                       [86%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 22                       [93%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 23  [88%] - Functional polymeric coatings: thiol-maleimide ‘click’ chemistry as ...
# 24  [86%] - Numerical analysis of coil designs to expedite fracture healing usin...
# 25  [85%] - Integrated particle image velocimetry and fluid–structure interactio...
# 26  [89%] - A Computational Software for Training Robust Drug–Target Affinity Pr...
# 27       [88%] - The Geopolitical Implications of the Renewable Energy Transition 1
# 28                      [89%] - A Cross-National Comparison of Statistics Curricula
# 29     [90%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 30  [83%] - Computational analysis of missense filamin-A variants, including the...
# 31  [91%] - Learning Object Affordances from Sensory-Motor Interaction via Bayes...
# 32                       [89%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 33  [79%] - Search for new phenomena in final states with large jet multipliciti...
# 34     [89%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 35                                                                      [87%] - nan
# 36  [88%] - Hydrophilic Cross-Linked Polymeric Nanofibers Using Electrospinning:...
# 37  [88%] - Edge-Compatible Deep Learning for Biometric Identification from Wris...
# 38                       [89%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 39   [94%] - OurMED D3.3 Report on the Nature's Contribution to People. Version 1.1
# 40  [87%] - How We Found Our IMU: Guidelines to IMU Selection and a Comparison o...
# 41  [89%] - Assessment of Carotid Stiffness and Strain Parameters Using Speckle ...
# 42  [87%] - MRI pathway for small volume prostate gland index lesions: a single-...
# 43  [89%] - MRI pathway for small volume prostate gland index lesions: a single-...
# 44     [85%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 45            [93%] - Fiscal stimulus packages to COVID‐19: The role of informality
# 46                                                                      [87%] - nan
# 47  [88%] - Learning Object Affordances from Sensory-Motor Interaction via Bayes...
# 48  [90%] - Search for new phenomena in final states with large jet multipliciti...
# 49  [89%] - Special issue on advances and applications of artificial intelligenc...
#
#                                                           Hybrid (BM25+SPECTER2) #1
# 0   [3%] - Evaluation of Knowledge, Behavior, and Attitudes of Construction Work...
# 1                    [3%] - Clustering Event Streams With Low Rank Hawkes Processes
# 2                    [3%] - Leading quantum correction to the classical free energy
# 3                         [3%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 4   [3%] - Label‐Free Identification of Exosomes using Raman Spectroscopy and Ma...
# 5       [3%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 6   [3%] - MIDISpace: Finding Linear Directions in Latent Space for Music Genera...
# 7                         [3%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 8       [3%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 9   [3%] - Coexistence of proprietary and open‐source firms under product differ...
# 10    [3%] - OurMED D3.3 Report on the Nature's Contribution to People. Version 1.1
# 11      [3%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 12                        [3%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 13      [3%] - Microfluidic contact lenses for ocular diagnostics and drug delivery
# 14      [3%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 15  [3%] - Magnetic resonance spectroscopic correlates of progression free and o...
# 16      [3%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 17  [3%] - Improving Robustness of Deep Learning Systems with Fast and Customiza...
# 18  [3%] - Label‐Free Identification of Exosomes using Raman Spectroscopy and Ma...
# 19  [2%] - Comparing the impact of wild type and derived DBP allelic variants de...
# 20  [3%] - A Framework for Improving the Generalizability of Drug–Target Affinit...
# 21  [3%] - Search for new phenomena in final states with large jet multiplicitie...
# 22  [3%] - Efficient Delivering of a Photodynamic Therapy Drug into Cellular Mem...
# 23  [3%] - Expanding the versatility of poly(dimethylsiloxane) through polymeric...
# 24  [3%] - A Comparison of Wearable Heart Rate Sensors for HRV Biofeedback in th...
# 25                                        [3%] - Quo vadis artificial intelligence?
# 26  [3%] - A Framework for Improving the Generalizability of Drug–Target Affinit...
# 27  [3%] - Do Fossil Fuel Subsidies Delay the Low-Carbon Transition? Evidence fr...
# 28  [3%] - A Comparative Analysis on Employee Training: Competency-based vs Trad...
# 29      [3%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 30  [3%] - A novel homozygous loss-of-function variant in SOD1 causing progressi...
# 31  [3%] - Learning Object Affordances from Sensory-Motor Interaction via Bayesi...
# 32                        [3%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 33  [3%] - Analytic solutions of Brans–Dicke cosmology: Early inflation and late...
# 34      [3%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 35                                                                       [3%] - nan
# 36  [3%] - Hydrophilic Cross-Linked Polymeric Nanofibers Using Electrospinning: ...
# 37  [3%] - Edge-Compatible Deep Learning for Biometric Identification from Wrist...
# 38                        [3%] - Artificial Intelligence in Cancer: A SWOT Analysis
# 39    [3%] - OurMED D3.3 Report on the Nature's Contribution to People. Version 1.1
# 40            [3%] - Handling Concept Drift in Fraud Detection: A Replication Study
# 41  [3%] - MRI pathway for small volume prostate gland index lesions: a single-c...
# 42  [3%] - MRI pathway for small volume prostate gland index lesions: a single-c...
# 43  [3%] - MRI pathway for small volume prostate gland index lesions: a single-c...
# 44      [3%] - Microfluidic contact lenses for ocular diagnostics and drug delivery
# 45      [3%] - The Buffering Effects of Social Insurance for the Spread of Covid-19
# 46  [3%] - Neutron irradiation and electrical characterisation of the first 8” s...
# 47  [3%] - From Symbolic Representation to Submicroscopic One: Preservice Scienc...
# 48  [3%] - Analytic solutions of Brans–Dicke cosmology: Early inflation and late...
# 49  [3%] - Special issue on advances and applications of artificial intelligence...

# %%
# --- Task 1b: Compact Top-1 comparison table ---
rows = []
for i in range(len(sample_boun)):
    row = {'Query Paper': str(sample_boun.iloc[i]['title'])}
    for method in METHODS:
        idx, score = results_1b[method][i][0]
        title = str(followed_df.iloc[idx]['title'])
        pct = int(round(score * 100))
        row[f'{method_labels[method]} #1'] = f"[{pct}%] - {title}"
    rows.append(row)

df_1b_top1 = pd.DataFrame(rows)
print(f"Task 1b — BOUN → External: Top-1 per method ({len(df_1b_top1)} queries)")
df_1b_top1
# Out:
# Task 1b — BOUN → External: Top-1 per method (50 queries)
#                                                                         Query Paper  \
# 0            A local earthquake tomography on the EAF shows dipping fault structure
# 1   The effect of business administration students’ individual values on their e...
# 2   Pre-Service Mathematics and Physics Teachers’ Experiences of Implementing Pe...
# 3   Equivalence of matter-type modified gravity theories to general relativity w...
# 4      TRIFIN: Hybrid Indoor Positioning with Bluetooth Internet of Things Gateways
# 5                     Excitons in strained and suspended monolayer WSe <sub>2</sub>
# 6                       A new formulation for a code‐based vertical design spectrum
# 7   The effects of dihedral angle on hover rigidity and planar maneuvers in rota...
# 8   Boundary effects on the thermodynamics of quantum fields near a static black...
# 9   Maskless lithography with holographic feedback for the fabrication of optica...
# 10  Benzothiazole-disulfide based redox-responsive polymers: facile access to re...
# 11          Applications of Exosome Vesicles in Different Cancer Types asBiomarkers
# 12                               Active seismotectonics of the East Anatolian Fault
# 13  Fermatean Fuzzy Group Decision-Making Based CODAS Approach for Taxation of P...
# 14  Improving Code-Switching Dependency Parsing with Semi-Supervised Auxiliary T...
# 15  Distinct interaction modes orchestrate the polymerization of <scp>ASC PYD</s...
# 16  Probability Distribution of a Signal’s Peak Time in a Molecular Diffusive Media
# 17  Tomorrow&amp;#8217;s Cities: Multi-hazard interactions to inform disaster ri...
# 18  Efficient Delivering of a Photodynamic Therapy Drug into Cellular Membranes ...
# 19  A thermomechanical investigation of textured Magnesium in an effort to valid...
# 20  REFLECTIONS FROM HOME ON SECULARISM AND THE POSSIBILITY OF MUSLIM DEMOCRACY ...
# 21  Navigating the digital age: Children's self‐regulatory skills and technofere...
# 22  MRI pathway for small volume prostate gland index lesions: a single-centre r...
# 23  IMPROVING THE QUANTIFICATION ACCURACY OF Tc-99m MIBI DUAL-PHASE PARATHYROID ...
# 24              GHz-to-THz broadband communications for 6G non-terrestrial networks
# 25  Effects of Different Video Modalities on Writing Achievement in Flipped Engl...
# 26  Seismic coupling and aseismic slip along the central section of the North An...
# 27                                A Dynamic Model for Managing Volunteer Engagement
# 28    Cross Attentive Multi-Cue Fusion for Skeleton-Based Sign Language Recognition
# 29  WQI-Based Algorithmic Decision-Making for Water Withdrawal Depth in Drinking...
# 30  Using Atomic Charges to Describe the p <i>K</i> <sub>a</sub> of Carboxylic A...
# 31          Representation of Male Love in East Asia and West: “Fetish vs Activism”
# 32  Gender Detection with Smartphone Motion Sensors Using Convolutional Neural N...
# 33  Enthalpy of Formation of Polycyclic Aromatic Hydrocarbons and Heterocyclic A...
# 34   Imitation and mirror systems in robots through Deep Modality Blending Networks
# 35  Solute movement through undisturbed calcareous and dry region soils under di...
# 36  Search for Magnetic Monopoles and Stable High-Electric-Charge Objects in 13 ...
# 37                                An alternative interest-free home financing model
# 38  Singularity, violence and universality in Derrida’s ethics: Deconstruction’s...
# 39  Evaluating GPT and BERT models for protein–protein interaction identificatio...
# 40  Scale Development of Formative Higher Order Construct: Situational Strength ...
# 41                        Unitarianism and Social Reconciliation in North and South
# 42  Characterization of zika virus infection of human fetal cardiac mesenchymal ...
# 43                                   Holographic drag force in non-conformal plasma
# 44  Injectable and Biocompatible Mussel‐Inspired Adhesive for Enhanced Reendothe...
# 45                               President Erdogan’s Discourse on the Kurdish Issue
# 46  Cross Laminated Timber furniture providing shelter during earthquakes. Lifes...
# 47  Solar Flare Activity, 1937–2024: Introducing the New Hemispheric Solar Flare...
# 48   Spatial reason of the state: the role of space in protest repression in Turkey
# 49  The making of a global medical tourism destination: From state-supported pri...
#
#                                                                           TF-IDF #1  \
# 0              [8%] - Urban Seismic Site Characterization by Fiber‐Optic Seismology
# 1   [24%] - Context, time, and change: Historical approaches to entrepreneurship...
# 2   [19%] - A CHecklist for statistical Assessment of Medical Papers (the CHAMP ...
# 3   [41%] - Dark Energy Survey Year 3 results: Cosmology from cosmic shear and r...
# 4                            [12%] - A Survey on Computational Propaganda Detection
# 5   [15%] - Extreme tensile strain states in La <sub>0.7</sub> Ca <sub>0.3</sub>...
# 6                 [11%] - Subambient daytime radiative cooling of vertical surfaces
# 7   [5%] - MobileNeRF: Exploiting the Polygon Rasterization Pipeline for Efficie...
# 8   [16%] - First Sagittarius A* Event Horizon Telescope Results. IV. Variabilit...
# 9                             [12%] - Covid-19 and Health Care’s Digital Revolution
# 10  [17%] - Microfluidic electrochemistry for single-electron transfer redox-neu...
# 11                                                [39%] - Early detection of cancer
# 12   [7%] - Eighty Years of the Finite Element Method: Birth, Evolution, and Future
# 13  [15%] - To explain or not to explain?—Artificial intelligence explainability...
# 14  [14%] - Informer: Beyond Efficient Transformer for Long Sequence Time-Series...
# 15  [18%] - NLRP3 Inflammasome Assembly in Neutrophils Is Supported by PAD4 and ...
# 16                               [16%] - On Distillation of Guided Diffusion Models
# 17  [12%] - Mapping global urban boundaries from the global artificial imperviou...
# 18  [34%] - Independent Drug Action in Combination Therapy: Implications for Pre...
# 19  [13%] - Extreme tensile strain states in La <sub>0.7</sub> Ca <sub>0.3</sub>...
# 20  [9%] - Populism’s Threat to Democracy: Comparative Lessons for the United St...
# 21  [14%] - COVID-19–Associated Orphanhood and Caregiver Death in the United States
# 22  [34%] - A Phase 2/3 Prospective Multicenter Study of the Diagnostic Accuracy...
# 23  [15%] - Automatic Targetless Extrinsic Calibration of a 3D Lidar and Camera ...
# 24  [4%] - Strategies to prevent ventilator-associated pneumonia, ventilator-ass...
# 25  [9%] - Vid2Seq: Large-Scale Pretraining of a Visual Language Model for Dense...
# 26            [10%] - Urban Seismic Site Characterization by Fiber‐Optic Seismology
# 27  [6%] - Climate Adaptation as a Control Problem: Review and Perspectives on D...
# 28   [13%] - Action Genome: Actions As Compositions of Spatio-Temporal Scene Graphs
# 29  [17%] - Low‐Dimensional Electrocatalysts for Acidic Oxygen Evolution: Intrin...
# 30  [17%] - Differentiating Double-Layer, Psuedocapacitance, and Battery-like Me...
# 31                                       [11%] - Monsoons Climate Change Assessment
# 32  [21%] - Multi-task deep learning for cardiac rhythm detection in wearable de...
# 33  [9%] - Oxygenated Aromatic Compounds are Important Precursors of Secondary O...
# 34  [22%] - Self-Supervised Feature Learning via Exploiting Multi-Modal Data for...
# 35   [13%] - Ion-capture electrodialysis using multifunctional adsorptive membranes
# 36  [18%] - Constraints on low-mass, relic dark matter candidates from a surface...
# 37  [12%] - COVID-19 Home Confinement Negatively Impacts Social Participation an...
# 38      [23%] - Current research overstates American support for political violence
# 39  [23%] - Folding non-homologous proteins by coupling deep-learning contact ma...
# 40  [21%] - Spanish Version of the System Usability Scale for the Assessment of ...
# 41                    [8%] - Scientific Basis for Managing PFAS as a Chemical Class
# 42  [15%] - Integrated single-cell analysis of multicellular immune dynamics dur...
# 43                              [22%] - Conformal prediction beyond exchangeability
# 44           [34%] - Ultra-strong bio-glue from genetically engineered polypeptides
# 45  [15%] - Patterns of COVID-19 testing and mortality by race and ethnicity amo...
# 46  [7%] - Wood Carbon Based Single-Atom Catalyst for Rechargeable Zn–Air Batteries
# 47  [35%] - Electrons in the Young Solar Wind: First Results from the Parker Sol...
# 48  [9%] - BASS: multi-scale and multi-sample analysis enables accurate cell typ...
# 49  [15%] - Hardware Implementation of Deep Network Accelerators Towards Healthc...
#
#                                                                             BM25 #1  \
# 0                             [67%] - Relativistic kinematics of a magnetic soliton
# 1   [60%] - Context, time, and change: Historical approaches to entrepreneurship...
# 2   [59%] - A CHecklist for statistical Assessment of Medical Papers (the CHAMP ...
# 3   [64%] - On the Evolution of the Hubble Constant with the SNe Ia Pantheon Sam...
# 4   [53%] - Hardware Implementation of Deep Network Accelerators Towards Healthc...
# 5                                                [69%] - <i>Planck</i> 2018 results
# 6   [69%] - Improved SMAP Dual-Channel Algorithm for the Retrieval of Soil Moisture
# 7                           [68%] - Frequency-Dependent Squeezing for Advanced LIGO
# 8   [73%] - First Sagittarius A* Event Horizon Telescope Results. IV. Variabilit...
# 9   [58%] - 4D Printing of Freestanding Liquid Crystal Elastomers via Hybrid Add...
# 10  [25%] - Catalytic deconstruction of waste polyethylene with ethylene to form...
# 11  [68%] - Appropriate Use Criteria for Prostate-Specific Membrane Antigen PET ...
# 12  [71%] - DeepMIP: model intercomparison of early Eocene climatic optimum (EEC...
# 13  [62%] - Understanding inclusion in collaborative governance: a mixed methods...
# 14  [56%] - Informer: Beyond Efficient Transformer for Long Sequence Time-Series...
# 15  [72%] - NLRP3 Inflammasome Assembly in Neutrophils Is Supported by PAD4 and ...
# 16  [63%] - Trajectory-based differential expression analysis for single-cell se...
# 17  [64%] - Geo-knowledge-guided GPT models improve the extraction of location d...
# 18  [59%] - Small-molecule sequestration of amyloid-β as a drug discovery strate...
# 19  [61%] - Seawater sea-sand engineered/strain-hardening cementitious composite...
# 20  [44%] - Killing in the Slums: Social Order, Criminal Governance, and Police ...
# 21                                               [59%] - <i>Planck</i> 2018 results
# 22  [39%] - A Phase 2/3 Prospective Multicenter Study of the Diagnostic Accuracy...
# 23  [67%] - Automatic Targetless Extrinsic Calibration of a 3D Lidar and Camera ...
# 24  [60%] - Multi‐Parameter Optimized Triboelectric Nanogenerator Based Self‐Pow...
# 25  [64%] - Vid2Seq: Large-Scale Pretraining of a Visual Language Model for Dens...
# 26            [65%] - Urban Seismic Site Characterization by Fiber‐Optic Seismology
# 27  [45%] - Climate Adaptation as a Control Problem: Review and Perspectives on ...
# 28   [70%] - Action Genome: Actions As Compositions of Spatio-Temporal Scene Graphs
# 29                            [61%] - Kinetics of Sorption in Hygroscopic Hydrogels
# 30  [62%] - Constraints on low-mass, relic dark matter candidates from a surface...
# 31                                       [52%] - Monsoons Climate Change Assessment
# 32  [60%] - Multi-task deep learning for cardiac rhythm detection in wearable de...
# 33  [56%] - Oxygenated Aromatic Compounds are Important Precursors of Secondary ...
# 34             [76%] - RL-CycleGAN: Reinforcement Learning Aware Simulation-to-Real
# 35                            [81%] - Kinetics of Sorption in Hygroscopic Hydrogels
# 36  [63%] - Constraints on low-mass, relic dark matter candidates from a surface...
# 37  [82%] - Historical Redlining Is Associated with Present-Day Air Pollution Di...
# 38             [68%] - Quantum gas microscopy of Kardar-Parisi-Zhang superdiffusion
# 39  [25%] - Small-molecule sequestration of amyloid-β as a drug discovery strate...
# 40  [57%] - Spanish Version of the System Usability Scale for the Assessment of ...
# 41             [67%] - WFH Guidelines for the Management of Hemophilia, 3rd edition
# 42       [68%] - Phenotypic signatures of immune selection in HIV-1 reservoir cells
# 43           [45%] - Postselection-Free Entanglement Dynamics via Spacetime Duality
# 44           [72%] - Ultra-strong bio-glue from genetically engineered polypeptides
# 45  [64%] - Populism’s Threat to Democracy: Comparative Lessons for the United S...
# 46  [57%] - Electrostatic footpads enable agile insect-scale soft robots with tr...
# 47  [75%] - Electrons in the Young Solar Wind: First Results from the Parker Sol...
# 48  [62%] - How social norms are often a barrier to addressing climate change bu...
# 49  [69%] - Hardware Implementation of Deep Network Accelerators Towards Healthc...
#
#                                                                           MiniLM #1  \
# 0             [36%] - Urban Seismic Site Characterization by Fiber‐Optic Seismology
# 1   [40%] - Context, time, and change: Historical approaches to entrepreneurship...
# 2   [25%] - A CHecklist for statistical Assessment of Medical Papers (the CHAMP ...
# 3   [33%] - Statistical localization: From strong fragmentation to strong edge m...
# 4   [20%] - Multi-task deep learning for cardiac rhythm detection in wearable de...
# 5   [38%] - Single-Atom Pt Anchored on Oxygen Vacancy of Monolayer Ti<sub>3</sub...
# 6             [47%] - Urban Seismic Site Characterization by Fiber‐Optic Seismology
# 7   [36%] - FASTER: Fast and Safe Trajectory Planner for Navigation in Unknown E...
# 8   [34%] - Conservative Dynamics of Binary Systems to Third Post-Minkowskian Or...
# 9   [36%] - Radiation damage and dose limits in serial synchrotron crystallograp...
# 10             [47%] - Emerging porous organic polymers for biomedical applications
# 11  [67%] - Nanoparticles in tumor microenvironment remodeling and cancer immuno...
# 12            [27%] - Urban Seismic Site Characterization by Fiber‐Optic Seismology
# 13                   [25%] - Scientific Basis for Managing PFAS as a Chemical Class
# 14  [47%] - Syntactic Data Augmentation Increases Robustness to Inference Heuris...
# 15  [68%] - NLRP3 Inflammasome Assembly in Neutrophils Is Supported by PAD4 and ...
# 16  [27%] - Ultrasensitive Detection of Attomolar Protein Concentrations by Drop...
# 17  [39%] - An investigation of transmission control measures during the first 5...
# 18  [48%] - Effect of Nanoparticle Composition, Size, Shape, and Stiffness on Pe...
# 19  [35%] - Radiation damage and dose limits in serial synchrotron crystallograp...
# 20      [23%] - Current research overstates American support for political violence
# 21   [40%] - Is Parental Burnout Distinct From Job Burnout and Depressive Symptoms?
# 22  [59%] - NCCN Guidelines® Insights: Prostate Cancer Early Detection, Version ...
# 23  [37%] - Minimum Reporting Standards for in vivo Magnetic Resonance Spectrosc...
# 24  [34%] - The Stove, Dome, and Umbrella Effects of Atmospheric Aerosol on the ...
# 25  [41%] - Co-Writing Screenplays and Theatre Scripts with Language Models: Eva...
# 26  [31%] - First Sagittarius A* Event Horizon Telescope Results. IV. Variabilit...
# 27  [35%] - Understanding inclusion in collaborative governance: a mixed methods...
# 28  [45%] - Real-time, low-latency closed-loop feedback using markerless posture...
# 29  [33%] - Climate Adaptation as a Control Problem: Review and Perspectives on ...
# 30  [34%] - Differentiating Double-Layer, Psuedocapacitance, and Battery-like Me...
# 31  [33%] - Putting People Down and Pushing Them Out: Sexual Harassment in the W...
# 32       [50%] - Personality Research and Assessment in the Era of Machine Learning
# 33  [42%] - Oxygenated Aromatic Compounds are Important Precursors of Secondary ...
# 34       [49%] - Vector Neurons: A General Framework for SO(3)-Equivariant Networks
# 35                            [31%] - Kinetics of Sorption in Hygroscopic Hydrogels
# 36  [51%] - Constraints on low-mass, relic dark matter candidates from a surface...
# 37  [36%] - Historical redlining and cardiovascular health: The Multi-Ethnic Stu...
# 38  [27%] - Putting People Down and Pushing Them Out: Sexual Harassment in the W...
# 39  [44%] - ChatGPT Chemistry Assistant for Text Mining and the Prediction of MO...
# 40  [53%] - Spanish Version of the System Usability Scale for the Assessment of ...
# 41  [20%] - Context, time, and change: Historical approaches to entrepreneurship...
# 42  [43%] - Inhibition of PIKfyve kinase prevents infection by Zaire ebolavirus ...
# 43                       [37%] - <i>Colloquium</i>: Planckian dissipation in metals
# 44           [68%] - Ultra-strong bio-glue from genetically engineered polypeptides
# 45  [22%] - The Problematic Concept of Native Speaker in Psycholinguistics: Repl...
# 46  [28%] - From grasping to manipulation with gecko-inspired adhesives on a mul...
# 47  [47%] - Electrons in the Young Solar Wind: First Results from the Parker Sol...
# 48  [39%] - Killing in the Slums: Social Order, Criminal Governance, and Police ...
# 49  [34%] - Use and Content of Primary Care Office-Based vs Telemedicine Care Vi...
#
#                                                                         SPECTER2 #1  \
# 0             [86%] - Urban Seismic Site Characterization by Fiber‐Optic Seismology
# 1   [88%] - Understanding inclusion in collaborative governance: a mixed methods...
# 2   [89%] - A CHecklist for statistical Assessment of Medical Papers (the CHAMP ...
# 3   [91%] - Statistical localization: From strong fragmentation to strong edge m...
# 4   [86%] - Multi‐Parameter Optimized Triboelectric Nanogenerator Based Self‐Pow...
# 5   [88%] - Extreme tensile strain states in La <sub>0.7</sub> Ca <sub>0.3</sub>...
# 6   [89%] - Seawater sea-sand engineered/strain-hardening cementitious composite...
# 7   [87%] - FASTER: Fast and Safe Trajectory Planner for Navigation in Unknown E...
# 8   [87%] - Conservative Dynamics of Binary Systems to Third Post-Minkowskian Or...
# 9   [87%] - Learned rotationally symmetric diffractive achromat for full-spectru...
# 10             [87%] - Emerging porous organic polymers for biomedical applications
# 11  [95%] - Nanoparticles in tumor microenvironment remodeling and cancer immuno...
# 12  [85%] - High-frequency monitoring of anomalous methane point sources with mu...
# 13   [87%] - Using gross ecosystem product (GEP) to value nature in decision making
# 14  [93%] - Syntactic Data Augmentation Increases Robustness to Inference Heuris...
# 15  [92%] - NLRP3 Inflammasome Assembly in Neutrophils Is Supported by PAD4 and ...
# 16                                   [89%] - Roadmap on spatiotemporal light fields
# 17  [92%] - An ecosystem service perspective on urban nature, physical activity,...
# 18  [92%] - Effect of Nanoparticle Composition, Size, Shape, and Stiffness on Pe...
# 19            [88%] - Coarse graining molecular dynamics with graph neural networks
# 20           [87%] - Evaluating Models’ Local Decision Boundaries via Contrast Sets
# 21                                [89%] - The affective benefits of nature exposure
# 22  [93%] - Validation of a 22-Gene Genomic Classifier in Patients With Recurren...
# 23  [87%] - Minimum Reporting Standards for in vivo Magnetic Resonance Spectrosc...
# 24  [86%] - Improved SMAP Dual-Channel Algorithm for the Retrieval of Soil Moisture
# 25  [89%] - AI-generated characters for supporting personalized learning and wel...
# 26            [88%] - Urban Seismic Site Characterization by Fiber‐Optic Seismology
# 27  [90%] - An ecosystem service perspective on urban nature, physical activity,...
# 28  [91%] - Self-Supervised Feature Learning via Exploiting Multi-Modal Data for...
# 29  [91%] - Climate Adaptation as a Control Problem: Review and Perspectives on ...
# 30                      [88%] - Roadmap on Machine learning in electronic structure
# 31  [91%] - Putting People Down and Pushing Them Out: Sexual Harassment in the W...
# 32  [90%] - Hardware Implementation of Deep Network Accelerators Towards Healthc...
# 33                      [85%] - Roadmap on Machine learning in electronic structure
# 34             [93%] - RL-CycleGAN: Reinforcement Learning Aware Simulation-to-Real
# 35  [82%] - Improved SMAP Dual-Channel Algorithm for the Retrieval of Soil Moisture
# 36                 [90%] - Volume IV. The DUNE far detector single-phase technology
# 37                              [88%] - Anatomy of Corporate Borrowing Constraints*
# 38  [88%] - The Problematic Concept of Native Speaker in Psycholinguistics: Repl...
# 39  [91%] - Pharmacogene Variation Consortium: A Global Resource and Repository ...
# 40  [92%] - Spanish Version of the System Usability Scale for the Assessment of ...
# 41  [85%] - Putting People Down and Pushing Them Out: Sexual Harassment in the W...
# 42  [93%] - Type III interferons disrupt the lung epithelial barrier upon viral ...
# 43  [88%] - Conservative Dynamics of Binary Systems to Third Post-Minkowskian Or...
# 44           [95%] - Ultra-strong bio-glue from genetically engineered polypeptides
# 45  [89%] - Populism’s Threat to Democracy: Comparative Lessons for the United S...
# 46  [87%] - Seawater sea-sand engineered/strain-hardening cementitious composite...
# 47                                       [86%] - Monsoons Climate Change Assessment
# 48  [92%] - Killing in the Slums: Social Order, Criminal Governance, and Police ...
# 49  [90%] - Killing in the Slums: Social Order, Criminal Governance, and Police ...
#
#                                                           Hybrid (BM25+SPECTER2) #1
# 0              [3%] - Urban Seismic Site Characterization by Fiber‐Optic Seismology
# 1   [3%] - Context, time, and change: Historical approaches to entrepreneurship ...
# 2   [3%] - A CHecklist for statistical Assessment of Medical Papers (the CHAMP s...
# 3   [3%] - Large-misalignment mechanism for the formation of compact axion struc...
# 4   [3%] - Multi‐Parameter Optimized Triboelectric Nanogenerator Based Self‐Powe...
# 5   [3%] - Extreme tensile strain states in La <sub>0.7</sub> Ca <sub>0.3</sub> ...
# 6    [3%] - Improved SMAP Dual-Channel Algorithm for the Retrieval of Soil Moisture
# 7   [3%] - FASTER: Fast and Safe Trajectory Planner for Navigation in Unknown En...
# 8   [3%] - Conservative Dynamics of Binary Systems to Third Post-Minkowskian Ord...
# 9   [3%] - 4D Printing of Freestanding Liquid Crystal Elastomers via Hybrid Addi...
# 10  [3%] - Polaron Delocalization in Donor–Acceptor Polymers and its Impact on O...
# 11  [3%] - Nanoparticles in tumor microenvironment remodeling and cancer immunot...
# 12                                        [3%] - Monsoons Climate Change Assessment
# 13  [3%] - To explain or not to explain?—Artificial intelligence explainability ...
# 14  [3%] - Informer: Beyond Efficient Transformer for Long Sequence Time-Series ...
# 15  [3%] - NLRP3 Inflammasome Assembly in Neutrophils Is Supported by PAD4 and P...
# 16  [3%] - Trajectory-based differential expression analysis for single-cell seq...
# 17  [3%] - An ecosystem service perspective on urban nature, physical activity, ...
# 18  [3%] - Effect of Nanoparticle Composition, Size, Shape, and Stiffness on Pen...
# 19  [3%] - Seawater sea-sand engineered/strain-hardening cementitious composites...
# 20  [3%] - Killing in the Slums: Social Order, Criminal Governance, and Police V...
# 21    [3%] - Is Parental Burnout Distinct From Job Burnout and Depressive Symptoms?
# 22  [3%] - NCCN Guidelines® Insights: Prostate Cancer Early Detection, Version 1...
# 23  [3%] - Automatic Targetless Extrinsic Calibration of a 3D Lidar and Camera b...
# 24  [3%] - Multi‐Parameter Optimized Triboelectric Nanogenerator Based Self‐Powe...
# 25  [3%] - AI-generated characters for supporting personalized learning and well...
# 26             [3%] - Urban Seismic Site Characterization by Fiber‐Optic Seismology
# 27  [3%] - Understanding inclusion in collaborative governance: a mixed methods ...
# 28        [3%] - Vector Neurons: A General Framework for SO(3)-Equivariant Networks
# 29  [3%] - Climate Adaptation as a Control Problem: Review and Perspectives on D...
# 30  [3%] - Acidic Oxygen Evolution Reaction Activity–Stability Relationships in ...
# 31  [3%] - Putting People Down and Pushing Them Out: Sexual Harassment in the Wo...
# 32  [3%] - Multi-task deep learning for cardiac rhythm detection in wearable dev...
# 33  [3%] - Oxygenated Aromatic Compounds are Important Precursors of Secondary O...
# 34              [3%] - RL-CycleGAN: Reinforcement Learning Aware Simulation-to-Real
# 35   [3%] - Improved SMAP Dual-Channel Algorithm for the Retrieval of Soil Moisture
# 36                  [3%] - Volume IV. The DUNE far detector single-phase technology
# 37  [3%] - Historical Redlining Is Associated with Present-Day Air Pollution Dis...
# 38  [3%] - The Problematic Concept of Native Speaker in Psycholinguistics: Repla...
# 39  [3%] - Trajectory-based differential expression analysis for single-cell seq...
# 40  [3%] - Spanish Version of the System Usability Scale for the Assessment of E...
# 41  [3%] - The Problematic Concept of Native Speaker in Psycholinguistics: Repla...
# 42  [3%] - Morphological cell profiling of SARS-CoV-2 infection identifies drug ...
# 43  [3%] - Multisystem Bayesian constraints on the transport coefficients of QCD...
# 44            [3%] - Ultra-strong bio-glue from genetically engineered polypeptides
# 45  [3%] - Populism’s Threat to Democracy: Comparative Lessons for the United St...
# 46  [3%] - Multi‐Parameter Optimized Triboelectric Nanogenerator Based Self‐Powe...
# 47  [3%] - Electrons in the Young Solar Wind: First Results from the Parker Sola...
# 48  [3%] - How social norms are often a barrier to addressing climate change but...
# 49  [3%] - Killing in the Slums: Social Order, Criminal Governance, and Police V...

# %% [markdown]
# ## Task 2 — Embedding Method Comparison

# %% [markdown]
# ## Task 3 — Intra-Paper Similarity
#
# These tasks validate that the similarity pipeline ranks known-relevant papers highly.
#
# **3a. Same-Author Paper Ranking** — Given a target paper, retrieve all other papers by the same author(s) from the BOUN corpus. Rank by similarity. Expected: thematically related works by the same author should rank near the top.
#
#
# Same-Author in Top-5: Bir target paper için similarity sıralaması yapıldığında, en benzer 5 paper içinde kaç tanesi aynı yazara ait? Ör: Bir yazarın 15 paper'ı var. Birini target seçiyoruz, geri kalan 14'ünü + 50 rastgele paper'ı corpus'a koyuyoruz. Similarity ile sıralıyoruz. Top-5'te aynı yazarın kaç paper'ı çıktı?
#
# 3/5 → top-5'te 3'ü aynı yazar, iyi sonuç
# 0/5 → hiçbiri çıkmamış, embedding o yazar için ayırt edici değil
#
# **3b. Cited Paper Ranking** — Given a target paper, retrieve its reference list (papers it cites) from the dataset. Rank by similarity. Expected: directly cited works should score higher than unrelated papers.

# %%
# --- Build author & reference lookups on the FULL boun corpus ---
boun_full = boun_df_full.copy()

# Author → paper indices
author_to_papers = defaultdict(list)
paper_authors = {}

for i, row in boun_full.iterrows():
    auths = row.get('authorships', [])
    if isinstance(auths, list):
        aids = []
        for a in auths:
            if isinstance(a, dict) and 'author' in a:
                aid = a['author'].get('id', '')
                if aid:
                    aids.append(aid)
                    author_to_papers[aid].append(i)
        paper_authors[i] = aids

# Paper ID → index
boun_full_id_to_idx = {str(row['id']): i for i, row in boun_full.iterrows()}

# Referenced works per paper (only those in BOUN corpus)
boun_id_set = set(boun_full_id_to_idx.keys())
paper_refs_in_corpus = {}
for i, row in boun_full.iterrows():
    refs = row.get('referenced_works', [])
    if isinstance(refs, list):
        in_corpus = [r for r in refs if str(r) in boun_id_set]
        if in_corpus:
            paper_refs_in_corpus[i] = in_corpus

# Prolific authors (≥10 papers) for Task 3a
prolific_authors = {a: idxs for a, idxs in author_to_papers.items() if len(idxs) >= 10}

# Papers with ≥3 cited works in corpus for Task 3b
papers_with_refs = {i: refs for i, refs in paper_refs_in_corpus.items() if len(refs) >= 3}

print(f"Full BOUN corpus: {len(boun_full)} papers")
print(f"Prolific authors (≥10 papers): {len(prolific_authors)}")
print(f"Papers with ≥3 in-corpus references: {len(papers_with_refs)}")
# Out:
# Full BOUN corpus: 3000 papers
# Prolific authors (≥10 papers): 231
# Papers with ≥3 in-corpus references: 85

# %%
# --- Task 3a: Same-Author Paper Ranking ---
TASK3_METHODS = ['tfidf', 'bm25', 'minilm']  # exclude 'specter2' - hybrid (too slow for per-query eval)
cache_3a = os.path.join(CACHE_DIR, "results_3a_all.pkl")

if os.path.exists(cache_3a):
    print(f"Loading cached Task 3a results from {cache_3a}")
    with open(cache_3a, 'rb') as f:
        task3a_results = pickle.load(f)
    missing = [m for m in TASK3_METHODS if m not in task3a_results]
    if missing:
        print(f"  Computing missing methods: {missing}")
        np.random.seed(42)
        sampled_authors = np.random.choice(list(prolific_authors.keys()), size=min(20, len(prolific_authors)), replace=False)
        for method in missing:
            print(f"\n  ▶ Task 3a with {method_labels[method]}...")
            method_results = []
            for author_id in sampled_authors:
                paper_idxs = author_to_papers[author_id]
                target_idx = np.random.choice(paper_idxs)
                same_author_idxs = [j for j in paper_idxs if j != target_idx]
                non_author_pool = [j for j in range(len(boun_full)) if j not in set(paper_idxs)]
                n_negative = min(50, len(non_author_pool))
                negative_idxs = list(np.random.choice(non_author_pool, size=n_negative, replace=False))
                corpus_idxs = same_author_idxs + negative_idxs
                is_same_author = [True] * len(same_author_idxs) + [False] * len(negative_idxs)
                target_text = boun_full.iloc[target_idx]['text']
                corpus_texts = [boun_full.iloc[j]['text'] for j in corpus_idxs]
                if method == 'tfidf':
                    sim = tfidf_similarity([target_text], corpus_texts)[0]
                elif method == 'bm25':
                    sim = bm25_similarity([target_text], corpus_texts)[0]
                else:
                    sim = sentence_embedding_similarity([target_text], corpus_texts, model_name=MODEL_MAP[method])[0]
                ranked = sorted(zip(corpus_idxs, is_same_author, sim), key=lambda x: -x[2])
                author_name = ""
                auths = boun_full.iloc[target_idx].get('authorships', [])
                for a in (auths if isinstance(auths, list) else []):
                    if isinstance(a, dict) and a.get('author', {}).get('id') == author_id:
                        author_name = a['author'].get('display_name', '')
                        break
                method_results.append({
                    'author_id': author_id, 'author_name': author_name,
                    'target_idx': target_idx, 'target_title': str(boun_full.iloc[target_idx]['title']),
                    'n_same_author': len(same_author_idxs), 'n_corpus': len(corpus_idxs),
                    'ranked': [(idx, sa, float(s)) for idx, sa, s in ranked]
                })
            task3a_results[method] = method_results
            print(f"    Done: {len(method_results)} queries")
        with open(cache_3a, 'wb') as f:
            pickle.dump(task3a_results, f)
        print(f"  Updated cache")
else:
    np.random.seed(42)
    sampled_authors = np.random.choice(list(prolific_authors.keys()), size=min(20, len(prolific_authors)), replace=False)

    task3a_results = {}
    for method in TASK3_METHODS:
        print(f"\n▶ Task 3a with {method_labels[method]}...")
        method_results = []
        for author_id in sampled_authors:
            paper_idxs = author_to_papers[author_id]
            target_idx = np.random.choice(paper_idxs)
            same_author_idxs = [j for j in paper_idxs if j != target_idx]

            non_author_pool = [j for j in range(len(boun_full)) if j not in set(paper_idxs)]
            n_negative = min(50, len(non_author_pool))
            negative_idxs = list(np.random.choice(non_author_pool, size=n_negative, replace=False))
            corpus_idxs = same_author_idxs + negative_idxs
            is_same_author = [True] * len(same_author_idxs) + [False] * len(negative_idxs)

            target_text = boun_full.iloc[target_idx]['text']
            corpus_texts = [boun_full.iloc[j]['text'] for j in corpus_idxs]

            if method == 'tfidf':
                sim = tfidf_similarity([target_text], corpus_texts)[0]
            elif method == 'bm25':
                sim = bm25_similarity([target_text], corpus_texts)[0]
            else:
                sim = sentence_embedding_similarity([target_text], corpus_texts, model_name=MODEL_MAP[method])[0]

            ranked = sorted(zip(corpus_idxs, is_same_author, sim), key=lambda x: -x[2])

            author_name = ""
            auths = boun_full.iloc[target_idx].get('authorships', [])
            for a in (auths if isinstance(auths, list) else []):
                if isinstance(a, dict) and a.get('author', {}).get('id') == author_id:
                    author_name = a['author'].get('display_name', '')
                    break

            method_results.append({
                'author_id': author_id,
                'author_name': author_name,
                'target_idx': target_idx,
                'target_title': str(boun_full.iloc[target_idx]['title']),
                'n_same_author': len(same_author_idxs),
                'n_corpus': len(corpus_idxs),
                'ranked': [(idx, sa, float(s)) for idx, sa, s in ranked]
            })
        task3a_results[method] = method_results
        print(f"  Done: {len(method_results)} queries")

    with open(cache_3a, 'wb') as f:
        pickle.dump(task3a_results, f)
    print(f"\nSaved Task 3a results to {cache_3a}")

# Summary table per method
print(f"\n{'Method':<20} {'Avg Same-Author Rank':>22} {'Same-Author in Top-5':>22}")
print("─" * 70)
for method in TASK3_METHODS:
    avg_ranks = []
    top5_hits = []
    for res in task3a_results[method]:
        sa_ranks = [r + 1 for r, (_, sa, _) in enumerate(res['ranked']) if sa]
        avg_ranks.append(np.mean(sa_ranks) if sa_ranks else res['n_corpus'])
        top5_hits.append(sum(1 for _, sa, _ in res['ranked'][:5] if sa))
    print(f"{method_labels[method]:<20} {np.mean(avg_ranks):>22.1f} {np.mean(top5_hits):>22.2f}")
# Out:
# Loading cached Task 3a results from data/results_cache/results_3a_all.pkl
#
# Method                 Avg Same-Author Rank   Same-Author in Top-5
# ──────────────────────────────────────────────────────────────────────
# TF-IDF                                 13.9                   4.70
# BM25                                   15.5                   4.80
# MiniLM                                 13.1                   4.90

# %%
# --- Task 3b: Cited Paper Ranking ---
cache_3b = os.path.join(CACHE_DIR, "results_3b_all.pkl")

if os.path.exists(cache_3b):
    print(f"Loading cached Task 3b results from {cache_3b}")
    with open(cache_3b, 'rb') as f:
        task3b_results = pickle.load(f)
    missing = [m for m in TASK3_METHODS if m not in task3b_results]
    if missing:
        print(f"  Computing missing methods: {missing}")
        np.random.seed(42)
        sampled_papers = np.random.choice(list(papers_with_refs.keys()), size=min(20, len(papers_with_refs)), replace=False)
        for method in missing:
            print(f"\n  ▶ Task 3b with {method_labels[method]}...")
            method_results = []
            for target_idx in sampled_papers:
                ref_ids = papers_with_refs[target_idx]
                cited_idxs = [boun_full_id_to_idx[str(rid)] for rid in ref_ids if str(rid) in boun_full_id_to_idx]
                cited_set = set(cited_idxs)
                non_cited_pool = [j for j in range(len(boun_full)) if j != target_idx and j not in cited_set]
                n_negative = min(50, len(non_cited_pool))
                negative_idxs = list(np.random.choice(non_cited_pool, size=n_negative, replace=False))
                corpus_idxs = cited_idxs + negative_idxs
                is_cited = [True] * len(cited_idxs) + [False] * len(negative_idxs)
                target_text = boun_full.iloc[target_idx]['text']
                corpus_texts = [boun_full.iloc[j]['text'] for j in corpus_idxs]
                if method == 'tfidf':
                    sim = tfidf_similarity([target_text], corpus_texts)[0]
                elif method == 'bm25':
                    sim = bm25_similarity([target_text], corpus_texts)[0]
                else:
                    sim = sentence_embedding_similarity([target_text], corpus_texts, model_name=MODEL_MAP[method])[0]
                ranked = sorted(zip(corpus_idxs, is_cited, sim), key=lambda x: -x[2])
                method_results.append({
                    'target_idx': target_idx, 'target_title': str(boun_full.iloc[target_idx]['title']),
                    'n_cited': len(cited_idxs), 'n_corpus': len(corpus_idxs),
                    'ranked': [(idx, ic, float(s)) for idx, ic, s in ranked]
                })
            task3b_results[method] = method_results
            print(f"    Done: {len(method_results)} queries")
        with open(cache_3b, 'wb') as f:
            pickle.dump(task3b_results, f)
        print(f"  Updated cache")
else:
    np.random.seed(42)
    sampled_papers = np.random.choice(list(papers_with_refs.keys()), size=min(20, len(papers_with_refs)), replace=False)

    task3b_results = {}
    for method in TASK3_METHODS:
        print(f"\n▶ Task 3b with {method_labels[method]}...")
        method_results = []
        for target_idx in sampled_papers:
            ref_ids = papers_with_refs[target_idx]
            cited_idxs = [boun_full_id_to_idx[str(rid)] for rid in ref_ids if str(rid) in boun_full_id_to_idx]

            cited_set = set(cited_idxs)
            non_cited_pool = [j for j in range(len(boun_full)) if j != target_idx and j not in cited_set]
            n_negative = min(50, len(non_cited_pool))
            negative_idxs = list(np.random.choice(non_cited_pool, size=n_negative, replace=False))
            corpus_idxs = cited_idxs + negative_idxs
            is_cited = [True] * len(cited_idxs) + [False] * len(negative_idxs)

            target_text = boun_full.iloc[target_idx]['text']
            corpus_texts = [boun_full.iloc[j]['text'] for j in corpus_idxs]

            if method == 'tfidf':
                sim = tfidf_similarity([target_text], corpus_texts)[0]
            elif method == 'bm25':
                sim = bm25_similarity([target_text], corpus_texts)[0]
            else:
                sim = sentence_embedding_similarity([target_text], corpus_texts, model_name=MODEL_MAP[method])[0]

            ranked = sorted(zip(corpus_idxs, is_cited, sim), key=lambda x: -x[2])

            method_results.append({
                'target_idx': target_idx,
                'target_title': str(boun_full.iloc[target_idx]['title']),
                'n_cited': len(cited_idxs),
                'n_corpus': len(corpus_idxs),
                'ranked': [(idx, ic, float(s)) for idx, ic, s in ranked]
            })
        task3b_results[method] = method_results
        print(f"  Done: {len(method_results)} queries")

    with open(cache_3b, 'wb') as f:
        pickle.dump(task3b_results, f)
    print(f"\nSaved Task 3b results to {cache_3b}")

# Summary table per method
print(f"\n{'Method':<20} {'Avg Cited Rank':>16} {'Cited in Top-5':>16}")
print("─" * 56)
for method in TASK3_METHODS:
    avg_ranks = []
    top5_hits = []
    for res in task3b_results[method]:
        cited_ranks = [r + 1 for r, (_, ic, _) in enumerate(res['ranked']) if ic]
        avg_ranks.append(np.mean(cited_ranks) if cited_ranks else res['n_corpus'])
        top5_hits.append(sum(1 for _, ic, _ in res['ranked'][:5] if ic))
    print(f"{method_labels[method]:<20} {np.mean(avg_ranks):>16.1f} {np.mean(top5_hits):>16.2f}")
# Out:
# Loading cached Task 3b results from data/results_cache/results_3b_all.pkl
#
# Method                 Avg Cited Rank   Cited in Top-5
# ────────────────────────────────────────────────────────
# TF-IDF                            4.0             3.65
# BM25                              6.7             3.45
# MiniLM                            3.8             3.55

# %%
# --- Task 3b: Detailed per-query table ---
for method in TASK3_METHODS:
    rows = []
    for res in task3b_results[method]:
        ranked = res['ranked']
        top1_score = ranked[0][2] if ranked else None
        top1_is_cited = ranked[0][1] if ranked else None
        hits_3 = sum(1 for _, ic, _ in ranked[:3] if ic)
        hits_10 = sum(1 for _, ic, _ in ranked[:10] if ic)
        rows.append({
            'Target Paper': res['target_title'][:80],
            'Cited Papers': res['n_cited'],
            'Corpus Size': res['n_corpus'],
            'Top-1 Score': round(top1_score, 4) if top1_score is not None else None,
            'Top-1 Is Cited': top1_is_cited,
            'Hits@3': hits_3,
            'Hits@10': hits_10,
        })
    df_table = pd.DataFrame(rows)
    print(f"\n{'='*40}")
    print(f"  {method_labels[method]} — Cited Paper Retrieval")
    print(f"{'='*40}")
    display(df_table)
# Out:
# ========================================
#   TF-IDF — Cited Paper Retrieval
# ========================================
#                                                                        Target Paper  \
# 0   Functional polymeric coatings: thiol-maleimide ‘click’ chemistry as a powerf...
# 1                                     Smart sanitary hardware for health monitoring
# 2                 pH-Responsive nanofiber buttresses as local drug delivery devices
# 3   Dual-Functionalizable Hydrogel Coatings: Enabling Redox-Responsive Targeted ...
# 4   Redox-responsive micellar nanoparticles using benzothiazole-disulfide termin...
# 5                                New Perspectives in Photocatalytic Water Treatment
# 6   Search for cascade decays of charged sleptons and sneutrinos in final states...
# 7   High-resolution <i>P</i>-wave tomography of the 1999 Izmit and Düzce earthqu...
# 8                               An Overview of the CMS High Granularity Calorimeter
# 9   Photo‐magnetic imaging: a new functional imaging modality for more accurate ...
# 10                                                     AI-Based Metamaterial Design
# 11  Redox-Responsive “Catch and Release” Cryogels: A Versatile Platform for Capt...
# 12  Using graph neural networks to reconstruct charged pion showers in the CMS H...
# 13                                               Quo vadis artificial intelligence?
# 14  3D-Engineered Muscle Tissue as a Wireless Sensor: AntennAlive [Bioelectromag...
# 15  Influence of Sulfur Loading on Lithium‐Sulfur Battery Performance for Differ...
# 16  Biodegradable Implant Antenna Utilized for Real-Time Sensing Through Genetic...
# 17  Shape Fidelity Evaluation of Alginate-Based Hydrogels through Extrusion-Base...
# 18  Electrochemical Impedance Spectroscopy of Li‐S Batteries: Effect of Atomic V...
# 19                Implant Antenna Reconfigured by Engineered Skeletal Muscle Tissue
#
#     Cited Papers  Corpus Size  Top-1 Score  Top-1 Is Cited  Hits@3  Hits@10
# 0              7           57       0.3395            True       3        7
# 1              3           53       0.2074            True       3        3
# 2              5           55       0.2888           False       1        5
# 3             12           62       0.4125            True       3        9
# 4              3           53       0.5092            True       2        3
# 5              3           53       0.2156            True       2        3
# 6              3           53       0.1282            True       3        3
# 7              3           53       0.4869            True       3        3
# 8              3           53       0.3494            True       3        3
# 9              3           53       0.5346            True       3        3
# 10             7           57       0.4028            True       3        5
# 11             8           58       0.6021            True       3        8
# 12             4           54       0.5156            True       3        4
# 13             6           56       0.2018            True       2        5
# 14             3           53       0.5650            True       3        3
# 15             3           53       0.5762            True       3        3
# 16             6           56       0.5114            True       3        5
# 17             3           53       0.3224            True       2        2
# 18             5           55       0.5745            True       3        5
# 19             4           54       0.4106            True       2        4
# ========================================
#   BM25 — Cited Paper Retrieval
# ========================================
#                                                                        Target Paper  \
# 0   Functional polymeric coatings: thiol-maleimide ‘click’ chemistry as a powerf...
# 1                                     Smart sanitary hardware for health monitoring
# 2                 pH-Responsive nanofiber buttresses as local drug delivery devices
# 3   Dual-Functionalizable Hydrogel Coatings: Enabling Redox-Responsive Targeted ...
# 4   Redox-responsive micellar nanoparticles using benzothiazole-disulfide termin...
# 5                                New Perspectives in Photocatalytic Water Treatment
# 6   Search for cascade decays of charged sleptons and sneutrinos in final states...
# 7   High-resolution <i>P</i>-wave tomography of the 1999 Izmit and Düzce earthqu...
# 8                               An Overview of the CMS High Granularity Calorimeter
# 9   Photo‐magnetic imaging: a new functional imaging modality for more accurate ...
# 10                                                     AI-Based Metamaterial Design
# 11  Redox-Responsive “Catch and Release” Cryogels: A Versatile Platform for Capt...
# 12  Using graph neural networks to reconstruct charged pion showers in the CMS H...
# 13                                               Quo vadis artificial intelligence?
# 14  3D-Engineered Muscle Tissue as a Wireless Sensor: AntennAlive [Bioelectromag...
# 15  Influence of Sulfur Loading on Lithium‐Sulfur Battery Performance for Differ...
# 16  Biodegradable Implant Antenna Utilized for Real-Time Sensing Through Genetic...
# 17  Shape Fidelity Evaluation of Alginate-Based Hydrogels through Extrusion-Base...
# 18  Electrochemical Impedance Spectroscopy of Li‐S Batteries: Effect of Atomic V...
# 19                Implant Antenna Reconfigured by Engineered Skeletal Muscle Tissue
#
#     Cited Papers  Corpus Size  Top-1 Score  Top-1 Is Cited  Hits@3  Hits@10
# 0              7           57       0.6893            True       3        6
# 1              3           53       0.7331            True       2        3
# 2              5           55       0.6581           False       2        3
# 3             12           62       0.7536            True       3        6
# 4              3           53       0.8426            True       3        3
# 5              3           53       0.7903            True       2        3
# 6              3           53       0.7663            True       3        3
# 7              3           53       0.7168            True       3        3
# 8              3           53       0.7103            True       3        3
# 9              3           53       0.7698            True       3        3
# 10             7           57       0.7013            True       3        4
# 11             8           58       0.7966            True       3        5
# 12             4           54       0.7276            True       3        4
# 13             6           56       0.5997            True       2        4
# 14             3           53       0.7559            True       3        3
# 15             3           53       0.8026            True       3        3
# 16             6           56       0.8072            True       3        5
# 17             3           53       0.7072            True       2        2
# 18             5           55       0.7485            True       3        5
# 19             4           54       0.7183            True       3        4
# ========================================
#   MiniLM — Cited Paper Retrieval
# ========================================
#                                                                        Target Paper  \
# 0   Functional polymeric coatings: thiol-maleimide ‘click’ chemistry as a powerf...
# 1                                     Smart sanitary hardware for health monitoring
# 2                 pH-Responsive nanofiber buttresses as local drug delivery devices
# 3   Dual-Functionalizable Hydrogel Coatings: Enabling Redox-Responsive Targeted ...
# 4   Redox-responsive micellar nanoparticles using benzothiazole-disulfide termin...
# 5                                New Perspectives in Photocatalytic Water Treatment
# 6   Search for cascade decays of charged sleptons and sneutrinos in final states...
# 7   High-resolution <i>P</i>-wave tomography of the 1999 Izmit and Düzce earthqu...
# 8                               An Overview of the CMS High Granularity Calorimeter
# 9   Photo‐magnetic imaging: a new functional imaging modality for more accurate ...
# 10                                                     AI-Based Metamaterial Design
# 11  Redox-Responsive “Catch and Release” Cryogels: A Versatile Platform for Capt...
# 12  Using graph neural networks to reconstruct charged pion showers in the CMS H...
# 13                                               Quo vadis artificial intelligence?
# 14  3D-Engineered Muscle Tissue as a Wireless Sensor: AntennAlive [Bioelectromag...
# 15  Influence of Sulfur Loading on Lithium‐Sulfur Battery Performance for Differ...
# 16  Biodegradable Implant Antenna Utilized for Real-Time Sensing Through Genetic...
# 17  Shape Fidelity Evaluation of Alginate-Based Hydrogels through Extrusion-Base...
# 18  Electrochemical Impedance Spectroscopy of Li‐S Batteries: Effect of Atomic V...
# 19                Implant Antenna Reconfigured by Engineered Skeletal Muscle Tissue
#
#     Cited Papers  Corpus Size  Top-1 Score  Top-1 Is Cited  Hits@3  Hits@10
# 0              7           57       0.7031            True       3        7
# 1              3           53       0.6525            True       3        3
# 2              5           55       0.6022           False       2        5
# 3             12           62       0.6864            True       3       10
# 4              3           53       0.6971            True       3        3
# 5              3           53       0.6003            True       3        3
# 6              3           53       0.5797            True       3        3
# 7              3           53       0.8178            True       1        3
# 8              3           53       0.7905            True       3        3
# 9              3           53       0.8491            True       3        3
# 10             7           57       0.5438            True       3        6
# 11             8           58       0.8542            True       3        8
# 12             4           54       0.5246            True       3        4
# 13             6           56       0.5703            True       2        4
# 14             3           53       0.8869            True       3        3
# 15             3           53       0.8313            True       3        3
# 16             6           56       0.8725            True       3        6
# 17             3           53       0.7256            True       2        2
# 18             5           55       0.8208            True       2        5
# 19             4           54       0.7891            True       3        4

# %%
# --- Task 3: Visualization (ALL methods) ---
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# --- Plot 1: Same-Author avg rank per method ---
ax = axes[0]
sa_avg_ranks_per_method = {}
for method in TASK3_METHODS:
    ranks = []
    for res in task3a_results[method]:
        sa_ranks = [r + 1 for r, (_, sa, _) in enumerate(res['ranked']) if sa]
        ranks.append(np.mean(sa_ranks) if sa_ranks else res['n_corpus'])
    sa_avg_ranks_per_method[method] = np.mean(ranks)

# Add random baseline
avg_corpus = np.mean([r['n_corpus'] for r in task3a_results[TASK3_METHODS[0]]])
labels = [method_labels[m] for m in TASK3_METHODS] + ['Random\nBaseline']
heights = [sa_avg_ranks_per_method[m] for m in TASK3_METHODS] + [avg_corpus / 2]
bar_colors = [colors[m] for m in TASK3_METHODS] + ['#95a5a6']

bars = ax.bar(range(len(labels)), heights, color=bar_colors, edgecolor='white', linewidth=1.5)
ax.set_xticks(range(len(labels)))
ax.set_xticklabels(labels, fontsize=9, rotation=15)
ax.set_ylabel('Average Rank (lower = better)')
ax.set_title('3a: Same-Author Paper Ranking')
for bar, val in zip(bars, heights):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.3,
            f'{val:.1f}', ha='center', va='bottom', fontweight='bold', fontsize=9)
ax.grid(True, alpha=0.3, axis='y')

# --- Plot 2: Cited Paper avg rank per method ---
ax = axes[1]
cited_avg_ranks_per_method = {}
for method in TASK3_METHODS:
    ranks = []
    for res in task3b_results[method]:
        cited_ranks = [r + 1 for r, (_, ic, _) in enumerate(res['ranked']) if ic]
        ranks.append(np.mean(cited_ranks) if cited_ranks else res['n_corpus'])
    cited_avg_ranks_per_method[method] = np.mean(ranks)

avg_corpus_3b = np.mean([r['n_corpus'] for r in task3b_results[TASK3_METHODS[0]]])
labels = [method_labels[m] for m in TASK3_METHODS] + ['Random\nBaseline']
heights = [cited_avg_ranks_per_method[m] for m in TASK3_METHODS] + [avg_corpus_3b / 2]
bar_colors = [colors[m] for m in TASK3_METHODS] + ['#95a5a6']

bars = ax.bar(range(len(labels)), heights, color=bar_colors, edgecolor='white', linewidth=1.5)
ax.set_xticks(range(len(labels)))
ax.set_xticklabels(labels, fontsize=9, rotation=15)
ax.set_ylabel('Average Rank (lower = better)')
ax.set_title('3b: Cited Paper Ranking')
for bar, val in zip(bars, heights):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.3,
            f'{val:.1f}', ha='center', va='bottom', fontweight='bold', fontsize=9)
ax.grid(True, alpha=0.3, axis='y')

# %% [markdown]
# ## Task 4 — Field Ablation Study
#
# Evaluate how different text field combinations affect retrieval quality. The `build_text()` function supports a `fields` parameter — here we test which fields contribute most to performance.
#
# **Combinations tested:**
# - `title` only
# - `abstract` only
# - `title + abstract`
# - `title + abstract + concepts` (default)

# %%
# --- Task 4: Field Ablation ---
import os
import pickle

CACHE_DIR = globals().get("CACHE_DIR", "data/results_cache")
os.makedirs(CACHE_DIR, exist_ok=True)

FIELD_COMBOS = [
    (('title',), 'Title only'),
    (('abstract',), 'Abstract only'),
    (('title', 'abstract'), 'Title + Abstract'),
    (('title', 'abstract', 'concepts'), 'Title + Abstract + Concepts'),
]
ABLATION_METHODS = ['tfidf', 'specter2']  # test with one sparse and one dense

cache_ablation = os.path.join(CACHE_DIR, "ablation_results.pkl")

if os.path.exists(cache_ablation):
    print(f"Loading cached ablation results from {cache_ablation}")
    with open(cache_ablation, 'rb') as f:
        ablation_results = pickle.load(f)
else:
    ablation_results = {}
    for fields, label in FIELD_COMBOS:
        print(f"\n{'='*60}")
        print(f"Fields: {label}")
        print(f"{'='*60}")
        
        # Rebuild text for full corpus with these fields
        corpus_texts_abl = [build_text(row, fields=fields) for _, row in boun_df_full.iterrows()]
        # Rebuild query texts
        bench_queries_abl = []
        for pair in benchmark_pairs:
            query = pair['query']
            parts = []
            if 'title' in fields and query.get('title'):
                parts.append(query['title'])
            if 'abstract' in fields and query.get('abstract'):
                parts.append(query['abstract'])
            bench_queries_abl.append(' '.join(parts) if parts else query.get('title', ''))
        
        for method in ABLATION_METHODS:
            print(f"  Evaluating {method_labels[method]}...")
            # We need a temporary df with correct 'id' column for evaluate_method
            result = evaluate_method(method, bench_queries_abl, bench_positive_ids,
                                     corpus_texts_abl, boun_df_full)
            ablation_results[(label, method)] = result
    
    with open(cache_ablation, 'wb') as f:
        pickle.dump(ablation_results, f)
    print(f"\nSaved ablation results to {cache_ablation}")

# Print ablation table
print(f"\n{'Fields':<30} {'Method':<12} {'MRR':>6} {'HR@5':>6} {'NDCG@5':>7} {'MAP@5':>6}")
print("─" * 72)
for fields, label in FIELD_COMBOS:
    for method in ABLATION_METHODS:
        r = ablation_results[(label, method)]
        print(f"{label:<30} {method_labels[method]:<12} {r['mrr']:>6.3f} {r['hit_rate'][5]:>6.3f} {r['ndcg'][5]:>7.3f} {r['map'][5]:>6.3f}")
# Out:
# Loading cached ablation results from data/results_cache/ablation_results.pkl
#
# Fields                         Method          MRR   HR@5  NDCG@5  MAP@5
# ────────────────────────────────────────────────────────────────────────
# Title only                     TF-IDF        0.139  0.220   0.096  0.068
# Title only                     SPECTER2      0.243  0.370   0.179  0.134
# Abstract only                  TF-IDF        0.179  0.300   0.134  0.096
# Abstract only                  SPECTER2      0.234  0.320   0.156  0.116
# Title + Abstract               TF-IDF        0.202  0.360   0.152  0.106
# Title + Abstract               SPECTER2      0.268  0.360   0.183  0.139
# Title + Abstract + Concepts    TF-IDF        0.248  0.390   0.192  0.145
# Title + Abstract + Concepts    SPECTER2      0.276  0.420   0.197  0.144

# %%
# --- Field Ablation Visualization ---
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for ax_idx, method in enumerate(ABLATION_METHODS):
    ax = axes[ax_idx]
    field_labels = [label for _, label in FIELD_COMBOS]
    mrr_vals = [ablation_results[(label, method)]['mrr'] for _, label in FIELD_COMBOS]
    hr5_vals = [ablation_results[(label, method)]['hit_rate'][5] for _, label in FIELD_COMBOS]
    
    x = np.arange(len(field_labels))
    width = 0.35
    bars1 = ax.bar(x - width/2, mrr_vals, width, label='MRR', color=colors[method], alpha=0.7)
    bars2 = ax.bar(x + width/2, hr5_vals, width, label='HR@5', color=colors[method], alpha=1.0)
    
    for bar, val in zip(bars1, mrr_vals):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.005,
                f'{val:.3f}', ha='center', va='bottom', fontsize=8)
    for bar, val in zip(bars2, hr5_vals):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.005,
                f'{val:.3f}', ha='center', va='bottom', fontsize=8)
    
    ax.set_xticks(x)
    ax.set_xticklabels(field_labels, fontsize=9, rotation=15)
    ax.set_ylabel('Score')
    ax.set_title(f'Field Ablation: {method_labels[method]}')
    ax.legend()
    ax.grid(True, alpha=0.3, axis='y')
    ax.set_ylim(0, max(max(mrr_vals), max(hr5_vals)) * 1.3 if max(mrr_vals + hr5_vals) > 0 else 1)

plt.tight_layout()
plt.savefig('eval_dataset/field_ablation.png', dpi=150, bbox_inches='tight')
plt.show()
print("Saved: eval_dataset/field_ablation.png")
# Out:
# Saved: eval_dataset/field_ablation.png
