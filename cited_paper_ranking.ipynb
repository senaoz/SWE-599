# %% [markdown]
# # Week 3: Cited Paper Ranking Dataset for Method Evaluation
#
# Constructs a cited paper ranking dataset using `cleaned/priority_followed.csv` to test how embedding methods prioritize true references over random distractors.
#
# **Pipeline:**
# 1. **Step 1** — Select 100 main papers (P_i) with 6–14 references from `cleaned/priority_followed.csv`
# 2. **Step 2** — Build per-P_i evaluation set: n positives (actual cited papers) + 2n negatives (random)
# 3. **Step 3** — Rank 3n candidates per method; compute hit rate in top-n
# 4. **Step 4** — Aggregate metrics: Hit Rate %, Precision@n, MRR, nDCG@n
#
# Caches:
# - Embeddings → `data/embeddings_cache/week3/`
# - Results → `data/results_cache/week3/`
# - Outputs → `eval_dataset/week3/`

# %%
import os
import json
import pickle
import hashlib
import time
import random
import ast
import math
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from rank_bm25 import BM25Okapi
from sentence_transformers import SentenceTransformer
import google.generativeai as genai
from dotenv import load_dotenv

load_dotenv()
genai.configure(api_key=os.getenv('GEMINI_API_KEY'))
print('Imports OK')
# Out:
# Imports OK

# %%
# ── Paths ──────────────────────────────────────────────────────────────────
FOLLOWED_CSV   = 'data/cleaned/priority_followed.csv'
PARSED_CACHE   = 'data/cleaned/priority_followed.pkl'
REFERENCE_WORKS_PKL = 'data/cleaned/openalex_reference_works_raw.pkl'
EMBED_CACHE    = 'data/embeddings_cache/week3'
RESULTS_CACHE  = 'data/results_cache/week3'
EVAL_DIR       = 'eval_dataset/week3'

# -- CONSTANTS --
MIN_REF_COUNT = 6
MAX_REF_COUNT = 14

for d in [EMBED_CACHE, RESULTS_CACHE, EVAL_DIR, 'data/cleaned']:
    os.makedirs(d, exist_ok=True)

RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

# Methods to evaluate
METHODS = ['bm25', 'tfidf', 'minilm', 'specter2','gemini'] # 'gemini', 'qwen',

from src.similarity import DEVICE, MAX_TEXT_CHARS, BATCH_SIZES, MODEL_MAP
print(f'Device: {DEVICE}')
# Out:
# Device: mps

# %%
import importlib
import src.text_utils as _text_utils
importlib.reload(_text_utils)
from src.text_utils import safe_parse, extract_concept_names, build_text
from src.similarity import (
    DEVICE, MAX_TEXT_CHARS, BATCH_SIZES, _MODEL_CACHE,
    _corpus_hash, _cache_path, _get_model, _truncate_texts,
)

print('Utility functions OK')
# Out:
# Utility functions OK

# %%
from src.similarity import bm25_similarity, tfidf_similarity, sentence_embedding_similarity, gemini_rank_candidates

print('Similarity functions OK')
# Out:
# Similarity functions OK

# %%
fetched_works_df = pd.DataFrame()

if os.path.exists(REFERENCE_WORKS_PKL):
        fetched_works_df = pickle.load(open(REFERENCE_WORKS_PKL, 'rb'))
else:
    print(f'No REFERENCE_WORKS_PKL found')

# ── Load priority_followed data ────────────────────────────────────────────

if os.path.exists(PARSED_CACHE):
    print('Loading from parsed cache...')
    with open(PARSED_CACHE, 'rb') as f:
        followed_df = pickle.load(f)
else:
    print('Parsing priority_followed.csv (first time, may be slow)...')
    followed_df = pd.read_csv(FOLLOWED_CSV, low_memory=False)
    list_cols = ['referenced_works', 'related_works', 'concepts', 'keywords',
                 'authorships', 'topics', 'institutions']
    for col in list_cols:
        if col in followed_df.columns:
            followed_df[col] = followed_df[col].apply(safe_parse)
    with open(PARSED_CACHE, 'wb') as f:
        pickle.dump(followed_df, f)
    print('Saved to parsed cache.')

followed_df['text'] = followed_df.apply(lambda r: build_text(r), axis=1)

# merge followed_df and fetched_works
extended_followed_df = pd.concat([followed_df, fetched_works_df])

# Build id → row index lookup for fast reference resolution
id_to_idx = {row['id']: i for i, row in extended_followed_df.iterrows()}

print(f'Loaded {len(followed_df):,} papers')
print(f'Columns with ref counts: referenced_works_count sample:', 
      followed_df['referenced_works_count'].dropna().describe())
# Out:
# Loading from parsed cache...
# Loaded 9,946 papers
# Columns with ref counts: referenced_works_count sample: count    9946.000000
# mean       80.145184
# std       116.013381
# min         0.000000
# 25%        39.000000
# 50%        59.000000
# 75%        87.000000
# max      4428.000000
# Name: referenced_works_count, dtype: float64

# %%
id_to_idx
# Out:
# {'https://openalex.org/W1498342204': 367,
#  'https://openalex.org/W4406633044': 6720,
#  'https://openalex.org/W4413972333': 6203,
#  'https://openalex.org/W4410611457': 965,
#  'https://openalex.org/W4406426717': 6910,
#  'https://openalex.org/W4408806526': 6663,
#  'https://openalex.org/W4410594697': 3866,
#  'https://openalex.org/W4407142724': 3008,
#  'https://openalex.org/W4411413252': 9828,
#  'https://openalex.org/W4408105654': 7381,
#  'https://openalex.org/W4409283601': 6262,
#  'https://openalex.org/W4409530112': 1482,
#  'https://openalex.org/W4415091769': 7933,
#  'https://openalex.org/W4409483458': 1627,
#  'https://openalex.org/W4411407753': 7310,
#  'https://openalex.org/W4407173730': 4653,
#  'https://openalex.org/W2932930913': 804,
#  'https://openalex.org/W4394029306': 583,
#  'https://openalex.org/W4411068410': 9192,
#  'https://openalex.org/W4410396192': 5692,
#  'https://openalex.org/W4406440058': 1429,
#  'https://openalex.org/W4410636511': 4414,
#  'https://openalex.org/W4409293301': 5465,
#  'https://openalex.org/W4406152279': 1167,
#  'https://openalex.org/W4406208390': 8714,
#  'https://openalex.org/W4406550554': 9610,
#  'https://openalex.org/W4409878505': 6845,
#  'https://openalex.org/W4409669259': 5885,
#  'https://openalex.org/W4406333986': 4904,
#  'https://openalex.org/W4394029502': 4903,
#  'https://openalex.org/W4391428867': 9095,
#  'https://openalex.org/W4390880545': 9094,
#  'https://openalex.org/W4391717697': 2609,
#  'https://openalex.org/W4390741838': 5643,
#  'https://openalex.org/W4396955712': 5644,
#  'https://openalex.org/W4396955535': 817,
#  'https://openalex.org/W4393145114': 4874,
#  'https://openalex.org/W4392505481': 6540,
#  'https://openalex.org/W4390967609': 8996,
#  'https://openalex.org/W4400047099': 8997,
#  'https://openalex.org/W4400734098': 8998,
#  'https://openalex.org/W4402890475': 8999,
#  'https://openalex.org/W4398182689': 757,
#  'https://openalex.org/W4392500048': 4713,
#  'https://openalex.org/W4392977246': 2816,
#  'https://openalex.org/W4396783545': 2817,
#  'https://openalex.org/W4396732497': 4118,
#  'https://openalex.org/W4394595642': 4195,
#  'https://openalex.org/W4404531735': 742,
#  'https://openalex.org/W4391616565': 6481,
#  'https://openalex.org/W4393238683': 4714,
#  'https://openalex.org/W4390928581': 4117,
#  'https://openalex.org/W4390750892': 5691,
#  'https://openalex.org/W4390497397': 6480,
#  'https://openalex.org/W4392199370': 2841,
#  'https://openalex.org/W4396850943': 4196,
#  'https://openalex.org/W4399543291': 6770,
#  'https://openalex.org/W4391232927': 1046,
#  'https://openalex.org/W4392986561': 5601,
#  'https://openalex.org/W2101841715': 4142,
#  'https://openalex.org/W4392193048': 989,
#  'https://openalex.org/W4403062913': 2636,
#  'https://openalex.org/W4402891655': 6719,
#  'https://openalex.org/W4392947532': 980,
#  'https://openalex.org/W4392155415': 1005,
#  'https://openalex.org/W4403008105': 1006,
#  'https://openalex.org/W4399430129': 3529,
#  'https://openalex.org/W4390570560': 3528,
#  'https://openalex.org/W4399567465': 6662,
#  'https://openalex.org/W4396768342': 6661,
#  'https://openalex.org/W4392367298': 6660,
#  'https://openalex.org/W4390659102': 8713,
#  'https://openalex.org/W4399567248': 2870,
#  'https://openalex.org/W4401751612': 8817,
#  'https://openalex.org/W4402350163': 8818,
#  'https://openalex.org/W4392162030': 6767,
#  'https://openalex.org/W4390751412': 8911,
#  'https://openalex.org/W4392347821': 6768,
#  'https://openalex.org/W4399803265': 8912,
#  'https://openalex.org/W4401441260': 8913,
#  'https://openalex.org/W4401947164': 8914,
#  'https://openalex.org/W4399012115': 6769,
#  'https://openalex.org/W4391067309': 843,
#  'https://openalex.org/W4394577548': 4194,
#  'https://openalex.org/W4392153984': 6659,
#  'https://openalex.org/W4391170193': 5151,
#  'https://openalex.org/W4391876619': 654,
#  'https://openalex.org/W4390745503': 4309,
#  'https://openalex.org/W4399940216': 9514,
#  'https://openalex.org/W4391091522': 9513,
#  'https://openalex.org/W4390606426': 9512,
#  'https://openalex.org/W4400770247': 3043,
#  'https://openalex.org/W4399940463': 6202,
#  'https://openalex.org/W4391221150': 3022,
#  'https://openalex.org/W4399394788': 9400,
#  'https://openalex.org/W4396918865': 4628,
#  'https://openalex.org/W4394808357': 9399,
#  'https://openalex.org/W4394689630': 9398,
#  'https://openalex.org/W4392295948': 9397,
#  'https://openalex.org/W4391823713': 9396,
#  'https://openalex.org/W4392947521': 459,
#  'https://openalex.org/W4392298082': 6258,
#  'https://openalex.org/W4400831227': 9515,
#  'https://openalex.org/W4402754225': 9516,
#  'https://openalex.org/W4393397034': 4339,
#  'https://openalex.org/W4400948944': 4576,
#  'https://openalex.org/W4398133596': 4575,
#  'https://openalex.org/W4391629219': 4574,
#  'https://openalex.org/W4390706816': 5788,
#  'https://openalex.org/W4393902863': 5789,
#  'https://openalex.org/W4396566498': 5790,
#  'https://openalex.org/W4399118709': 5791,
#  'https://openalex.org/W4403337227': 3380,
#  'https://openalex.org/W4394580100': 3379,
#  'https://openalex.org/W4389485451': 3378,
#  'https://openalex.org/W4365211529': 3375,
#  'https://openalex.org/W4401815221': 6111,
#  'https://openalex.org/W4391503645': 6110,
#  'https://openalex.org/W4391530977': 9605,
#  'https://openalex.org/W4393234811': 6259,
#  'https://openalex.org/W4396939189': 4629,
#  'https://openalex.org/W4393397203': 2887,
#  'https://openalex.org/W4400539753': 9190,
#  'https://openalex.org/W4365211514': 4686,
#  'https://openalex.org/W4394998531': 4255,
#  'https://openalex.org/W4393948739': 4254,
#  'https://openalex.org/W4392300910': 6366,
#  'https://openalex.org/W4392242824': 4690,
#  'https://openalex.org/W4401419219': 9191,
#  'https://openalex.org/W4400324827': 9189,
#  'https://openalex.org/W4399437507': 6260,
#  'https://openalex.org/W4399860545': 9188,
#  'https://openalex.org/W4396733463': 2584,
#  'https://openalex.org/W4394674699': 9187,
#  'https://openalex.org/W4390919221': 9186,
#  'https://openalex.org/W4400881081': 623,
#  'https://openalex.org/W4390535733': 9183,
#  'https://openalex.org/W4391380867': 2942,
#  'https://openalex.org/W4401191299': 6322,
#  'https://openalex.org/W4390579529': 6321,
#  'https://openalex.org/W4390940980': 2956,
#  'https://openalex.org/W4396673676': 2957,
#  'https://openalex.org/W4395039984': 9291,
#  'https://openalex.org/W4402727529': 9292,
#  'https://openalex.org/W4405031167': 4652,
#  'https://openalex.org/W3105850678': 494,
#  'https://openalex.org/W4393153087': 4287,
#  'https://openalex.org/W4396699590': 4288,
#  'https://openalex.org/W4402066678': 4651,
#  'https://openalex.org/W4394727812': 4650,
#  'https://openalex.org/W4394694527': 5741,
#  'https://openalex.org/W3124388369': 4297,
#  'https://openalex.org/W3122715243': 5758,
#  'https://openalex.org/W4404797546': 6261,
#  'https://openalex.org/W4394964969': 4875,
#  'https://openalex.org/W4404880964': 3555,
#  'https://openalex.org/W4399779937': 8632,
#  'https://openalex.org/W4403813762': 1675,
#  'https://openalex.org/W4396862222': 7309,
#  'https://openalex.org/W4391444554': 3696,
#  'https://openalex.org/W4404470920': 5152,
#  'https://openalex.org/W4402135476': 7932,
#  'https://openalex.org/W4401819803': 7931,
#  'https://openalex.org/W4399881058': 7930,
#  'https://openalex.org/W4399335588': 7929,
#  'https://openalex.org/W4392553965': 1738,
#  'https://openalex.org/W4398209670': 7928,
#  'https://openalex.org/W4399068599': 7378,
#  'https://openalex.org/W4399512636': 7379,
#  'https://openalex.org/W4401694862': 7380,
#  'https://openalex.org/W4404793799': 3886,
#  'https://openalex.org/W4392367648': 2126,
#  'https://openalex.org/W4391135337': 1614,
#  'https://openalex.org/W2408908326': 8006,
#  'https://openalex.org/W4390670214': 5416,
#  'https://openalex.org/W4403405969': 5114,
#  'https://openalex.org/W4402769322': 7248,
#  'https://openalex.org/W4399746595': 7247,
#  'https://openalex.org/W4399521812': 3942,
#  'https://openalex.org/W4403062911': 1560,
#  'https://openalex.org/W4400800926': 1547,
#  'https://openalex.org/W4391925503': 1526,
#  'https://openalex.org/W4392036900': 8102,
#  'https://openalex.org/W4393191344': 8103,
#  'https://openalex.org/W4394580205': 8104,
#  'https://openalex.org/W4394713438': 8105,
#  'https://openalex.org/W4404928582': 8106,
#  'https://openalex.org/W4405220977': 8107,
#  'https://openalex.org/W4392242084': 3667,
#  'https://openalex.org/W4404755712': 3722,
#  'https://openalex.org/W4392028279': 5193,
#  'https://openalex.org/W4391738483': 6842,
#  'https://openalex.org/W4392615009': 7703,
#  'https://openalex.org/W4399322386': 7771,
#  'https://openalex.org/W4396746727': 7770,
#  'https://openalex.org/W4391027505': 7769,
#  'https://openalex.org/W4391636383': 7534,
#  'https://openalex.org/W4401517658': 7535,
#  'https://openalex.org/W4392986196': 7704,
#  'https://openalex.org/W4392376294': 1878,
#  'https://openalex.org/W4403217241': 3865,
#  'https://openalex.org/W4396544292': 5329,
#  'https://openalex.org/W4391468387': 1888,
#  'https://openalex.org/W4399528455': 1904,
#  'https://openalex.org/W4404350033': 7616,
#  'https://openalex.org/W4394687744': 7613,
#  'https://openalex.org/W4401640776': 7614,
#  'https://openalex.org/W4392681182': 3747,
#  'https://openalex.org/W3150080251': 7495,
#  'https://openalex.org/W4395469472': 2067,
#  'https://openalex.org/W4392762752': 1801,
#  'https://openalex.org/W4404595545': 7448,
#  'https://openalex.org/W4392691406': 7447,
#  'https://openalex.org/W4390907984': 7446,
#  'https://openalex.org/W4402221345': 5194,
#  'https://openalex.org/W4399301840': 2092,
#  'https://openalex.org/W4391062880': 1766,
#  'https://openalex.org/W4396531762': 7844,
#  'https://openalex.org/W4396917273': 7845,
#  'https://openalex.org/W4392015766': 1758,
#  'https://openalex.org/W4399803382': 7846,
#  'https://openalex.org/W4401560172': 7847,
#  'https://openalex.org/W4390605189': 1753,
#  'https://openalex.org/W4392984771': 3864,
#  'https://openalex.org/W4404467861': 7190,
#  'https://openalex.org/W4391617219': 7189,
#  'https://openalex.org/W4396780652': 5074,
#  'https://openalex.org/W4391697048': 8478,
#  'https://openalex.org/W4390741291': 6907,
#  'https://openalex.org/W4399848783': 6908,
#  'https://openalex.org/W4400126525': 6909,
#  'https://openalex.org/W4391849830': 4931,
#  'https://openalex.org/W4402715971': 8480,
#  'https://openalex.org/W4392850630': 8479,
#  'https://openalex.org/W4392200417': 4960,
#  'https://openalex.org/W4390588003': 8179,
#  'https://openalex.org/W4402474910': 4961,
#  'https://openalex.org/W4399518864': 4047,
#  'https://openalex.org/W4392984046': 2461,
#  'https://openalex.org/W4394998532': 1256,
#  'https://openalex.org/W4391424688': 2449,
#  'https://openalex.org/W4400192348': 5507,
#  'https://openalex.org/W4392515871': 4073,
#  'https://openalex.org/W4404535307': 4074,
#  'https://openalex.org/W4404349982': 2521,
#  'https://openalex.org/W4400112692': 8559,
#  'https://openalex.org/W4402261051': 8560,
#  'https://openalex.org/W4392768687': 2534,
#  'https://openalex.org/W4380551319': 5553,
#  'https://openalex.org/W4390940921': 4902,
#  'https://openalex.org/W4390986771': 5556,
#  'https://openalex.org/W4399119006': 5557,
#  'https://openalex.org/W4399292897': 5558,
#  'https://openalex.org/W4392563703': 9607,
#  'https://openalex.org/W4392611940': 3554,
#  'https://openalex.org/W4390919342': 4095,
#  'https://openalex.org/W4396544387': 6844,
#  'https://openalex.org/W4393037494': 6843,
#  'https://openalex.org/W4395112138': 2428,
#  'https://openalex.org/W4392915605': 8398,
#  'https://openalex.org/W4394728313': 2412,
#  'https://openalex.org/W4392552172': 5035,
#  'https://openalex.org/W4391809311': 8180,
#  'https://openalex.org/W4392503764': 8181,
#  'https://openalex.org/W4390629178': 5073,
#  'https://openalex.org/W4405183524': 1440,
#  'https://openalex.org/W4394576672': 1428,
#  'https://openalex.org/W4401420347': 5464,
#  'https://openalex.org/W4400083776': 7115,
#  'https://openalex.org/W4392773006': 7114,
#  'https://openalex.org/W4391530715': 2340,
#  'https://openalex.org/W4390575634': 8247,
#  'https://openalex.org/W4390793875': 8248,
#  'https://openalex.org/W4393043838': 8249,
#  'https://openalex.org/W4393335480': 8250,
#  'https://openalex.org/W4392699774': 5036,
#  'https://openalex.org/W4392383011': 5034,
#  'https://openalex.org/W4391934251': 7035,
#  'https://openalex.org/W4392739873': 2376,
#  'https://openalex.org/W4402220065': 2384,
#  'https://openalex.org/W4391616577': 8321,
#  'https://openalex.org/W4396803203': 8322,
#  'https://openalex.org/W4401305294': 8323,
#  'https://openalex.org/W4401585036': 2404,
#  'https://openalex.org/W4391383681': 5506,
#  'https://openalex.org/W4391836235': 1315,
#  'https://openalex.org/W4390487565': 4023,
#  'https://openalex.org/W4394745423': 4024,
#  'https://openalex.org/W4396895148': 4025,
#  'https://openalex.org/W4404470077': 3608,
#  'https://openalex.org/W4400580347': 7037,
#  'https://openalex.org/W4391992243': 7036,
#  'https://openalex.org/W4392378328': 9606,
#  'https://openalex.org/W4401751645': 7615,
#  'https://openalex.org/W4391105189': 9948,
#  'https://openalex.org/W4400473741': 9713,
#  'https://openalex.org/W4394857110': 208,
#  'https://openalex.org/W4403102965': 3180,
#  'https://openalex.org/W4396721167': 9,
#  'https://openalex.org/W4400416998': 5828,
#  'https://openalex.org/W4391462401': 6020,
#  'https://openalex.org/W4400089962': 142,
#  'https://openalex.org/W4403680143': 3315,
#  'https://openalex.org/W4399394397': 9711,
#  'https://openalex.org/W4391025098': 6019,
#  'https://openalex.org/W4402634925': 4360,
#  'https://openalex.org/W4398781461': 265,
#  'https://openalex.org/W4390707638': 6018,
#  'https://openalex.org/W4392850483': 9608,
#  'https://openalex.org/W4392304105': 151,
#  'https://openalex.org/W4391494845': 3333,
#  'https://openalex.org/W4390690905': 5935,
#  'https://openalex.org/W4393411172': 5883,
#  'https://openalex.org/W4404343451': 5884,
#  'https://openalex.org/W4399743225': 3334,
#  'https://openalex.org/W4394859735': 4514,
#  'https://openalex.org/W4398195210': 9951,
#  'https://openalex.org/W4393097303': 9950,
#  'https://openalex.org/W4392032200': 9949,
#  'https://openalex.org/W4402125701': 9714,
#  'https://openalex.org/W4391215170': 6059,
#  'https://openalex.org/W4396667339': 4515,
#  'https://openalex.org/W4402329561': 3215,
#  'https://openalex.org/W4391403992': 3354,
#  'https://openalex.org/W4402008181': 3335,
#  'https://openalex.org/W3196836501': 197,
#  'https://openalex.org/W4391418258': 3179,
#  'https://openalex.org/W4399428914': 9712,
#  'https://openalex.org/W4392298786': 9709,
#  'https://openalex.org/W4400880443': 3126,
#  'https://openalex.org/W4392956046': 9609,
#  'https://openalex.org/W4396780205': 3125,
#  'https://openalex.org/W4402827768': 9827,
#  'https://openalex.org/W4399688201': 3247,
#  'https://openalex.org/W4401397240': 6061,
#  'https://openalex.org/W4391655333': 6060,
#  'https://openalex.org/W4399807124': 9826,
#  'https://openalex.org/W4391563878': 9707,
#  'https://openalex.org/W4396862429': 9710,
#  'https://openalex.org/W4391649568': 51,
#  'https://openalex.org/W4390675414': 9825,
#  'https://openalex.org/W4392092898': 9708,
#  'https://openalex.org/W4388858772': 8476,
#  'https://openalex.org/W4361003486': 4045,
#  'https://openalex.org/W4382520315': 6966,
#  'https://openalex.org/W4389670715': 6968,
#  'https://openalex.org/W4386530351': 9823,
#  'https://openalex.org/W4389861936': 4046,
#  'https://openalex.org/W4390227755': 9824,
#  'https://openalex.org/W4388494498': 6967,
#  'https://openalex.org/W4389391124': 1255,
#  'https://openalex.org/W4390874306': 6969,
#  'https://openalex.org/W4322757054': 4412,
#  'https://openalex.org/W4366974898': 4413,
#  'https://openalex.org/W4386725477': 2460,
#  'https://openalex.org/W4386851581': 3590,
#  'https://openalex.org/W4387077861': 3214,
#  'https://openalex.org/W4389113716': 2448,
#  'https://openalex.org/W4317213523': 4511,
#  'https://openalex.org/W4385394492': 1186,
#  'https://openalex.org/W4387144847': 2427,
#  'https://openalex.org/W4383265707': 9822,
#  'https://openalex.org/W4378374030': 9821,
#  'https://openalex.org/W4322739688': 5551,
#  'https://openalex.org/W4367841521': 3213,
#  'https://openalex.org/W4322622390': 5550,
#  'https://openalex.org/W4388706033': 8396,
#  'https://openalex.org/W4323659943': 1214,
#  'https://openalex.org/W4389947931': 8477,
#  'https://openalex.org/W4387036470': 1215,
#  'https://openalex.org/W4321490900': 1208,
#  'https://openalex.org/W4380490520': 8474,
#  'https://openalex.org/W4324141237': 8473,
#  'https://openalex.org/W4319440743': 4957,
#  'https://openalex.org/W4321471227': 8472,
#  'https://openalex.org/W4385839624': 1203,
#  'https://openalex.org/W4313558986': 5549,
#  'https://openalex.org/W4386071610': 3579,
#  'https://openalex.org/W4320716674': 3578,
#  'https://openalex.org/W4384816777': 8475,
#  'https://openalex.org/W4313893014': 3588,
#  'https://openalex.org/W4380357923': 3589,
#  'https://openalex.org/W4389672456': 1232,
#  'https://openalex.org/W4384523451': 2496,
#  'https://openalex.org/W4388616071': 2497,
#  'https://openalex.org/W4322492266': 4958,
#  'https://openalex.org/W4362608384': 4959,
#  'https://openalex.org/W4380791793': 1237,
#  'https://openalex.org/W4315489693': 4411,
#  'https://openalex.org/W4313455446': 6964,
#  'https://openalex.org/W4367857311': 2467,
#  'https://openalex.org/W4322495337': 6965,
#  'https://openalex.org/W4389178822': 8397,
#  'https://openalex.org/W4389367121': 293,
#  'https://openalex.org/W4386824148': 8395,
#  'https://openalex.org/W4317567028': 3630,
#  'https://openalex.org/W4353055381': 5032,
#  'https://openalex.org/W4315631901': 2358,
#  'https://openalex.org/W4384024410': 2359,
#  'https://openalex.org/W4366166156': 4002,
#  'https://openalex.org/W4361000553': 1364,
#  'https://openalex.org/W3146796711': 2368,
#  'https://openalex.org/W4386091044': 1354,
#  'https://openalex.org/W4385691296': 8394,
#  'https://openalex.org/W4381487086': 1349,
#  'https://openalex.org/W4353056919': 1348,
#  'https://openalex.org/W4313593593': 8315,
#  'https://openalex.org/W4319160895': 8316,
#  'https://openalex.org/W4323306527': 8317,
#  'https://openalex.org/W4367056813': 8318,
#  'https://openalex.org/W4378952025': 5033,
#  'https://openalex.org/W4387966260': 3332,
#  'https://openalex.org/W4366984620': 3331,
#  'https://openalex.org/W4385430679': 1382,
#  'https://openalex.org/W4388627063': 1383,
#  'https://openalex.org/W4362546931': 1385,
#  'https://openalex.org/W4321380998': 7102,
#  'https://openalex.org/W4364356934': 7103,
#  'https://openalex.org/W4367848890': 7104,
#  'https://openalex.org/W4375854036': 7105,
#  'https://openalex.org/W4378977486': 7106,
#  'https://openalex.org/W4383314869': 7107,
#  'https://openalex.org/W4385650986': 7108,
#  'https://openalex.org/W4385658384': 7109,
#  'https://openalex.org/W4388965956': 7110,
#  'https://openalex.org/W4389045706': 7111,
#  'https://openalex.org/W4390872653': 4474,
#  'https://openalex.org/W4386741066': 8319,
#  'https://openalex.org/W4381953540': 2383,
#  'https://openalex.org/W4389546039': 8320,
#  'https://openalex.org/W4385618104': 7031,
#  'https://openalex.org/W4362735831': 2426,
#  'https://openalex.org/W4367055754': 8393,
#  'https://openalex.org/W4324305901': 8392,
#  'https://openalex.org/W4322489988': 8391,
#  'https://openalex.org/W4315797449': 8390,
#  'https://openalex.org/W4318767763': 7025,
#  'https://openalex.org/W4322616570': 7026,
#  'https://openalex.org/W4321790088': 1295,
#  'https://openalex.org/W4363678746': 7027,
#  'https://openalex.org/W4376609014': 7028,
#  'https://openalex.org/W4385803938': 4070,
#  'https://openalex.org/W4377164289': 7029,
#  'https://openalex.org/W4321760728': 1299,
#  'https://openalex.org/W4379932151': 7030,
#  'https://openalex.org/W4386225325': 7032,
#  'https://openalex.org/W4318771331': 3232,
#  'https://openalex.org/W4387762676': 7033,
#  'https://openalex.org/W4389546980': 7034,
#  'https://openalex.org/W4387142556': 5976,
#  'https://openalex.org/W4385535562': 5975,
#  'https://openalex.org/W4366824412': 3607,
#  'https://openalex.org/W4381249309': 5974,
#  'https://openalex.org/W4365133685': 5973,
#  'https://openalex.org/W4364354368': 5972,
#  'https://openalex.org/W4317355154': 1314,
#  'https://openalex.org/W4382520345': 4022,
#  'https://openalex.org/W4383172002': 5505,
#  'https://openalex.org/W4388488716': 2403,
#  'https://openalex.org/W4388303860': 4996,
#  'https://openalex.org/W4317209626': 5504,
#  'https://openalex.org/W3204719635': 2508,
#  'https://openalex.org/W4316928453': 6902,
#  'https://openalex.org/W4377090407': 6906,
#  'https://openalex.org/W4379878309': 4838,
#  'https://openalex.org/W3161316774': 6754,
#  'https://openalex.org/W3133824676': 1009,
#  'https://openalex.org/W4313557127': 5597,
#  'https://openalex.org/W4321611101': 5598,
#  'https://openalex.org/W4388660746': 6017,
#  'https://openalex.org/W4386949197': 5599,
#  'https://openalex.org/W4388111249': 5600,
#  'https://openalex.org/W4386075787': 2635,
#  'https://openalex.org/W4317951947': 998,
#  'https://openalex.org/W4376609298': 4137,
#  'https://openalex.org/W4378192633': 4138,
#  'https://openalex.org/W4382937503': 4139,
#  'https://openalex.org/W4386071831': 4140,
#  'https://openalex.org/W4387541325': 4141,
#  'https://openalex.org/W4387440676': 173,
#  'https://openalex.org/W3216299966': 4865,
#  'https://openalex.org/W4323320159': 6016,
#  'https://openalex.org/W4315435482': 1022,
#  'https://openalex.org/W4385537492': 8707,
#  'https://openalex.org/W4385330852': 6766,
#  'https://openalex.org/W4366422639': 8702,
#  'https://openalex.org/W4367309725': 8703,
#  'https://openalex.org/W4376107652': 8704,
#  'https://openalex.org/W4376132268': 8705,
#  'https://openalex.org/W4384699485': 8706,
#  'https://openalex.org/W4386742257': 8708,
#  'https://openalex.org/W4322495913': 6015,
#  'https://openalex.org/W4386969607': 8709,
#  'https://openalex.org/W4387242624': 8710,
#  'https://openalex.org/W4387460165': 8711,
#  'https://openalex.org/W4386076532': 1026,
#  'https://openalex.org/W4293022516': 1025,
#  'https://openalex.org/W4388035395': 8712,
#  'https://openalex.org/W4385972331': 4839,
#  'https://openalex.org/W4380769213': 985,
#  'https://openalex.org/W4389665446': 4071,
#  'https://openalex.org/W4319162181': 984,
#  'https://openalex.org/W4362720950': 8810,
#  'https://openalex.org/W4366594168': 8811,
#  'https://openalex.org/W4385948524': 935,
#  'https://openalex.org/W4386765496': 934,
#  'https://openalex.org/W4386134158': 6656,
#  'https://openalex.org/W4367369274': 8812,
#  'https://openalex.org/W4378768711': 8813,
#  'https://openalex.org/W4379376118': 8814,
#  'https://openalex.org/W4381334985': 8815,
#  'https://openalex.org/W3125678515': 2692,
#  'https://openalex.org/W4318774826': 5823,
#  'https://openalex.org/W4385289063': 6655,
#  'https://openalex.org/W4292420463': 6652,
#  'https://openalex.org/W4382363386': 4812,
#  'https://openalex.org/W4315705280': 938,
#  'https://openalex.org/W4321788752': 8809,
#  'https://openalex.org/W4387298393': 6657,
#  'https://openalex.org/W4386116142': 3527,
#  'https://openalex.org/W4365457270': 6718,
#  'https://openalex.org/W4318821817': 6717,
#  'https://openalex.org/W4362673398': 2646,
#  'https://openalex.org/W4313877452': 6716,
#  'https://openalex.org/W4327575929': 1944,
#  'https://openalex.org/W4384816694': 3178,
#  'https://openalex.org/W4385325063': 3526,
#  'https://openalex.org/W4389523706': 6658,
#  'https://openalex.org/W4381480701': 3525,
#  'https://openalex.org/W4366987677': 2678,
#  'https://openalex.org/W4387871742': 5827,
#  'https://openalex.org/W4385671288': 5826,
#  'https://openalex.org/W4383896222': 5825,
#  'https://openalex.org/W4362661817': 5824,
#  'https://openalex.org/W4379617776': 3196,
#  'https://openalex.org/W4322489648': 2608,
#  'https://openalex.org/W4319661295': 3549,
#  'https://openalex.org/W4376321189': 1057,
#  'https://openalex.org/W4385476149': 8556,
#  'https://openalex.org/W4385759414': 8557,
#  'https://openalex.org/W4387996251': 8558,
#  'https://openalex.org/W4361282736': 9817,
#  'https://openalex.org/W4320932489': 1143,
#  'https://openalex.org/W4382358890': 2533,
#  'https://openalex.org/W4360805036': 9816,
#  'https://openalex.org/W4322621664': 9815,
#  'https://openalex.org/W4322500410': 9814,
#  'https://openalex.org/W4381309178': 5554,
#  'https://openalex.org/W4383197912': 5555,
#  'https://openalex.org/W4321613246': 9813,
#  'https://openalex.org/W4318617673': 9812,
#  'https://openalex.org/W4318250455': 9811,
#  'https://openalex.org/W4315435977': 9810,
#  'https://openalex.org/W4379739787': 8555,
#  'https://openalex.org/W4323924862': 2532,
#  'https://openalex.org/W4324134829': 8554,
#  'https://openalex.org/W4322494707': 6904,
#  'https://openalex.org/W4390872670': 4072,
#  'https://openalex.org/W4386861232': 132,
#  'https://openalex.org/W4376959545': 9820,
#  'https://openalex.org/W4384663467': 2511,
#  'https://openalex.org/W4386072096': 134,
#  'https://openalex.org/W4366823331': 6905,
#  'https://openalex.org/W4319457090': 6903,
#  'https://openalex.org/W4315487473': 8552,
#  'https://openalex.org/W4367154056': 4472,
#  'https://openalex.org/W4376121343': 9819,
#  'https://openalex.org/W4313549642': 2520,
#  'https://openalex.org/W4375858821': 9818,
#  'https://openalex.org/W4366693590': 5552,
#  'https://openalex.org/W4313857802': 8551,
#  'https://openalex.org/W4387581619': 1128,
#  'https://openalex.org/W4313545069': 9809,
#  'https://openalex.org/W4361278213': 4094,
#  'https://openalex.org/W4388946853': 2595,
#  'https://openalex.org/W4321501059': 2583,
#  'https://openalex.org/W4389727268': 3199,
#  'https://openalex.org/W4387617694': 3198,
#  'https://openalex.org/W4385571011': 4873,
#  'https://openalex.org/W4317390654': 4872,
#  'https://openalex.org/W4225725984': 4870,
#  'https://openalex.org/W4386886497': 3553,
#  'https://openalex.org/W4389333849': 8630,
#  'https://openalex.org/W4385520050': 1063,
#  'https://openalex.org/W4383957026': 158,
#  'https://openalex.org/W4384198172': 3197,
#  'https://openalex.org/W4382940253': 3552,
#  'https://openalex.org/W4327568837': 3551,
#  'https://openalex.org/W4319663675': 3550,
#  'https://openalex.org/W4389938084': 8631,
#  'https://openalex.org/W4387526312': 8629,
#  'https://openalex.org/W4387540644': 1120,
#  'https://openalex.org/W4385948838': 1108,
#  'https://openalex.org/W4388464011': 153,
#  'https://openalex.org/W4386075803': 6841,
#  'https://openalex.org/W4377142588': 6840,
#  'https://openalex.org/W4318919268': 6839,
#  'https://openalex.org/W4318071509': 6838,
#  'https://openalex.org/W4317952732': 6837,
#  'https://openalex.org/W4317682429': 6836,
#  'https://openalex.org/W4385294431': 8628,
#  'https://openalex.org/W4320491874': 2571,
#  'https://openalex.org/W4381786045': 2572,
#  'https://openalex.org/W4321183784': 8624,
#  'https://openalex.org/W4366987732': 8625,
#  'https://openalex.org/W4380322282': 8626,
#  'https://openalex.org/W4384936771': 8627,
#  'https://openalex.org/W4385872154': 4473,
#  'https://openalex.org/W4321441607': 8241,
#  'https://openalex.org/W4323659812': 3330,
#  'https://openalex.org/W4387682177': 7841,
#  'https://openalex.org/W4390872508': 7843,
#  'https://openalex.org/W4386495948': 9943,
#  'https://openalex.org/W4386390424': 9942,
#  'https://openalex.org/W4386127107': 9941,
#  'https://openalex.org/W4388870365': 2103,
#  'https://openalex.org/W4385798528': 9940,
#  'https://openalex.org/W4385634273': 9939,
#  'https://openalex.org/W4382515581': 9938,
#  'https://openalex.org/W4385430674': 1752,
#  'https://openalex.org/W4389991855': 2104,
#  'https://openalex.org/W4322739150': 3862,
#  'https://openalex.org/W4362555260': 3863,
#  'https://openalex.org/W4390872696': 1747,
#  'https://openalex.org/W4389917881': 1746,
#  'https://openalex.org/W4376132855': 9937,
#  'https://openalex.org/W4389542468': 7842,
#  'https://openalex.org/W4383341002': 1765,
#  'https://openalex.org/W4388627415': 2074,
#  'https://openalex.org/W4386740881': 9944,
#  'https://openalex.org/W4389538293': 9946,
#  'https://openalex.org/W4385172574': 1791,
#  'https://openalex.org/W4385984544': 7445,
#  'https://openalex.org/W4385813776': 7444,
#  'https://openalex.org/W4385527621': 7443,
#  'https://openalex.org/W4385396235': 7442,
#  'https://openalex.org/W4379878423': 7441,
#  'https://openalex.org/W4378175164': 7440,
#  'https://openalex.org/W4324139219': 7439,
#  'https://openalex.org/W4386887204': 9945,
#  'https://openalex.org/W4318577731': 7438,
#  'https://openalex.org/W4313706441': 7837,
#  'https://openalex.org/W4384401122': 7838,
#  'https://openalex.org/W4384401159': 7839,
#  'https://openalex.org/W4385879037': 7840,
#  'https://openalex.org/W4375954875': 9936,
#  'https://openalex.org/W4327550249': 36,
#  'https://openalex.org/W4387078309': 5192,
#  'https://openalex.org/W4367050035': 9935,
#  'https://openalex.org/W4317390883': 40,
#  'https://openalex.org/W4381547687': 5380,
#  'https://openalex.org/W4386065740': 5381,
#  'https://openalex.org/W4386066385': 5382,
#  'https://openalex.org/W4386485122': 5383,
#  'https://openalex.org/W4387880919': 5384,
#  'https://openalex.org/W4322739225': 9933,
#  'https://openalex.org/W4321480339': 9932,
#  'https://openalex.org/W4386045865': 2138,
#  'https://openalex.org/W4380302641': 1697,
#  'https://openalex.org/W4319999881': 9931,
#  'https://openalex.org/W4319348806': 9930,
#  'https://openalex.org/W4390063783': 7377,
#  'https://openalex.org/W4389440080': 7376,
#  'https://openalex.org/W4383302171': 7375,
#  'https://openalex.org/W4386334048': 3885,
#  'https://openalex.org/W4385977967': 3884,
#  'https://openalex.org/W4327813569': 9934,
#  'https://openalex.org/W4327954986': 5379,
#  'https://openalex.org/W4387799038': 1737,
#  'https://openalex.org/W4324344258': 5191,
#  'https://openalex.org/W4324134951': 5190,
#  'https://openalex.org/W4315606134': 5376,
#  'https://openalex.org/W4315643346': 5377,
#  'https://openalex.org/W4318218814': 5378,
#  'https://openalex.org/W4378189609': 1727,
#  'https://openalex.org/W4387706996': 2125,
#  'https://openalex.org/W4366823175': 1726,
#  'https://openalex.org/W4321351416': 1725,
#  'https://openalex.org/W4388080313': 3721,
#  'https://openalex.org/W4362457937': 3720,
#  'https://openalex.org/W4318225016': 3719,
#  'https://openalex.org/W4317757464': 2124,
#  'https://openalex.org/W4390873915': 9947,
#  'https://openalex.org/W4353055437': 2066,
#  'https://openalex.org/W4322763951': 7920,
#  'https://openalex.org/W4388002801': 5263,
#  'https://openalex.org/W4316926647': 1903,
#  'https://openalex.org/W4378530323': 5262,
#  'https://openalex.org/W4322492099': 5261,
#  'https://openalex.org/W4313893493': 5260,
#  'https://openalex.org/W4316927645': 5327,
#  'https://openalex.org/W4366339435': 5328,
#  'https://openalex.org/W4377099394': 5879,
#  'https://openalex.org/W4382394445': 5880,
#  'https://openalex.org/W4387259074': 3771,
#  'https://openalex.org/W4317434672': 3770,
#  'https://openalex.org/W4313546023': 3769,
#  'https://openalex.org/W4313647663': 7696,
#  'https://openalex.org/W4315784559': 7697,
#  'https://openalex.org/W4319457643': 7699,
#  'https://openalex.org/W4366598565': 7700,
#  'https://openalex.org/W4376134750': 5878,
#  'https://openalex.org/W4381598122': 1970,
#  'https://openalex.org/W4318541517': 3743,
#  'https://openalex.org/W4319591096': 7607,
#  'https://openalex.org/W4315928354': 5875,
#  'https://openalex.org/W4318592683': 5876,
#  'https://openalex.org/W4367836072': 5877,
#  'https://openalex.org/W4386113253': 7612,
#  'https://openalex.org/W4382345302': 7611,
#  'https://openalex.org/W4365504267': 7610,
#  'https://openalex.org/W4368342591': 1953,
#  'https://openalex.org/W4323354665': 7609,
#  'https://openalex.org/W4390025027': 5298,
#  'https://openalex.org/W4386944725': 5297,
#  'https://openalex.org/W4390030343': 1930,
#  'https://openalex.org/W4389636360': 1929,
#  'https://openalex.org/W4386209525': 1928,
#  'https://openalex.org/W4318983406': 1927,
#  'https://openalex.org/W4322499794': 7608,
#  'https://openalex.org/W4384155285': 5881,
#  'https://openalex.org/W4367856849': 7701,
#  'https://openalex.org/W4384129427': 7702,
#  'https://openalex.org/W4376272229': 4446,
#  'https://openalex.org/W4376959289': 2035,
#  'https://openalex.org/W4383815588': 2036,
#  'https://openalex.org/W4387163062': 2037,
#  'https://openalex.org/W4385620388': 2042,
#  'https://openalex.org/W4368617825': 7764,
#  'https://openalex.org/W4382362021': 7765,
#  'https://openalex.org/W4384156273': 7766,
#  'https://openalex.org/W4386865468': 7767,
#  'https://openalex.org/W4388017359': 7768,
#  'https://openalex.org/W4320913268': 2053,
#  'https://openalex.org/W4379375856': 2054,
#  'https://openalex.org/W2927831250': 2055,
#  'https://openalex.org/W4387568247': 3746,
#  'https://openalex.org/W4379467249': 3745,
#  'https://openalex.org/W4378191996': 3744,
#  'https://openalex.org/W4319866562': 5222,
#  'https://openalex.org/W4387095485': 5223,
#  'https://openalex.org/W4380874786': 1848,
#  'https://openalex.org/W4385639069': 7531,
#  'https://openalex.org/W4380872196': 1995,
#  'https://openalex.org/W4365483636': 4445,
#  'https://openalex.org/W3128143783': 7733,
#  'https://openalex.org/W4386076097': 5882,
#  'https://openalex.org/W4387540805': 7533,
#  'https://openalex.org/W4387354365': 7532,
#  'https://openalex.org/W4383186133': 7530,
#  'https://openalex.org/W4321112414': 7525,
#  'https://openalex.org/W4382404966': 7529,
#  'https://openalex.org/W4386102828': 2012,
#  'https://openalex.org/W4386220262': 2013,
#  'https://openalex.org/W4362602956': 7528,
#  'https://openalex.org/W4360999229': 7527,
#  'https://openalex.org/W4324128992': 7526,
#  'https://openalex.org/W4319982255': 7919,
#  'https://openalex.org/W4323294354': 7921,
#  'https://openalex.org/W4388824146': 8246,
#  'https://openalex.org/W4386065512': 1515,
#  'https://openalex.org/W4318982690': 5110,
#  'https://openalex.org/W4319080562': 1505,
#  'https://openalex.org/W4385955324': 3666,
#  'https://openalex.org/W4385898388': 3665,
#  'https://openalex.org/W4317355000': 3664,
#  'https://openalex.org/W4361269840': 2278,
#  'https://openalex.org/W4390872773': 7188,
#  'https://openalex.org/W4387966468': 7187,
#  'https://openalex.org/W4280619489': 8164,
#  'https://openalex.org/W4389523957': 1481,
#  'https://openalex.org/W4386584720': 7186,
#  'https://openalex.org/W4376107028': 7185,
#  'https://openalex.org/W4322492557': 7184,
#  'https://openalex.org/W4292421666': 8169,
#  'https://openalex.org/W4313892922': 7183,
#  'https://openalex.org/W4319920549': 5111,
#  'https://openalex.org/W4384665281': 3261,
#  'https://openalex.org/W4390221451': 1546,
#  'https://openalex.org/W4386221015': 3262,
#  'https://openalex.org/W4381094969': 1538,
#  'https://openalex.org/W4377101771': 2257,
#  'https://openalex.org/W4319067008': 8091,
#  'https://openalex.org/W4321749334': 8092,
#  'https://openalex.org/W4363678105': 8093,
#  'https://openalex.org/W4366083624': 8094,
#  'https://openalex.org/W4367312000': 8095,
#  'https://openalex.org/W4377193384': 8096,
#  'https://openalex.org/W4385295851': 8097,
#  'https://openalex.org/W4385298633': 8098,
#  'https://openalex.org/W4387542025': 1525,
#  'https://openalex.org/W4385543838': 8099,
#  'https://openalex.org/W4386055621': 8100,
#  'https://openalex.org/W4388763087': 8101,
#  'https://openalex.org/W4387782438': 3263,
#  'https://openalex.org/W4313500193': 8173,
#  'https://openalex.org/W4226512186': 1468,
#  'https://openalex.org/W4322422773': 8174,
#  'https://openalex.org/W4323032735': 8175,
#  'https://openalex.org/W4366992020': 2328,
#  'https://openalex.org/W4387931371': 5463,
#  'https://openalex.org/W4315436844': 3245,
#  'https://openalex.org/W4367369432': 1414,
#  'https://openalex.org/W4389794953': 7113,
#  'https://openalex.org/W4385454046': 2339,
#  'https://openalex.org/W4389452727': 1409,
#  'https://openalex.org/W4389670703': 7112,
#  'https://openalex.org/W4387051158': 912,
#  'https://openalex.org/W4377014276': 8242,
#  'https://openalex.org/W4379599010': 8243,
#  'https://openalex.org/W4384469083': 8244,
#  'https://openalex.org/W4385369331': 8245,
#  'https://openalex.org/W4378953806': 1402,
#  'https://openalex.org/W4319062614': 1401,
#  'https://openalex.org/W4362596712': 1421,
#  'https://openalex.org/W4386499248': 5462,
#  'https://openalex.org/W4390873312': 1427,
#  'https://openalex.org/W4384028715': 3975,
#  'https://openalex.org/W4360613104': 8176,
#  'https://openalex.org/W4381481431': 8177,
#  'https://openalex.org/W4382721316': 8178,
#  'https://openalex.org/W4324344208': 5934,
#  'https://openalex.org/W4362453755': 5072,
#  'https://openalex.org/W4313557922': 5071,
#  'https://openalex.org/W4313439128': 82,
#  'https://openalex.org/W4382520426': 3246,
#  'https://openalex.org/W4386065515': 3976,
#  'https://openalex.org/W4320498734': 2315,
#  'https://openalex.org/W4388609820': 3648,
#  'https://openalex.org/W4319599929': 3647,
#  'https://openalex.org/W4377019739': 5460,
#  'https://openalex.org/W4385571157': 5461,
#  'https://openalex.org/W4362561173': 2256,
#  'https://openalex.org/W2916674581': 1555,
#  'https://openalex.org/W4376132136': 1688,
#  'https://openalex.org/W4313544794': 9926,
#  'https://openalex.org/W4386615105': 5149,
#  'https://openalex.org/W4385298067': 5148,
#  'https://openalex.org/W4382394400': 5147,
#  'https://openalex.org/W4367833987': 5146,
#  'https://openalex.org/W4323825363': 5145,
#  'https://openalex.org/W4320497972': 5144,
#  'https://openalex.org/W4362591486': 2167,
#  'https://openalex.org/W4315643128': 3911,
#  'https://openalex.org/W4386155656': 2175,
#  'https://openalex.org/W4389670373': 1635,
#  'https://openalex.org/W4385298686': 3313,
#  'https://openalex.org/W4390872744': 3695,
#  'https://openalex.org/W4385726786': 2186,
#  'https://openalex.org/W4388291555': 3694,
#  'https://openalex.org/W4323546636': 3693,
#  'https://openalex.org/W4389726555': 5150,
#  'https://openalex.org/W4318016836': 7371,
#  'https://openalex.org/W4323320361': 7243,
#  'https://openalex.org/W4313893987': 9927,
#  'https://openalex.org/W4378976943': 7374,
#  'https://openalex.org/W4324378493': 7373,
#  'https://openalex.org/W4366824082': 7922,
#  'https://openalex.org/W4324019056': 7372,
#  'https://openalex.org/W4378800731': 7923,
#  'https://openalex.org/W4379518351': 7924,
#  'https://openalex.org/W4387899906': 7925,
#  'https://openalex.org/W4387955534': 7926,
#  'https://openalex.org/W4361286998': 1679,
#  'https://openalex.org/W4388931436': 7927,
#  'https://openalex.org/W4317356542': 9929,
#  'https://openalex.org/W4367173722': 3312,
#  'https://openalex.org/W4386075614': 1674,
#  'https://openalex.org/W4315620242': 9928,
#  'https://openalex.org/W4390873054': 49,
#  'https://openalex.org/W4385298725': 3314,
#  'https://openalex.org/W4323809195': 1626,
#  'https://openalex.org/W4386100600': 1621,
#  'https://openalex.org/W4317241078': 3280,
#  'https://openalex.org/W4323036933': 7306,
#  'https://openalex.org/W4386113054': 1592,
#  'https://openalex.org/W4384154098': 5415,
#  'https://openalex.org/W3148575479': 3682,
#  'https://openalex.org/W4377142171': 1571,
#  'https://openalex.org/W4383197616': 2234,
#  'https://openalex.org/W4384071683': 61,
#  'https://openalex.org/W4361302966': 5113,
#  'https://openalex.org/W4383533486': 7246,
#  'https://openalex.org/W4361299044': 5112,
#  'https://openalex.org/W4367173653': 3940,
#  'https://openalex.org/W4386090060': 3941,
#  'https://openalex.org/W4385027818': 1559,
#  'https://openalex.org/W4377968698': 7245,
#  'https://openalex.org/W4362673605': 7244,
#  'https://openalex.org/W4360797446': 7307,
#  'https://openalex.org/W4387142551': 2200,
#  'https://openalex.org/W4386450967': 3913,
#  'https://openalex.org/W4382541699': 8001,
#  'https://openalex.org/W4318197205': 7996,
#  'https://openalex.org/W4322490942': 7997,
#  'https://openalex.org/W4327837216': 7998,
#  'https://openalex.org/W4360610013': 7999,
#  'https://openalex.org/W4388520183': 7308,
#  'https://openalex.org/W4376983012': 8000,
#  'https://openalex.org/W4384561103': 8002,
#  'https://openalex.org/W4361012985': 3912,
#  'https://openalex.org/W4385080392': 8003,
#  'https://openalex.org/W4386127054': 8004,
#  'https://openalex.org/W4388304484': 1604,
#  'https://openalex.org/W4316511358': 1603,
#  'https://openalex.org/W4387744574': 8005,
#  'https://openalex.org/W4381598483': 58,
#  'https://openalex.org/W4323255417': 4811,
#  'https://openalex.org/W4315641779': 1119,
#  'https://openalex.org/W4318982558': 2703,
#  'https://openalex.org/W4386758072': 5690,
#  'https://openalex.org/W4385988359': 694,
#  'https://openalex.org/W4375955255': 4222,
#  'https://openalex.org/W4366003124': 4221,
#  'https://openalex.org/W4323347737': 4220,
#  'https://openalex.org/W4383066393': 449,
#  'https://openalex.org/W4379209546': 448,
#  'https://openalex.org/W4385341464': 3007,
#  'https://openalex.org/W4315489816': 9389,
#  'https://openalex.org/W4320033104': 9390,
#  'https://openalex.org/W4321611584': 9391,
#  'https://openalex.org/W4318755347': 4219,
#  'https://openalex.org/W4377693398': 9392,
#  'https://openalex.org/W4315705344': 9088,
#  'https://openalex.org/W4366548330': 701,
#  'https://openalex.org/W4321440702': 5689,
#  'https://openalex.org/W4323530556': 703,
#  'https://openalex.org/W4315436185': 5688,
#  'https://openalex.org/W4317905177': 4539,
#  'https://openalex.org/W4387526062': 6058,
#  'https://openalex.org/W4384206592': 9093,
#  'https://openalex.org/W4382775476': 9092,
#  'https://openalex.org/W4382358538': 9091,
#  'https://openalex.org/W4379469042': 9090,
#  'https://openalex.org/W4360603378': 9089,
#  'https://openalex.org/W4382630739': 4223,
#  'https://openalex.org/W4385664020': 4224,
#  'https://openalex.org/W4379959055': 4540,
#  'https://openalex.org/W4380684571': 4541,
#  'https://openalex.org/W4327681325': 3123,
#  'https://openalex.org/W4318541322': 6416,
#  'https://openalex.org/W4386762080': 6417,
#  'https://openalex.org/W4386949506': 6418,
#  'https://openalex.org/W4387541035': 6419,
#  'https://openalex.org/W4390258985': 6420,
#  'https://openalex.org/W4389681263': 670,
#  'https://openalex.org/W4322733206': 2990,
#  'https://openalex.org/W4390023570': 6257,
#  'https://openalex.org/W4388720459': 6256,
#  'https://openalex.org/W4386969571': 6255,
#  'https://openalex.org/W4384155024': 6254,
#  'https://openalex.org/W4321607142': 4709,
#  'https://openalex.org/W4323532421': 4710,
#  'https://openalex.org/W4388900411': 4711,
#  'https://openalex.org/W4389920694': 4712,
#  'https://openalex.org/W4383218197': 6253,
#  'https://openalex.org/W4316687819': 3122,
#  'https://openalex.org/W4372203465': 6252,
#  'https://openalex.org/W4389132715': 685,
#  'https://openalex.org/W4389670555': 457,
#  'https://openalex.org/W4389373471': 456,
#  'https://openalex.org/W4317242238': 6251,
#  'https://openalex.org/W4380627387': 437,
#  'https://openalex.org/W4313557110': 9087,
#  'https://openalex.org/W4388111256': 787,
#  'https://openalex.org/W4366162530': 6196,
#  'https://openalex.org/W4327662982': 3398,
#  'https://openalex.org/W4386148333': 6201,
#  'https://openalex.org/W4385443485': 6200,
#  'https://openalex.org/W4378471793': 4740,
#  'https://openalex.org/W4377237770': 3042,
#  'https://openalex.org/W4387472464': 4742,
#  'https://openalex.org/W4387674093': 4743,
#  'https://openalex.org/W4384820649': 2798,
#  'https://openalex.org/W4382794886': 6199,
#  'https://openalex.org/W4380785158': 6198,
#  'https://openalex.org/W4366589759': 6197,
#  'https://openalex.org/W4313897562': 6535,
#  'https://openalex.org/W4380574892': 436,
#  'https://openalex.org/W4319946238': 6536,
#  'https://openalex.org/W4321076735': 6537,
#  'https://openalex.org/W4387142583': 6538,
#  'https://openalex.org/W4387344519': 775,
#  'https://openalex.org/W4386057725': 776,
#  'https://openalex.org/W4386740800': 777,
#  'https://openalex.org/W4387307597': 6539,
#  'https://openalex.org/W4324143593': 4770,
#  'https://openalex.org/W4368359961': 781,
#  'https://openalex.org/W3150546480': 9768,
#  'https://openalex.org/W4379162539': 3161,
#  'https://openalex.org/W4377011124': 206,
#  'https://openalex.org/W4320485404': 4598,
#  'https://openalex.org/W4388654737': 405,
#  'https://openalex.org/W4321610982': 406,
#  'https://openalex.org/W4318071656': 435,
#  'https://openalex.org/W4380563898': 9393,
#  'https://openalex.org/W4386076275': 9394,
#  'https://openalex.org/W4387451853': 9395,
#  'https://openalex.org/W4319300158': 6475,
#  'https://openalex.org/W4360609132': 6476,
#  ...}

# %% [markdown]
# ## Step 1: Find Main Papers (P_i)
#
# Filter papers where `referenced_works_count ∈ [MIN_REF_COUNT, MAX_REF_COUNT]` and at all of their cited works are resolvable within the followed corpus.

# %%
MAIN_PAPERS_PATH = os.path.join(EVAL_DIR, 'main_papers.json')

if os.path.exists(MAIN_PAPERS_PATH):
    print('Loading cached main_papers.json...')
    with open(MAIN_PAPERS_PATH) as f:
        main_papers = json.load(f)
    print(f'Loaded {len(main_papers)} main papers.')
else:
    print('Selecting main papers...')

    # Filter by ref count range
    mask = (followed_df['referenced_works_count'] >= MIN_REF_COUNT) & \
           (followed_df['referenced_works_count'] <= MAX_REF_COUNT)
    candidates = followed_df[mask].copy()
    print(f'Papers with {MIN_REF_COUNT}-{MAX_REF_COUNT} refs: {len(candidates):,}')

    # Further filter: need abstract text and ref list present
    def has_valid_refs(refs):
        return isinstance(refs, list) and len(refs) >= MIN_REF_COUNT

    candidates = candidates[
        candidates['referenced_works'].apply(has_valid_refs) &
        candidates['abstract'].notna()
    ]
    print(f'After quality filters: {len(candidates):}')

    candidates.to_csv(f'data/cleaned/{MIN_REF_COUNT}-{MAX_REF_COUNT}-refs.csv', index=False)

    sampled = candidates

    main_papers = []
    for _, row in sampled.iterrows():
        refs = row['referenced_works'] if isinstance(row['referenced_works'], list) else []
        main_papers.append({
            'id': row['id'],
            'title': row.get('title', ''),
            'abstract': row.get('abstract', ''),
            'referenced_works': refs,
            'referenced_works_count': int(row['referenced_works_count']),
            'text': row['text'],
            'concepts_array': row['concepts_array'],
        })

    with open(MAIN_PAPERS_PATH, 'w') as f:
        json.dump(main_papers, f, indent=2)
    print(f'Saved {len(main_papers)} main papers to {MAIN_PAPERS_PATH}')
# Out:
# Loading cached main_papers.json...
# Loaded 174 main papers.

# %% [markdown]
# ## Step 2: Build Per-P_i Evaluation Sets
#
# For each P_i with n references:
# - **Positives (n):** actual cited papers — looked up in corpus, or fetched via OpenAlex API
# - **Negatives (2n):** random papers from `priority_followed.csv`, excluding P_i's refs and same-author works
#
# Result: 3n candidates per query.

# %%
# ── OpenAlex API fetch for references not in corpus ────────────────────────
import importlib
import urllib.request

import src.text_utils as _text_utils
importlib.reload(_text_utils)
from src.text_utils import reconstruct_abstract, clean_abstract


def fetch_openalex_works(openalex_ids, batch_size=50, sleep=0.3):
    """Fetch work metadata for a list of OpenAlex IDs via public API."""
    results = {}
    fetched_works = []
    ids = list(openalex_ids)
    for i in range(0, len(ids), batch_size):
        batch = ids[i:i + batch_size]
        # Strip URL prefix if present
        short_ids = [b.split('/')[-1] for b in batch]
        filter_str = '|'.join(short_ids)
        url = f'https://api.openalex.org/works?filter=openalex_id:{filter_str}&per_page={batch_size}'
        try:
            with urllib.request.urlopen(url, timeout=15) as resp:
                data = json.loads(resp.read())
                batch_works = data.get('results', [])

                if not batch_works:
                    break

                for work in batch_works:
                    fetched_works.append(work)
                    wid = work.get('id', '')
                    raw = reconstruct_abstract(work.get('abstract_inverted_index'))
                    abstract = (clean_abstract(raw) or '') if raw else ''
                    results[wid] = {
                        'id': wid,
                        'title': work.get('title', '') or '',
                        'abstract': abstract,
                        'concepts': work.get('concepts', []),
                    }

                df = pd.DataFrame(fetched_works)
                df.to_csv('data/openalex_reference_works_raw.csv', index=False, encoding="utf-8")
                print(f"\nCompleted! Total {len(df)} papers saved to data/openalex_reference_works_raw.csv")
        except Exception as e:
            print(f'  API error for batch {i//batch_size}: {e}')
        time.sleep(sleep)
    return results


print('OpenAlex fetch function ready')
# Out:
# OpenAlex fetch function ready

# %%
from src.preprocessing import process_papers


EVAL_SETS_PATH = os.path.join(RESULTS_CACHE, 'eval_sets.pkl')

if os.path.exists(EVAL_SETS_PATH):
    print('Loading cached eval sets...')
    with open(EVAL_SETS_PATH, 'rb') as f:
        eval_sets = pickle.load(f)
    print(f'Loaded {len(eval_sets)} eval sets.')
else:
    print('Building eval sets...')

    # Collect all ref IDs not in corpus so we can batch-fetch them
    all_missing_ids = set()
    for paper in main_papers:
        for ref_id in paper['referenced_works']:
            if ref_id not in id_to_idx:
                all_missing_ids.add(ref_id)

    print(f'Missing {len(all_missing_ids)} reference papers not in corpus...')
        
    # Build eval sets
    all_followed_ids = set(followed_df['id'].tolist())

    def _get_author_ids(auths):
        ids = set()
        if isinstance(auths, list):
            for a in auths:
                if isinstance(a, dict):
                    author = a.get('author')
                    if isinstance(author, dict):
                        aid = author.get('id', '')
                        if aid:
                            ids.add(aid)
        return ids

    eval_sets = []
    for paper in tqdm(main_papers, desc='Building eval sets'):
        pi_id   = paper['id']
        pi_text = paper['text']
        ref_ids = paper['referenced_works']

        # Build positive candidates
        positives = []
        for ref_id in ref_ids:
            if ref_id in id_to_idx:
                row = extended_followed_df.iloc[id_to_idx[ref_id]]
                positives.append({
                    'id': ref_id,
                    'title': row.get('title', ''),
                    'abstract': row.get('abstract', ''),
                    'text': row['text'],
                    'concepts_array': row['concepts_array']
                })

        n = len(positives)

        # Build negative candidates: 2n random, excluding refs and same-author works
        ref_id_set = set(ref_ids)

        # Get author IDs for P_i to exclude same-author works
        pi_row = followed_df[followed_df['id'] == pi_id]
        pi_author_ids = set()
        if not pi_row.empty:
            pi_author_ids = _get_author_ids(pi_row.iloc[0].get('authorships', []))

        exclude_ids = ref_id_set | {pi_id}

        # Exclude same-author papers if we have author info
        if pi_author_ids:
            same_author_mask = followed_df['authorships'].apply(
                lambda auths: bool(_get_author_ids(auths) & pi_author_ids)
            )
        else:
            same_author_mask = pd.Series(False, index=followed_df.index)

        neg_pool = followed_df[
            ~followed_df['id'].isin(exclude_ids) &
            (followed_df['text'].str.len() > 20) &
            ~same_author_mask &
            (followed_df['abstract'].notna() & (followed_df['abstract'] != ''))
        ]
        # print('Size of neg_pool:', len(neg_pool), 'for', pi_id)
        neg_sample = neg_pool.sample(n=min(2 * n, len(neg_pool)),
                                     random_state=hash(pi_id) % (2**31))
        negatives = [{
            'id': row['id'],
            'title': row.get('title', '') or '',
            'abstract': row.get('abstract', '') or '',
            'text': row['text'],
            'source': 'negative',
        } for _, row in neg_sample.iterrows()]

        eval_sets.append({
            'pi_id':       pi_id,
            'pi_title':    paper['title'],
            'pi_text':     pi_text,
            'n_positives': len(positives),
            'n_negatives': len(negatives),
            'positives':   positives,
            'negatives':   negatives,
        })

    with open(EVAL_SETS_PATH, 'wb') as f:
        pickle.dump(eval_sets, f)
    print(f'Built and cached {len(eval_sets)} eval sets → {EVAL_SETS_PATH}')

# Summary
n_pos_list = [e['n_positives'] for e in eval_sets]
n_neg_list = [len(e['negatives']) for e in eval_sets]
print(f'\nEval sets: {len(eval_sets)}')
# Out:
# Building eval sets...
# Missing 142 reference papers not in corpus...
# Building eval sets: 100%|██████████| 174/174 [00:12<00:00, 13.99it/s]
# Built and cached 174 eval sets → data/results_cache/week3/eval_sets.pkl
#
# Eval sets: 174

# %%
# create df and pront from eval_sets also add text length
eval_sets_df = pd.DataFrame(eval_sets)
eval_sets_df['text_length'] = eval_sets_df['pi_text'].apply(len)
eval_sets_df
# Out:
#                                 pi_id  \
# 0    https://openalex.org/W4399940463
# 1    https://openalex.org/W4392515871
# 2    https://openalex.org/W4388303860
# 3    https://openalex.org/W4380769213
# 4    https://openalex.org/W4385289063
# ..                                ...
# 169  https://openalex.org/W3014945260
# 170  https://openalex.org/W3023399464
# 171  https://openalex.org/W3018157127
# 172  https://openalex.org/W3000477794
# 173  https://openalex.org/W3039756956
#
#                                               pi_title  \
# 0    ADMET-AI: a machine learning ADMET platform fo...
# 1    The STROCSS 2024 guideline: strengthening the ...
# 2    The Importance of Financial Literacy: Opening ...
# 3                 Art and the science of generative AI
# 4    MERF: Memory-Efficient Radiance Fields for Rea...
# ..                                                 ...
# 169  The Coronavirus and the Risks to the Elderly i...
# 170  Opportunities From the Coronavirus Disease 201...
# 171  Ventilator Triage Policies During the COVID-19...
# 172  Clinical Impact of Metagenomic Next-Generation...
# 173  Unmuting Medical Students’ Education: Utilizin...
#
#                                                pi_text  n_positives  \
# 0    ADMET-AI: a machine learning ADMET platform fo...           14
# 1    The STROCSS 2024 guideline: strengthening the ...           12
# 2    The Importance of Financial Literacy: Opening ...            5
# 3    Art and the science of generative AI Understan...            7
# 4    MERF: Memory-Efficient Radiance Fields for Rea...            4
# ..                                                 ...          ...
# 169  The Coronavirus and the Risks to the Elderly i...            7
# 170  Opportunities From the Coronavirus Disease 201...           10
# 171  Ventilator Triage Policies During the COVID-19...           14
# 172  Clinical Impact of Metagenomic Next-Generation...           10
# 173  Unmuting Medical Students’ Education: Utilizin...           14
#
#      n_negatives                                          positives  \
# 0             28  [{'id': 'https://openalex.org/W2009867031', 't...
# 1             24  [{'id': 'https://openalex.org/W2002463857', 't...
# 2             10  [{'id': 'https://openalex.org/W1549162356', 't...
# 3             14  [{'id': 'https://openalex.org/W2526781987', 't...
# 4              8  [{'id': 'https://openalex.org/W2122572959', 't...
# ..           ...                                                ...
# 169           14  [{'id': 'https://openalex.org/W2151860978', 't...
# 170           20  [{'id': 'https://openalex.org/W2089711903', 't...
# 171           28  [{'id': 'https://openalex.org/W1975543319', 't...
# 172           20  [{'id': 'https://openalex.org/W2901531873', 't...
# 173           28  [{'id': 'https://openalex.org/W2190106216', 't...
#
#                                              negatives  text_length
# 0    [{'id': 'https://openalex.org/W2988274083', 't...          621
# 1    [{'id': 'https://openalex.org/W3194710570', 't...          733
# 2    [{'id': 'https://openalex.org/W4318484119', 't...         1051
# 3    [{'id': 'https://openalex.org/W3196097483', 't...          277
# 4    [{'id': 'https://openalex.org/W4225775378', 't...         1202
# ..                                                 ...          ...
# 169  [{'id': 'https://openalex.org/W3188255222', 't...         1036
# 170  [{'id': 'https://openalex.org/W3137307641', 't...          531
# 171  [{'id': 'https://openalex.org/W3135141008', 't...          388
# 172  [{'id': 'https://openalex.org/W2983192835', 't...         1985
# 173  [{'id': 'https://openalex.org/W3027407129', 't...         1410
#
# [174 rows x 8 columns]

# %%
# mean of text length
print("mean of text length: ", eval_sets_df['text_length'].mean())
# median of text length
print("median of text length: ", eval_sets_df['text_length'].median())
# max of text length
print("max of text length: ", eval_sets_df['text_length'].max())
# Out:
# mean of text length:  1433.7931034482758
# median of text length:  837.5
# max of text length:  24964

# %%
random_eval_sets = random.sample(eval_sets, 100)
random_eval_sets_df = pd.DataFrame(random_eval_sets)
random_eval_sets_df
# Out:
#                                pi_id  \
# 0   https://openalex.org/W3048459274
# 1   https://openalex.org/W4306722800
# 2   https://openalex.org/W4389523957
# 3   https://openalex.org/W3202634790
# 4   https://openalex.org/W3138513807
# ..                               ...
# 95  https://openalex.org/W3014846055
# 96  https://openalex.org/W3092899113
# 97  https://openalex.org/W4385289063
# 98  https://openalex.org/W3091818265
# 99  https://openalex.org/W3194326451
#
#                                              pi_title  \
# 0   COVID-19 and Health Code: How Digital Platform...
# 1   Interpreting area under the receiver operating...
# 2   Is ChatGPT a General-Purpose Natural Language ...
# 3   New strategies to improve minimap2 alignment a...
# 4   LocusZoom.js: interactive and embeddable visua...
# ..                                                ...
# 95  Sample Pooling as a Strategy to Detect Communi...
# 96  Updated science-wide author databases of stand...
# 97  MERF: Memory-Efficient Radiance Fields for Rea...
# 98  Priorities for addressing the impact of the CO...
# 99  Personalized Prediction Model to Risk Stratify...
#
#                                               pi_text  n_positives  \
# 0   COVID-19 and Health Code: How Digital Platform...            6
# 1   Interpreting area under the receiver operating...           10
# 2   Is ChatGPT a General-Purpose Natural Language ...           12
# 3   New strategies to improve minimap2 alignment a...           14
# 4   LocusZoom.js: interactive and embeddable visua...            6
# ..                                                ...          ...
# 95  Sample Pooling as a Strategy to Detect Communi...            7
# 96  Updated science-wide author databases of stand...            5
# 97  MERF: Memory-Efficient Radiance Fields for Rea...            4
# 98  Priorities for addressing the impact of the CO...            6
# 99  Personalized Prediction Model to Risk Stratify...           14
#
#     n_negatives                                          positives  \
# 0            12  [{'id': 'https://openalex.org/W2184763095', 't...
# 1            20  [{'id': 'https://openalex.org/W1144300234', 't...
# 2            24  [{'id': 'https://openalex.org/W2552383788', 't...
# 3            28  [{'id': 'https://openalex.org/W2043257286', 't...
# 4            12  [{'id': 'https://openalex.org/W2142386149', 't...
# ..          ...                                                ...
# 95           14  [{'id': 'https://openalex.org/W2128538941', 't...
# 96           10  [{'id': 'https://openalex.org/W2170240176', 't...
# 97            8  [{'id': 'https://openalex.org/W2122572959', 't...
# 98           12  [{'id': 'https://openalex.org/W2106800179', 't...
# 99           28  [{'id': 'https://openalex.org/W187238933', 'ti...
#
#                                             negatives
# 0   [{'id': 'https://openalex.org/W4293332167', 't...
# 1   [{'id': 'https://openalex.org/W4376107652', 't...
# 2   [{'id': 'https://openalex.org/W4304693765', 't...
# 3   [{'id': 'https://openalex.org/W3072681182', 't...
# 4   [{'id': 'https://openalex.org/W3206845495', 't...
# ..                                                ...
# 95  [{'id': 'https://openalex.org/W3000160985', 't...
# 96  [{'id': 'https://openalex.org/W3088515428', 't...
# 97  [{'id': 'https://openalex.org/W4225775378', 't...
# 98  [{'id': 'https://openalex.org/W3206550133', 't...
# 99  [{'id': 'https://openalex.org/W3164849473', 't...
#
# [100 rows x 7 columns]

# %%
# one row per abstract from positives
abstracts_df = random_eval_sets_df[['positives']].explode('positives').reset_index(drop=True)
abstracts_df['abstract'] = abstracts_df['positives'].apply(lambda p: p['abstract'])
abstracts_df = abstracts_df.drop(columns='positives')
abstracts_df
# Out:
#                                               abstract
# 0                                                  NaN
# 1                                                  NaN
# 2    Two extant frameworks - the harshness-unpredic...
# 3                                                  NaN
# 4    The weak gravity conjecture, at the simplest l...
# ..                                                 ...
# 939                                                NaN
# 940  Rucaparib monotherapy is effective as first-li...
# 941  Multiple studies have established associations...
# 942  Economy-wide emissions drop 43 to 48% below 20...
# 943  We present an overview of the Large Program, “...
#
# [944 rows x 1 columns]

# %%
# count NaNs
print(abstracts_df['abstract'].isna().sum())

# count empty strings
print(abstracts_df['abstract'].apply(lambda x: x == '').sum())
# Out:
# 347
# 2

# %% [markdown]
# ## Step 3: Compute Embeddings and Rankings
#
# For each method, rank all 3n candidates per query and compute per-query hit rate:
# ```
# hit_rate = (# true references in top-n) / n × 100%
# ```

# %%
# ── Ranking function ───────────────────────────────────────────────────────

def rank_candidates(query_text, candidates, method):
    """
    Rank `candidates` (list of dicts with 'text', 'title', 'concepts_array' keys) against `query_text`.
    Returns list of (candidate_idx, score) sorted by score descending.
    """
    texts = [c['text'] for c in candidates]

    if method == 'bm25':
        scores = bm25_similarity([query_text], texts)[0]

    elif method == 'tfidf':
        scores = tfidf_similarity([query_text], texts)[0]

    elif method in MODEL_MAP:
        model_name = MODEL_MAP[method]
        sim_matrix = sentence_embedding_similarity(
            [query_text], texts, model_name=model_name, cache_dir=EMBED_CACHE
        )
        scores = sim_matrix[0]

    elif method == 'gemini':
        gemini_texts = [
            ' '.join(filter(None, [
                c.get('title', ''),
                ' '.join(c.get('concepts_array', [])),
            ]))
            for c in candidates
        ]
        return gemini_rank_candidates(query_text, gemini_texts)

    else:
        raise ValueError(f'Unknown method: {method}')

    ranked = sorted(enumerate(scores.tolist()), key=lambda x: x[1], reverse=True)
    return ranked


print('Ranking function ready')
# Out:
# Ranking function ready

# %%
# ── Run rankings for all methods ───────────────────────────────────────────
# Results format: {method: [{pi_id, pi_title, n_positives, ranked, positive_indices}, ...]}

RANKINGS_CACHE = os.path.join(RESULTS_CACHE, 'rankings.pkl')

if os.path.exists(RANKINGS_CACHE):
    with open(RANKINGS_CACHE, 'rb') as f:
        all_rankings = pickle.load(f)
    print(f'Loaded rankings cache. Methods present: {list(all_rankings.keys())}')
else:
    all_rankings = {}

methods_to_run = [m for m in METHODS if m not in all_rankings]
print(f'Methods to compute: {methods_to_run}')

for method in methods_to_run:
    print(f'\n── Method: {method} ──')
    method_results = []

    for ev in tqdm(random_eval_sets, desc=method):
        main_text = ev['pi_text']
        candidates = ev['positives'] + ev['negatives']
        positive_ids = {p['id'] for p in ev['positives']}
        positive_indices = set(range(len(ev['positives'])))  # positives are first

        ranked = rank_candidates(main_text, candidates, method)

        method_results.append({
            'pi_id':            ev['pi_id'],
            'pi_title':         ev['pi_title'],
            'n_positives':      ev['n_positives'],
            'n_candidates':     len(candidates),
            'ranked':           ranked,          # [(candidate_idx, score), ...]
            'positive_indices': positive_indices, # set of indices that are positives
        })

    all_rankings[method] = method_results

    # Save incrementally
    with open(RANKINGS_CACHE, 'wb') as f:
        pickle.dump(all_rankings, f)
    print(f'  Saved {len(method_results)} results for {method}')

print('\nAll rankings computed.')
# Out:
# Methods to compute: ['bm25', 'tfidf', 'minilm', 'specter2']
#
# ── Method: bm25 ──
# bm25: 100%|██████████| 100/100 [00:00<00:00, 219.02it/s]
#   Saved 100 results for bm25
#
# ── Method: tfidf ──
# tfidf: 100%|██████████| 100/100 [00:00<00:00, 204.20it/s]
#   Saved 100 results for tfidf
#
# ── Method: minilm ──
# minilm:   0%|          | 0/100 [00:00<?, ?it/s]Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 4995.36it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# minilm: 100%|██████████| 100/100 [00:21<00:00,  4.66it/s]
#   Saved 100 results for minilm
#
# ── Method: specter2 ──
# specter2:   0%|          | 0/100 [00:00<?, ?it/s]No sentence-transformers model found with name allenai/specter2_base. Creating a new one with mean pooling.
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 42812.19it/s]
# BertModel LOAD REPORT from: allenai/specter2_base
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# specter2: 100%|██████████| 100/100 [03:45<00:00,  2.26s/it]
#   Saved 100 results for specter2
#
# All rankings computed.

# %% [markdown]
# ## Step 4: Evaluation Metrics
#
# Aggregate across all queries and report per method:
#
# | Metric | Description |
# |---|---|
# | **Hit Rate %** | % of top-n slots filled by true references |
# | **Precision@n** | Equivalent to mean hit rate |
# | **MRR** | Mean reciprocal rank of first positive |
# | **nDCG@n** | Ranking quality accounting for all positives' positions |

# %%
from src.metrics import hit_rate_at_n, reciprocal_rank, ndcg_at_n


def compute_metrics(method_results):
    """Return dict of metric_name → list of per-query values."""
    hit_rates, mrrs, ndcgs = [], [], []

    for res in method_results:
        n   = res['n_positives']
        pos = res['positive_indices']
        r   = res['ranked']

        hit_rates.append(hit_rate_at_n(r, pos, n) * 100)
        mrrs.append(reciprocal_rank(r, pos))
        ndcgs.append(ndcg_at_n(r, pos, n))

    return {
        'hit_rate': hit_rates,
        'mrr':      mrrs,
        'ndcg':     ndcgs,
    }


print('Metric functions ready')
# Out:
# Metric functions ready

# %%
# ── Aggregate and display results ──────────────────────────────────────────

rows = []
metrics_by_method = {}

for method, results in all_rankings.items():
    m = compute_metrics(results)
    metrics_by_method[method] = m
    rows.append({
        'Method':              method,
        'Mean Hit Rate %':     round(np.mean(m['hit_rate']), 2),
        'Std Hit Rate %':      round(np.std(m['hit_rate']),  2),
        'Median Hit Rate %':   round(np.median(m['hit_rate']), 2),
        'Mean MRR':            round(np.mean(m['mrr']),  4),
        'Std MRR':             round(np.std(m['mrr']),   4),
        'Mean nDCG@n':         round(np.mean(m['ndcg']), 4),
        'Std nDCG@n':          round(np.std(m['ndcg']),  4),
    })

results_df = pd.DataFrame(rows).sort_values('Mean Hit Rate %', ascending=False)
print('\n=== Week 3 Results ===')
print(results_df.to_string(index=False))

# Save results table
results_df.to_csv(os.path.join(EVAL_DIR, 'metrics_summary.csv'), index=False)

# Save per-query metrics
with open(os.path.join(RESULTS_CACHE, 'metrics_by_method.pkl'), 'wb') as f:
    pickle.dump(metrics_by_method, f)

print(f'\nSaved metrics_summary.csv → {EVAL_DIR}')
# Out:
# === Week 3 Results ===
#   Method  Mean Hit Rate %  Std Hit Rate %  Median Hit Rate %  Mean MRR  Std MRR  Mean nDCG@n  Std nDCG@n
#   minilm            35.90           16.70              33.33    0.5357   0.3448       0.6324      0.2179
#    tfidf            33.41           14.62              33.33    0.5362   0.3363       0.6294      0.2142
# specter2            30.21           15.83              30.00    0.4654   0.3215       0.5819      0.2240
#     bm25            23.09           11.70              21.43    0.4099   0.3041       0.5278      0.2388
#
# Saved metrics_summary.csv → eval_dataset/week3

# %%
# ── Save per-method ranking files ──────────────────────────────────────────
# eval_dataset/week3/rankings_{method}.json

for method, results in all_rankings.items():
    m = metrics_by_method[method]
    output = []
    for i, res in enumerate(results):
        output.append({
            'pi_id':       res['pi_id'],
            'pi_title':    res['pi_title'],
            'n_positives': res['n_positives'],
            'hit_rate':    round(m['hit_rate'][i], 4),
            'mrr':         round(m['mrr'][i], 4),
            'ndcg':        round(m['ndcg'][i], 4),
            'ranked_ids':  [res['ranked'][j][0] for j in range(min(res['n_positives'], len(res['ranked'])))],
            'ranked_scores': [round(res['ranked'][j][1], 4) for j in range(min(res['n_positives'], len(res['ranked'])))],
        })
    path = os.path.join(EVAL_DIR, f'rankings_{method}.json')
    with open(path, 'w') as f:
        json.dump(output, f, indent=2)
    print(f'Saved {path}')
# Out:
# Saved eval_dataset/week3/rankings_bm25.json
# Saved eval_dataset/week3/rankings_tfidf.json
# Saved eval_dataset/week3/rankings_minilm.json
# Saved eval_dataset/week3/rankings_specter2.json

# %%
# ── Visualisation ──────────────────────────────────────────────────────────
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

methods_sorted = results_df['Method'].tolist()
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
fig.suptitle('Week 3: Cited Paper Ranking — Method Comparison', fontsize=14)

colors = plt.cm.tab10(np.linspace(0, 0.6, len(methods_sorted)))

# Hit Rate distribution
ax = axes[0]
data = [metrics_by_method[m]['hit_rate'] for m in methods_sorted]
ax.boxplot(data, labels=methods_sorted, patch_artist=True,
           boxprops=dict(facecolor='lightblue'))
ax.set_title('Hit Rate @ n (%)')
ax.set_ylabel('%')
ax.tick_params(axis='x', rotation=30)

# MRR distribution
ax = axes[1]
data = [metrics_by_method[m]['mrr'] for m in methods_sorted]
ax.boxplot(data, labels=methods_sorted, patch_artist=True,
           boxprops=dict(facecolor='lightgreen'))
ax.set_title('MRR (Mean Reciprocal Rank)')
ax.tick_params(axis='x', rotation=30)

# nDCG@n distribution
ax = axes[2]
data = [metrics_by_method[m]['ndcg'] for m in methods_sorted]
ax.boxplot(data, labels=methods_sorted, patch_artist=True,
           boxprops=dict(facecolor='lightsalmon'))
ax.set_title('nDCG @ n')
ax.tick_params(axis='x', rotation=30)

plt.tight_layout()
out_path = os.path.join(EVAL_DIR, 'method_comparison.png')
plt.savefig(out_path, dpi=150, bbox_inches='tight')
plt.show()
print(f'Saved → {out_path}')
# Out:
# Saved → eval_dataset/week3/method_comparison.png

# %% [markdown]
# <b>Top-1 Score is the similarity score assigned to the highest-ranked candidate paper for a given query.</b>
#
# Concretely, after ranking all candidates (positives + negatives) by similarity to the target paper, ranked[0] is the top result — Top-1 Score is the raw similarity value from that method (e.g. cosine similarity for embedding methods, BM25 score, TF-IDF score). It tells you how confident the method was about its top pick, but says nothing about whether that pick was correct — that's what Top-1 Is Cited is for.

# %%
# ── Detailed per-query table ────────────────────────────────────────────

def build_per_query_table(rankings):
    rows = []
    for res in rankings:
        ranked      = res['ranked']
        pos_indices = res['positive_indices']
        n           = res['n_positives']

        top1_idx, top1_score = ranked[0] if ranked else (None, float('nan'))
        top1_is_cited = top1_idx in pos_indices if top1_idx is not None else False
        hits_at_n = sum(1 for idx, _ in ranked[:n] if idx in pos_indices)

        rows.append({
            'Target Paper':   res['pi_title'][:80] + ('…' if len(res['pi_title']) > 80 else ''),
            'Cited Papers':   n,
            'Corpus Size':    res['n_candidates'],
            'Top-1 Score':    round(top1_score, 4),
            'Top-1 Is Cited': '✓' if top1_is_cited else '✗',
            'Hits@n':         hits_at_n,
            'Hits@n%':        round(hits_at_n / n * 100, 2),
        })

    return pd.DataFrame(rows)

# %%
comparison_rows = []

for method, rankings in all_rankings.items():
    print(f'\n{"═"*100}')
    print(f'  Method: {method.upper()}')
    print(f'{"═"*100}')
    df = build_per_query_table(rankings)
    display(df.style
              .map(lambda v: 'color: green; font-weight: bold' if v == '✓' else
                             ('color: red' if v == '✗' else ''),
                   subset=['Top-1 Is Cited'])
              .background_gradient(subset=['Hits@n', 'Hits@n%'], cmap='YlGn')
              .format({'Top-1 Score': '{:.4f}', 'Hits@n%': '{:.2f}'})
    )

    top1_acc = (df['Top-1 Is Cited'] == '✓').mean() * 100
    mean_hits = df['Hits@n%'].mean()
    comparison_rows.append({'Method': method, 'Hits@n%': round(mean_hits, 2), 'Top-1 Accuracy%': round(top1_acc, 1)})
    print(f'  Top-1 accuracy : {top1_acc:.1f}%')
    print(f'  Mean Hits@n%   : {mean_hits:.2f}%')

method_comparison_df = pd.DataFrame(comparison_rows).sort_values('Top-1 Accuracy%', ascending=False).reset_index(drop=True)
# Out:
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#   Method: BM25
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# <style type="text/css">
# #T_1113b_row0_col4, #T_1113b_row1_col4, #T_1113b_row2_col4, #T_1113b_row4_col4, #T_1113b_row5_col4, #T_1113b_row8_col4, #T_1113b_row9_col4, #T_1113b_row10_col4, #T_1113b_row11_col4, #T_1113b_row12_col4, #T_1113b_row13_col4, #T_1113b_row14_col4, #T_1113b_row15_col4, #T_1113b_row16_col4, #T_1113b_row17_col4, #T_1113b_row19_col4, #T_1113b_row20_col4, #T_1113b_row21_col4, #T_1113b_row22_col4, #T_1113b_row23_col4, #T_1113b_row24_col4, #T_1113b_row25_col4, #T_1113b_row26_col4, #T_1113b_row29_col4, #T_1113b_row30_col4, #T_1113b_row31_col4, #T_1113b_row32_col4, #T_1113b_row33_col4, #T_1113b_row34_col4, #T_1113b_row36_col4, #T_1113b_row37_col4, #T_1113b_row38_col4, #T_1113b_row39_col4, #T_1113b_row41_col4, #T_1113b_row42_col4, #T_1113b_row44_col4, #T_1113b_row45_col4, #T_1113b_row46_col4, #T_1113b_row47_col4, #T_1113b_row48_col4, #T_1113b_row49_col4, #T_1113b_row51_col4, #T_1113b_row52_col4, #T_1113b_row55_col4, #T_1113b_row56_col4, #T_1113b_row57_col4, #T_1113b_row58_col4, #T_1113b_row59_col4, #T_1113b_row60_col4, #T_1113b_row61_col4, #T_1113b_row62_col4, #T_1113b_row63_col4, #T_1113b_row64_col4, #T_1113b_row65_col4, #T_1113b_row66_col4, #T_1113b_row67_col4, #T_1113b_row69_col4, #T_1113b_row70_col4, #T_1113b_row71_col4, #T_1113b_row72_col4, #T_1113b_row74_col4, #T_1113b_row75_col4, #T_1113b_row76_col4, #T_1113b_row78_col4, #T_1113b_row80_col4, #T_1113b_row81_col4, #T_1113b_row82_col4, #T_1113b_row83_col4, #T_1113b_row84_col4, #T_1113b_row85_col4, #T_1113b_row86_col4, #T_1113b_row87_col4, #T_1113b_row88_col4, #T_1113b_row89_col4, #T_1113b_row90_col4, #T_1113b_row91_col4, #T_1113b_row92_col4, #T_1113b_row93_col4, #T_1113b_row94_col4, #T_1113b_row96_col4, #T_1113b_row97_col4, #T_1113b_row99_col4 {
#   color: red;
# }
# #T_1113b_row0_col5, #T_1113b_row0_col6, #T_1113b_row11_col5, #T_1113b_row11_col6, #T_1113b_row13_col5, #T_1113b_row13_col6, #T_1113b_row30_col5, #T_1113b_row30_col6, #T_1113b_row83_col5, #T_1113b_row83_col6, #T_1113b_row90_col5, #T_1113b_row90_col6, #T_1113b_row93_col5, #T_1113b_row93_col6, #T_1113b_row97_col5, #T_1113b_row97_col6 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_1113b_row1_col5, #T_1113b_row2_col5, #T_1113b_row2_col6, #T_1113b_row6_col5, #T_1113b_row7_col5, #T_1113b_row7_col6, #T_1113b_row9_col5, #T_1113b_row10_col5, #T_1113b_row10_col6, #T_1113b_row20_col5, #T_1113b_row24_col5, #T_1113b_row28_col5, #T_1113b_row39_col5, #T_1113b_row45_col5, #T_1113b_row48_col5, #T_1113b_row48_col6, #T_1113b_row49_col5, #T_1113b_row52_col5, #T_1113b_row53_col5, #T_1113b_row55_col6, #T_1113b_row60_col5, #T_1113b_row65_col5, #T_1113b_row68_col5, #T_1113b_row69_col5, #T_1113b_row70_col5, #T_1113b_row73_col6, #T_1113b_row79_col5, #T_1113b_row82_col5, #T_1113b_row99_col5 {
#   background-color: #77c679;
#   color: #000000;
# }
# #T_1113b_row1_col6, #T_1113b_row24_col6, #T_1113b_row28_col6, #T_1113b_row53_col6 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_1113b_row3_col4, #T_1113b_row6_col4, #T_1113b_row7_col4, #T_1113b_row18_col4, #T_1113b_row27_col4, #T_1113b_row28_col4, #T_1113b_row35_col4, #T_1113b_row40_col4, #T_1113b_row43_col4, #T_1113b_row50_col4, #T_1113b_row53_col4, #T_1113b_row54_col4, #T_1113b_row68_col4, #T_1113b_row73_col4, #T_1113b_row77_col4, #T_1113b_row79_col4, #T_1113b_row95_col4, #T_1113b_row98_col4 {
#   color: green;
#   font-weight: bold;
# }
# #T_1113b_row3_col5, #T_1113b_row69_col6, #T_1113b_row76_col6 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_1113b_row3_col6, #T_1113b_row6_col6, #T_1113b_row79_col6 {
#   background-color: #056c39;
#   color: #f1f1f1;
# }
# #T_1113b_row4_col5, #T_1113b_row17_col5, #T_1113b_row18_col5, #T_1113b_row23_col5, #T_1113b_row25_col5, #T_1113b_row37_col5, #T_1113b_row37_col6, #T_1113b_row51_col5, #T_1113b_row55_col5, #T_1113b_row58_col5, #T_1113b_row61_col5, #T_1113b_row62_col5, #T_1113b_row67_col5, #T_1113b_row72_col5, #T_1113b_row81_col5, #T_1113b_row81_col6, #T_1113b_row86_col5, #T_1113b_row87_col5, #T_1113b_row89_col5, #T_1113b_row92_col5, #T_1113b_row95_col5, #T_1113b_row96_col5, #T_1113b_row98_col5 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_1113b_row4_col6, #T_1113b_row5_col5, #T_1113b_row5_col6, #T_1113b_row8_col5, #T_1113b_row12_col5, #T_1113b_row14_col5, #T_1113b_row15_col5, #T_1113b_row16_col5, #T_1113b_row19_col5, #T_1113b_row21_col5, #T_1113b_row22_col5, #T_1113b_row25_col6, #T_1113b_row27_col5, #T_1113b_row27_col6, #T_1113b_row29_col5, #T_1113b_row33_col5, #T_1113b_row35_col5, #T_1113b_row36_col5, #T_1113b_row38_col5, #T_1113b_row40_col5, #T_1113b_row41_col5, #T_1113b_row42_col5, #T_1113b_row43_col5, #T_1113b_row44_col5, #T_1113b_row56_col5, #T_1113b_row57_col5, #T_1113b_row59_col5, #T_1113b_row63_col5, #T_1113b_row73_col5, #T_1113b_row74_col5, #T_1113b_row75_col5, #T_1113b_row78_col5, #T_1113b_row80_col5, #T_1113b_row84_col5, #T_1113b_row85_col5, #T_1113b_row88_col5, #T_1113b_row94_col5, #T_1113b_row98_col6 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_1113b_row8_col6, #T_1113b_row9_col6, #T_1113b_row12_col6, #T_1113b_row26_col5, #T_1113b_row31_col5, #T_1113b_row32_col5, #T_1113b_row34_col5, #T_1113b_row35_col6, #T_1113b_row43_col6, #T_1113b_row44_col6, #T_1113b_row46_col5, #T_1113b_row47_col5, #T_1113b_row50_col5, #T_1113b_row50_col6, #T_1113b_row54_col5, #T_1113b_row59_col6, #T_1113b_row65_col6, #T_1113b_row66_col5, #T_1113b_row71_col5, #T_1113b_row71_col6, #T_1113b_row77_col5, #T_1113b_row78_col6, #T_1113b_row88_col6, #T_1113b_row91_col5 {
#   background-color: #379e54;
#   color: #f1f1f1;
# }
# #T_1113b_row14_col6, #T_1113b_row33_col6, #T_1113b_row84_col6 {
#   background-color: #b1df90;
#   color: #000000;
# }
# #T_1113b_row15_col6, #T_1113b_row21_col6, #T_1113b_row22_col6, #T_1113b_row94_col6 {
#   background-color: #58b669;
#   color: #f1f1f1;
# }
# #T_1113b_row16_col6, #T_1113b_row23_col6, #T_1113b_row29_col6, #T_1113b_row57_col6, #T_1113b_row61_col6, #T_1113b_row63_col6, #T_1113b_row74_col6, #T_1113b_row85_col6, #T_1113b_row86_col6, #T_1113b_row87_col6, #T_1113b_row92_col6, #T_1113b_row96_col6 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_1113b_row17_col6, #T_1113b_row58_col6, #T_1113b_row89_col6 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_1113b_row18_col6, #T_1113b_row19_col6, #T_1113b_row36_col6, #T_1113b_row38_col6, #T_1113b_row40_col6, #T_1113b_row67_col6, #T_1113b_row72_col6, #T_1113b_row75_col6, #T_1113b_row95_col6 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_1113b_row20_col6, #T_1113b_row39_col6, #T_1113b_row60_col6, #T_1113b_row82_col6, #T_1113b_row99_col6 {
#   background-color: #97d385;
#   color: #000000;
# }
# #T_1113b_row26_col6, #T_1113b_row54_col6, #T_1113b_row77_col6 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_1113b_row31_col6 {
#   background-color: #006435;
#   color: #f1f1f1;
# }
# #T_1113b_row32_col6, #T_1113b_row46_col6, #T_1113b_row47_col6, #T_1113b_row66_col6, #T_1113b_row91_col6 {
#   background-color: #15793e;
#   color: #f1f1f1;
# }
# #T_1113b_row34_col6 {
#   background-color: #288a47;
#   color: #f1f1f1;
# }
# #T_1113b_row41_col6, #T_1113b_row42_col6 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_1113b_row45_col6, #T_1113b_row52_col6, #T_1113b_row70_col6 {
#   background-color: #64bc6f;
#   color: #f1f1f1;
# }
# #T_1113b_row49_col6, #T_1113b_row68_col6 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_1113b_row51_col6 {
#   background-color: #e0f3a8;
#   color: #000000;
# }
# #T_1113b_row56_col6, #T_1113b_row80_col6 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_1113b_row62_col6 {
#   background-color: #f3fab6;
#   color: #000000;
# }
# #T_1113b_row64_col5, #T_1113b_row64_col6, #T_1113b_row76_col5 {
#   background-color: #0b713b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1113b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1113b_level0_col0" class="col_heading level0 col0" >Target Paper</th>
#       <th id="T_1113b_level0_col1" class="col_heading level0 col1" >Cited Papers</th>
#       <th id="T_1113b_level0_col2" class="col_heading level0 col2" >Corpus Size</th>
#       <th id="T_1113b_level0_col3" class="col_hea
#   Top-1 accuracy : 18.0%
#   Mean Hits@n%   : 23.09%
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#   Method: TFIDF
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# <style type="text/css">
# #T_b696b_row0_col4, #T_b696b_row1_col4, #T_b696b_row4_col4, #T_b696b_row5_col4, #T_b696b_row10_col4, #T_b696b_row11_col4, #T_b696b_row12_col4, #T_b696b_row13_col4, #T_b696b_row14_col4, #T_b696b_row15_col4, #T_b696b_row17_col4, #T_b696b_row19_col4, #T_b696b_row20_col4, #T_b696b_row21_col4, #T_b696b_row23_col4, #T_b696b_row24_col4, #T_b696b_row25_col4, #T_b696b_row26_col4, #T_b696b_row28_col4, #T_b696b_row29_col4, #T_b696b_row30_col4, #T_b696b_row31_col4, #T_b696b_row32_col4, #T_b696b_row33_col4, #T_b696b_row34_col4, #T_b696b_row36_col4, #T_b696b_row37_col4, #T_b696b_row38_col4, #T_b696b_row41_col4, #T_b696b_row43_col4, #T_b696b_row44_col4, #T_b696b_row45_col4, #T_b696b_row46_col4, #T_b696b_row47_col4, #T_b696b_row49_col4, #T_b696b_row52_col4, #T_b696b_row55_col4, #T_b696b_row57_col4, #T_b696b_row59_col4, #T_b696b_row60_col4, #T_b696b_row61_col4, #T_b696b_row62_col4, #T_b696b_row64_col4, #T_b696b_row65_col4, #T_b696b_row67_col4, #T_b696b_row68_col4, #T_b696b_row70_col4, #T_b696b_row71_col4, #T_b696b_row72_col4, #T_b696b_row74_col4, #T_b696b_row76_col4, #T_b696b_row78_col4, #T_b696b_row80_col4, #T_b696b_row81_col4, #T_b696b_row82_col4, #T_b696b_row83_col4, #T_b696b_row84_col4, #T_b696b_row85_col4, #T_b696b_row86_col4, #T_b696b_row87_col4, #T_b696b_row89_col4, #T_b696b_row90_col4, #T_b696b_row91_col4, #T_b696b_row92_col4, #T_b696b_row93_col4, #T_b696b_row94_col4, #T_b696b_row96_col4, #T_b696b_row97_col4 {
#   color: red;
# }
# #T_b696b_row0_col5, #T_b696b_row13_col5, #T_b696b_row21_col5, #T_b696b_row55_col5, #T_b696b_row61_col5, #T_b696b_row67_col5, #T_b696b_row83_col5, #T_b696b_row93_col5, #T_b696b_row94_col5 {
#   background-color: #f7fcb9;
#   color: #000000;
# }
# #T_b696b_row0_col6, #T_b696b_row2_col6, #T_b696b_row5_col6 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_b696b_row1_col5, #T_b696b_row26_col5, #T_b696b_row35_col5, #T_b696b_row50_col5, #T_b696b_row68_col5, #T_b696b_row70_col5, #T_b696b_row79_col5 {
#   background-color: #40aa5c;
#   color: #f1f1f1;
# }
# #T_b696b_row1_col6, #T_b696b_row8_col6, #T_b696b_row11_col6, #T_b696b_row25_col6, #T_b696b_row64_col6, #T_b696b_row69_col6, #T_b696b_row88_col6, #T_b696b_row98_col6 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_b696b_row2_col4, #T_b696b_row3_col4, #T_b696b_row6_col4, #T_b696b_row7_col4, #T_b696b_row8_col4, #T_b696b_row9_col4, #T_b696b_row16_col4, #T_b696b_row18_col4, #T_b696b_row22_col4, #T_b696b_row27_col4, #T_b696b_row35_col4, #T_b696b_row39_col4, #T_b696b_row40_col4, #T_b696b_row42_col4, #T_b696b_row48_col4, #T_b696b_row50_col4, #T_b696b_row51_col4, #T_b696b_row53_col4, #T_b696b_row54_col4, #T_b696b_row56_col4, #T_b696b_row58_col4, #T_b696b_row63_col4, #T_b696b_row66_col4, #T_b696b_row69_col4, #T_b696b_row73_col4, #T_b696b_row75_col4, #T_b696b_row77_col4, #T_b696b_row79_col4, #T_b696b_row88_col4, #T_b696b_row95_col4, #T_b696b_row98_col4, #T_b696b_row99_col4 {
#   color: green;
#   font-weight: bold;
# }
# #T_b696b_row2_col5, #T_b696b_row4_col5, #T_b696b_row5_col5, #T_b696b_row12_col5, #T_b696b_row15_col5, #T_b696b_row22_col5, #T_b696b_row23_col5, #T_b696b_row28_col5, #T_b696b_row36_col5, #T_b696b_row42_col5, #T_b696b_row43_col5, #T_b696b_row44_col5, #T_b696b_row51_col5, #T_b696b_row56_col5, #T_b696b_row57_col5, #T_b696b_row73_col5, #T_b696b_row74_col5, #T_b696b_row78_col5, #T_b696b_row80_col5, #T_b696b_row86_col5, #T_b696b_row90_col5, #T_b696b_row92_col5 {
#   background-color: #d9f0a3;
#   color: #000000;
# }
# #T_b696b_row3_col5, #T_b696b_row39_col5, #T_b696b_row64_col5, #T_b696b_row77_col5, #T_b696b_row99_col5 {
#   background-color: #228343;
#   color: #f1f1f1;
# }
# #T_b696b_row3_col6, #T_b696b_row6_col6, #T_b696b_row18_col6, #T_b696b_row39_col6, #T_b696b_row72_col6, #T_b696b_row95_col6, #T_b696b_row99_col6 {
#   background-color: #72c376;
#   color: #000000;
# }
# #T_b696b_row4_col6, #T_b696b_row7_col6, #T_b696b_row10_col6, #T_b696b_row12_col6, #T_b696b_row13_col6, #T_b696b_row37_col6, #T_b696b_row43_col6, #T_b696b_row44_col6, #T_b696b_row78_col6 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_b696b_row6_col5, #T_b696b_row8_col5, #T_b696b_row11_col5, #T_b696b_row16_col5, #T_b696b_row18_col5, #T_b696b_row25_col5, #T_b696b_row32_col5, #T_b696b_row41_col5, #T_b696b_row46_col5, #T_b696b_row48_col5, #T_b696b_row52_col5, #T_b696b_row62_col5, #T_b696b_row63_col5, #T_b696b_row69_col5, #T_b696b_row71_col5, #T_b696b_row72_col5, #T_b696b_row76_col5, #T_b696b_row81_col5, #T_b696b_row84_col5, #T_b696b_row88_col5, #T_b696b_row89_col5, #T_b696b_row91_col5, #T_b696b_row95_col5, #T_b696b_row96_col5, #T_b696b_row98_col5 {
#   background-color: #acdd8e;
#   color: #000000;
# }
# #T_b696b_row7_col5, #T_b696b_row9_col5, #T_b696b_row10_col5, #T_b696b_row14_col5, #T_b696b_row17_col5, #T_b696b_row19_col5, #T_b696b_row20_col5, #T_b696b_row24_col5, #T_b696b_row29_col5, #T_b696b_row31_col5, #T_b696b_row34_col5, #T_b696b_row37_col5, #T_b696b_row38_col5, #T_b696b_row40_col5, #T_b696b_row45_col5, #T_b696b_row47_col5, #T_b696b_row49_col5, #T_b696b_row50_col6, #T_b696b_row53_col5, #T_b696b_row58_col5, #T_b696b_row59_col5, #T_b696b_row60_col5, #T_b696b_row65_col5, #T_b696b_row66_col5, #T_b696b_row75_col5, #T_b696b_row82_col5, #T_b696b_row85_col5 {
#   background-color: #77c679;
#   color: #000000;
# }
# #T_b696b_row9_col6, #T_b696b_row31_col6, #T_b696b_row65_col6 {
#   background-color: #69bf72;
#   color: #000000;
# }
# #T_b696b_row14_col6, #T_b696b_row34_col6, #T_b696b_row45_col6 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_b696b_row15_col6, #T_b696b_row19_col6, #T_b696b_row20_col6, #T_b696b_row22_col6, #T_b696b_row38_col6, #T_b696b_row40_col6, #T_b696b_row60_col6, #T_b696b_row75_col6, #T_b696b_row82_col6 {
#   background-color: #b9e294;
#   color: #000000;
# }
# #T_b696b_row16_col6, #T_b696b_row32_col6, #T_b696b_row46_col6, #T_b696b_row63_col6, #T_b696b_row76_col6, #T_b696b_row89_col6, #T_b696b_row91_col6 {
#   background-color: #b2df90;
#   color: #000000;
# }
# #T_b696b_row17_col6, #T_b696b_row23_col6, #T_b696b_row24_col6, #T_b696b_row29_col6, #T_b696b_row47_col6, #T_b696b_row53_col6, #T_b696b_row58_col6, #T_b696b_row66_col6, #T_b696b_row85_col6, #T_b696b_row86_col6, #T_b696b_row92_col6 {
#   background-color: #81ca7d;
#   color: #000000;
# }
# #T_b696b_row21_col6, #T_b696b_row36_col6, #T_b696b_row67_col6, #T_b696b_row94_col6 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_b696b_row26_col6, #T_b696b_row68_col6 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_b696b_row27_col5, #T_b696b_row35_col6 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_b696b_row27_col6, #T_b696b_row59_col6 {
#   background-color: #15793e;
#   color: #f1f1f1;
# }
# #T_b696b_row28_col6, #T_b696b_row57_col6, #T_b696b_row61_col6, #T_b696b_row74_col6, #T_b696b_row83_col6 {
#   background-color: #dcf1a5;
#   color: #000000;
# }
# #T_b696b_row30_col5, #T_b696b_row30_col6, #T_b696b_row33_col5, #T_b696b_row33_col6, #T_b696b_row87_col5, #T_b696b_row87_col6, #T_b696b_row97_col5, #T_b696b_row97_col6 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_b696b_row41_col6 {
#   background-color: #d0ec9f;
#   color: #000000;
# }
# #T_b696b_row42_col6 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_b696b_row48_col6, #T_b696b_row55_col6, #T_b696b_row71_col6, #T_b696b_row73_col6, #T_b696b_row81_col6, #T_b696b_row90_col6 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_b696b_row49_col6 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_b696b_row51_col6, #T_b696b_row56_col6, #T_b696b_row80_col6 {
#   background-color: #d3eda0;
#   color: #000000;
# }
# #T_b696b_row52_col6, #T_b696b_row84_col6 {
#   background-color: #bee596;
#   color: #000000;
# }
# #T_b696b_row54_col5 {
#   background-color: #006737;
#   color: #f1f1f1;
# }
# #T_b696b_row54_col6 {
#   background-color: #3ca458;
#   color: #f1f1f1;
# }
# #T_b696b_row62_col6 {
#   background-color: #d7efa2;
#   color: #000000;
# }
# #T_b696b_row70_col6 {
#   background-color: #64bc6f;
#   color: #f1f1f1;
# }
# #T_b696b_row77_col6 {
#   background-color: #61bb6d;
#   color: #f1f1f1;
# }
# #T_b696b_row79_col6 {
#   background-color: #056c39;
#   color: #f1f1f1;
# }
# #T_b696b_row93_col6 {
#   background-color:
#   Top-1 accuracy : 32.0%
#   Mean Hits@n%   : 33.41%
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#   Method: MINILM
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# <style type="text/css">
# #T_9fdeb_row0_col4, #T_9fdeb_row2_col4, #T_9fdeb_row10_col4, #T_9fdeb_row11_col4, #T_9fdeb_row12_col4, #T_9fdeb_row13_col4, #T_9fdeb_row14_col4, #T_9fdeb_row15_col4, #T_9fdeb_row16_col4, #T_9fdeb_row17_col4, #T_9fdeb_row18_col4, #T_9fdeb_row19_col4, #T_9fdeb_row20_col4, #T_9fdeb_row21_col4, #T_9fdeb_row22_col4, #T_9fdeb_row23_col4, #T_9fdeb_row24_col4, #T_9fdeb_row26_col4, #T_9fdeb_row27_col4, #T_9fdeb_row28_col4, #T_9fdeb_row29_col4, #T_9fdeb_row30_col4, #T_9fdeb_row31_col4, #T_9fdeb_row32_col4, #T_9fdeb_row33_col4, #T_9fdeb_row34_col4, #T_9fdeb_row35_col4, #T_9fdeb_row36_col4, #T_9fdeb_row37_col4, #T_9fdeb_row39_col4, #T_9fdeb_row42_col4, #T_9fdeb_row43_col4, #T_9fdeb_row44_col4, #T_9fdeb_row47_col4, #T_9fdeb_row49_col4, #T_9fdeb_row50_col4, #T_9fdeb_row55_col4, #T_9fdeb_row57_col4, #T_9fdeb_row58_col4, #T_9fdeb_row60_col4, #T_9fdeb_row61_col4, #T_9fdeb_row62_col4, #T_9fdeb_row63_col4, #T_9fdeb_row64_col4, #T_9fdeb_row65_col4, #T_9fdeb_row67_col4, #T_9fdeb_row68_col4, #T_9fdeb_row70_col4, #T_9fdeb_row71_col4, #T_9fdeb_row72_col4, #T_9fdeb_row74_col4, #T_9fdeb_row75_col4, #T_9fdeb_row76_col4, #T_9fdeb_row78_col4, #T_9fdeb_row80_col4, #T_9fdeb_row81_col4, #T_9fdeb_row82_col4, #T_9fdeb_row83_col4, #T_9fdeb_row85_col4, #T_9fdeb_row86_col4, #T_9fdeb_row87_col4, #T_9fdeb_row90_col4, #T_9fdeb_row91_col4, #T_9fdeb_row92_col4, #T_9fdeb_row93_col4, #T_9fdeb_row94_col4, #T_9fdeb_row97_col4 {
#   color: red;
# }
# #T_9fdeb_row0_col5, #T_9fdeb_row18_col5, #T_9fdeb_row20_col5, #T_9fdeb_row33_col5, #T_9fdeb_row33_col6, #T_9fdeb_row61_col5, #T_9fdeb_row62_col5, #T_9fdeb_row78_col5, #T_9fdeb_row83_col5, #T_9fdeb_row87_col5, #T_9fdeb_row89_col5, #T_9fdeb_row90_col5, #T_9fdeb_row94_col5 {
#   background-color: #f7fcb9;
#   color: #000000;
# }
# #T_9fdeb_row0_col6, #T_9fdeb_row78_col6 {
#   background-color: #ddf2a6;
#   color: #000000;
# }
# #T_9fdeb_row1_col4, #T_9fdeb_row3_col4, #T_9fdeb_row4_col4, #T_9fdeb_row5_col4, #T_9fdeb_row6_col4, #T_9fdeb_row7_col4, #T_9fdeb_row8_col4, #T_9fdeb_row9_col4, #T_9fdeb_row25_col4, #T_9fdeb_row38_col4, #T_9fdeb_row40_col4, #T_9fdeb_row41_col4, #T_9fdeb_row45_col4, #T_9fdeb_row46_col4, #T_9fdeb_row48_col4, #T_9fdeb_row51_col4, #T_9fdeb_row52_col4, #T_9fdeb_row53_col4, #T_9fdeb_row54_col4, #T_9fdeb_row56_col4, #T_9fdeb_row59_col4, #T_9fdeb_row66_col4, #T_9fdeb_row69_col4, #T_9fdeb_row73_col4, #T_9fdeb_row77_col4, #T_9fdeb_row79_col4, #T_9fdeb_row84_col4, #T_9fdeb_row88_col4, #T_9fdeb_row89_col4, #T_9fdeb_row95_col4, #T_9fdeb_row96_col4, #T_9fdeb_row98_col4, #T_9fdeb_row99_col4 {
#   color: green;
#   font-weight: bold;
# }
# #T_9fdeb_row1_col5, #T_9fdeb_row5_col5, #T_9fdeb_row6_col5, #T_9fdeb_row14_col5, #T_9fdeb_row15_col5, #T_9fdeb_row19_col5, #T_9fdeb_row21_col5, #T_9fdeb_row29_col5, #T_9fdeb_row31_col5, #T_9fdeb_row34_col5, #T_9fdeb_row41_col5, #T_9fdeb_row44_col5, #T_9fdeb_row49_col5, #T_9fdeb_row57_col5, #T_9fdeb_row58_col5, #T_9fdeb_row69_col5, #T_9fdeb_row70_col5, #T_9fdeb_row75_col5, #T_9fdeb_row77_col5, #T_9fdeb_row85_col5, #T_9fdeb_row92_col5, #T_9fdeb_row93_col5, #T_9fdeb_row96_col5, #T_9fdeb_row98_col5 {
#   background-color: #acdd8e;
#   color: #000000;
# }
# #T_9fdeb_row1_col6, #T_9fdeb_row29_col6, #T_9fdeb_row57_col6, #T_9fdeb_row58_col6, #T_9fdeb_row85_col6, #T_9fdeb_row93_col6 {
#   background-color: #9ad587;
#   color: #000000;
# }
# #T_9fdeb_row2_col5, #T_9fdeb_row8_col5, #T_9fdeb_row9_col5, #T_9fdeb_row10_col5, #T_9fdeb_row17_col5, #T_9fdeb_row25_col5, #T_9fdeb_row26_col5, #T_9fdeb_row35_col5, #T_9fdeb_row38_col5, #T_9fdeb_row42_col5, #T_9fdeb_row45_col5, #T_9fdeb_row51_col5, #T_9fdeb_row53_col5, #T_9fdeb_row56_col5, #T_9fdeb_row59_col5, #T_9fdeb_row60_col5, #T_9fdeb_row65_col5, #T_9fdeb_row68_col5, #T_9fdeb_row71_col5, #T_9fdeb_row76_col5, #T_9fdeb_row79_col5, #T_9fdeb_row81_col5, #T_9fdeb_row91_col5 {
#   background-color: #77c679;
#   color: #000000;
# }
# #T_9fdeb_row2_col6, #T_9fdeb_row4_col6, #T_9fdeb_row10_col6, #T_9fdeb_row11_col6, #T_9fdeb_row12_col6, #T_9fdeb_row31_col6, #T_9fdeb_row43_col6, #T_9fdeb_row71_col6, #T_9fdeb_row81_col6, #T_9fdeb_row88_col6 {
#   background-color: #86cc7f;
#   color: #000000;
# }
# #T_9fdeb_row3_col5, #T_9fdeb_row22_col6, #T_9fdeb_row54_col5 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_9fdeb_row3_col6, #T_9fdeb_row79_col6 {
#   background-color: #15793e;
#   color: #f1f1f1;
# }
# #T_9fdeb_row4_col5, #T_9fdeb_row11_col5, #T_9fdeb_row12_col5, #T_9fdeb_row23_col5, #T_9fdeb_row28_col5, #T_9fdeb_row36_col5, #T_9fdeb_row43_col5, #T_9fdeb_row52_col5, #T_9fdeb_row55_col5, #T_9fdeb_row67_col5, #T_9fdeb_row72_col5, #T_9fdeb_row73_col5, #T_9fdeb_row80_col5, #T_9fdeb_row82_col5, #T_9fdeb_row86_col5, #T_9fdeb_row88_col5, #T_9fdeb_row95_col5 {
#   background-color: #d9f0a3;
#   color: #000000;
# }
# #T_9fdeb_row5_col6, #T_9fdeb_row73_col6 {
#   background-color: #b6e192;
#   color: #000000;
# }
# #T_9fdeb_row6_col6, #T_9fdeb_row15_col6, #T_9fdeb_row21_col6, #T_9fdeb_row40_col6, #T_9fdeb_row99_col6 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_9fdeb_row7_col5, #T_9fdeb_row24_col5, #T_9fdeb_row27_col5, #T_9fdeb_row32_col5, #T_9fdeb_row37_col5, #T_9fdeb_row40_col5, #T_9fdeb_row63_col5, #T_9fdeb_row74_col5, #T_9fdeb_row84_col5, #T_9fdeb_row99_col5 {
#   background-color: #228343;
#   color: #f1f1f1;
# }
# #T_9fdeb_row7_col6, #T_9fdeb_row16_col6, #T_9fdeb_row27_col6, #T_9fdeb_row37_col6, #T_9fdeb_row44_col6, #T_9fdeb_row46_col6, #T_9fdeb_row47_col6, #T_9fdeb_row55_col6, #T_9fdeb_row66_col6, #T_9fdeb_row69_col6, #T_9fdeb_row98_col6 {
#   background-color: #2f934d;
#   color: #f1f1f1;
# }
# #T_9fdeb_row8_col6, #T_9fdeb_row25_col6, #T_9fdeb_row35_col6, #T_9fdeb_row59_col6 {
#   background-color: #005830;
#   color: #f1f1f1;
# }
# #T_9fdeb_row9_col6, #T_9fdeb_row51_col6, #T_9fdeb_row56_col6, #T_9fdeb_row65_col6 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_9fdeb_row13_col5, #T_9fdeb_row13_col6, #T_9fdeb_row30_col5, #T_9fdeb_row30_col6, #T_9fdeb_row97_col5, #T_9fdeb_row97_col6 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_9fdeb_row14_col6, #T_9fdeb_row34_col6, #T_9fdeb_row70_col6 {
#   background-color: #abdc8d;
#   color: #000000;
# }
# #T_9fdeb_row16_col5, #T_9fdeb_row22_col5, #T_9fdeb_row39_col5, #T_9fdeb_row46_col5, #T_9fdeb_row47_col5, #T_9fdeb_row50_col5, #T_9fdeb_row66_col5 {
#   background-color: #40aa5c;
#   color: #f1f1f1;
# }
# #T_9fdeb_row17_col6, #T_9fdeb_row23_col6, #T_9fdeb_row53_col6, #T_9fdeb_row76_col6, #T_9fdeb_row86_col6, #T_9fdeb_row91_col6 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_9fdeb_row18_col6, #T_9fdeb_row36_col6, #T_9fdeb_row82_col6, #T_9fdeb_row94_col6 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_9fdeb_row19_col6, #T_9fdeb_row75_col6 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_9fdeb_row20_col6, #T_9fdeb_row62_col6 {
#   background-color: #f9fdc2;
#   color: #000000;
# }
# #T_9fdeb_row24_col6, #T_9fdeb_row32_col6, #T_9fdeb_row63_col6, #T_9fdeb_row74_col6, #T_9fdeb_row92_col6, #T_9fdeb_row96_col6 {
#   background-color: #096f3a;
#   color: #f1f1f1;
# }
# #T_9fdeb_row26_col6, #T_9fdeb_row42_col6, #T_9fdeb_row68_col6 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_9fdeb_row28_col6, #T_9fdeb_row61_col6, #T_9fdeb_row83_col6, #T_9fdeb_row87_col6 {
#   background-color: #cfec9e;
#   color: #000000;
# }
# #T_9fdeb_row38_col6, #T_9fdeb_row60_col6, #T_9fdeb_row67_col6, #T_9fdeb_row72_col6, #T_9fdeb_row95_col6 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_9fdeb_row39_col6 {
#   background-color: #79c679;
#   color: #000000;
# }
# #T_9fdeb_row41_col6, #T_9fdeb_row49_col6, #T_9fdeb_row77_col6 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_9fdeb_row45_col6 {
#   background-color: #74c477;
#   color: #000000;
# }
# #T_9fdeb_row48_col5, #T_9fdeb_row64_col5 {
#   background-color: #006737;
#   color: #f1f1f1;
# }
# #T_9fdeb_row48_col6, #T_9fdeb_row64_col6 {
#   background-color: #10743c;
#   color: #f1f1f1;
# }
# #T_9fdeb_row50_col6 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_9fdeb_row52_col6 {
#   background-color: #d7efa2;
#   color: #000000;
# }
# #T_9fdeb_row54_col6 {
#   background-color: #036b38;
#   color: #f1f1f1;
# }
# #T_9fdeb_row80_col6 {
#   backgroun
#   Top-1 accuracy : 33.0%
#   Mean Hits@n%   : 35.90%
#
# ════════════════════════════════════════════════════════════════════════════════════════════════════
#   Method: SPECTER2
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# <style type="text/css">
# #T_ed7eb_row0_col4, #T_ed7eb_row2_col4, #T_ed7eb_row4_col4, #T_ed7eb_row9_col4, #T_ed7eb_row10_col4, #T_ed7eb_row11_col4, #T_ed7eb_row12_col4, #T_ed7eb_row13_col4, #T_ed7eb_row15_col4, #T_ed7eb_row16_col4, #T_ed7eb_row17_col4, #T_ed7eb_row18_col4, #T_ed7eb_row19_col4, #T_ed7eb_row20_col4, #T_ed7eb_row21_col4, #T_ed7eb_row22_col4, #T_ed7eb_row23_col4, #T_ed7eb_row24_col4, #T_ed7eb_row26_col4, #T_ed7eb_row28_col4, #T_ed7eb_row29_col4, #T_ed7eb_row30_col4, #T_ed7eb_row31_col4, #T_ed7eb_row32_col4, #T_ed7eb_row33_col4, #T_ed7eb_row34_col4, #T_ed7eb_row35_col4, #T_ed7eb_row36_col4, #T_ed7eb_row37_col4, #T_ed7eb_row38_col4, #T_ed7eb_row39_col4, #T_ed7eb_row40_col4, #T_ed7eb_row41_col4, #T_ed7eb_row43_col4, #T_ed7eb_row44_col4, #T_ed7eb_row45_col4, #T_ed7eb_row47_col4, #T_ed7eb_row48_col4, #T_ed7eb_row49_col4, #T_ed7eb_row51_col4, #T_ed7eb_row52_col4, #T_ed7eb_row55_col4, #T_ed7eb_row57_col4, #T_ed7eb_row58_col4, #T_ed7eb_row60_col4, #T_ed7eb_row61_col4, #T_ed7eb_row62_col4, #T_ed7eb_row63_col4, #T_ed7eb_row64_col4, #T_ed7eb_row65_col4, #T_ed7eb_row66_col4, #T_ed7eb_row67_col4, #T_ed7eb_row68_col4, #T_ed7eb_row69_col4, #T_ed7eb_row70_col4, #T_ed7eb_row71_col4, #T_ed7eb_row72_col4, #T_ed7eb_row74_col4, #T_ed7eb_row75_col4, #T_ed7eb_row76_col4, #T_ed7eb_row78_col4, #T_ed7eb_row80_col4, #T_ed7eb_row81_col4, #T_ed7eb_row82_col4, #T_ed7eb_row83_col4, #T_ed7eb_row84_col4, #T_ed7eb_row85_col4, #T_ed7eb_row86_col4, #T_ed7eb_row87_col4, #T_ed7eb_row90_col4, #T_ed7eb_row91_col4, #T_ed7eb_row92_col4, #T_ed7eb_row93_col4, #T_ed7eb_row94_col4, #T_ed7eb_row96_col4, #T_ed7eb_row97_col4 {
#   color: red;
# }
# #T_ed7eb_row0_col5, #T_ed7eb_row4_col5, #T_ed7eb_row12_col5, #T_ed7eb_row15_col5, #T_ed7eb_row30_col5, #T_ed7eb_row33_col5, #T_ed7eb_row36_col5, #T_ed7eb_row43_col5, #T_ed7eb_row55_col5, #T_ed7eb_row61_col5, #T_ed7eb_row62_col5, #T_ed7eb_row67_col5, #T_ed7eb_row86_col5, #T_ed7eb_row87_col5, #T_ed7eb_row90_col5, #T_ed7eb_row92_col5 {
#   background-color: #f9fdc2;
#   color: #000000;
# }
# #T_ed7eb_row0_col6, #T_ed7eb_row2_col6, #T_ed7eb_row4_col6, #T_ed7eb_row12_col6, #T_ed7eb_row30_col6, #T_ed7eb_row43_col6 {
#   background-color: #e1f3a9;
#   color: #000000;
# }
# #T_ed7eb_row1_col4, #T_ed7eb_row3_col4, #T_ed7eb_row5_col4, #T_ed7eb_row6_col4, #T_ed7eb_row7_col4, #T_ed7eb_row8_col4, #T_ed7eb_row14_col4, #T_ed7eb_row25_col4, #T_ed7eb_row27_col4, #T_ed7eb_row42_col4, #T_ed7eb_row46_col4, #T_ed7eb_row50_col4, #T_ed7eb_row53_col4, #T_ed7eb_row54_col4, #T_ed7eb_row56_col4, #T_ed7eb_row59_col4, #T_ed7eb_row73_col4, #T_ed7eb_row77_col4, #T_ed7eb_row79_col4, #T_ed7eb_row88_col4, #T_ed7eb_row89_col4, #T_ed7eb_row95_col4, #T_ed7eb_row98_col4, #T_ed7eb_row99_col4 {
#   color: green;
#   font-weight: bold;
# }
# #T_ed7eb_row1_col5, #T_ed7eb_row16_col5, #T_ed7eb_row19_col5, #T_ed7eb_row25_col5, #T_ed7eb_row26_col5, #T_ed7eb_row26_col6, #T_ed7eb_row34_col5, #T_ed7eb_row38_col5, #T_ed7eb_row40_col5, #T_ed7eb_row42_col5, #T_ed7eb_row42_col6, #T_ed7eb_row45_col5, #T_ed7eb_row46_col5, #T_ed7eb_row48_col5, #T_ed7eb_row56_col5, #T_ed7eb_row60_col5, #T_ed7eb_row63_col5, #T_ed7eb_row70_col5, #T_ed7eb_row81_col5, #T_ed7eb_row95_col5 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_ed7eb_row1_col6, #T_ed7eb_row16_col6, #T_ed7eb_row23_col6, #T_ed7eb_row46_col6, #T_ed7eb_row63_col6, #T_ed7eb_row83_col6, #T_ed7eb_row96_col6 {
#   background-color: #6fc174;
#   color: #000000;
# }
# #T_ed7eb_row2_col5, #T_ed7eb_row6_col5, #T_ed7eb_row8_col5, #T_ed7eb_row11_col5, #T_ed7eb_row14_col5, #T_ed7eb_row17_col5, #T_ed7eb_row18_col5, #T_ed7eb_row20_col5, #T_ed7eb_row21_col5, #T_ed7eb_row23_col5, #T_ed7eb_row29_col5, #T_ed7eb_row35_col5, #T_ed7eb_row41_col5, #T_ed7eb_row41_col6, #T_ed7eb_row44_col5, #T_ed7eb_row49_col5, #T_ed7eb_row49_col6, #T_ed7eb_row51_col5, #T_ed7eb_row57_col5, #T_ed7eb_row65_col5, #T_ed7eb_row75_col5, #T_ed7eb_row77_col5, #T_ed7eb_row77_col6, #T_ed7eb_row83_col5, #T_ed7eb_row84_col5, #T_ed7eb_row88_col5, #T_ed7eb_row89_col5, #T_ed7eb_row96_col5 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_ed7eb_row3_col5, #T_ed7eb_row7_col5, #T_ed7eb_row9_col5, #T_ed7eb_row74_col5, #T_ed7eb_row79_col5 {
#   background-color: #77c679;
#   color: #000000;
# }
# #T_ed7eb_row3_col6 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_ed7eb_row5_col5, #T_ed7eb_row10_col5, #T_ed7eb_row22_col5, #T_ed7eb_row24_col5, #T_ed7eb_row28_col5, #T_ed7eb_row31_col5, #T_ed7eb_row32_col5, #T_ed7eb_row37_col5, #T_ed7eb_row52_col5, #T_ed7eb_row53_col5, #T_ed7eb_row59_col5, #T_ed7eb_row66_col5, #T_ed7eb_row68_col5, #T_ed7eb_row68_col6, #T_ed7eb_row69_col5, #T_ed7eb_row71_col5, #T_ed7eb_row73_col5, #T_ed7eb_row76_col5, #T_ed7eb_row80_col5, #T_ed7eb_row82_col5, #T_ed7eb_row85_col5, #T_ed7eb_row91_col5, #T_ed7eb_row94_col5, #T_ed7eb_row98_col5 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_ed7eb_row5_col6, #T_ed7eb_row10_col6, #T_ed7eb_row37_col6, #T_ed7eb_row55_col6, #T_ed7eb_row71_col6 {
#   background-color: #bee596;
#   color: #000000;
# }
# #T_ed7eb_row6_col6, #T_ed7eb_row18_col6, #T_ed7eb_row19_col6, #T_ed7eb_row21_col6, #T_ed7eb_row38_col6, #T_ed7eb_row40_col6, #T_ed7eb_row60_col6 {
#   background-color: #aedd8e;
#   color: #000000;
# }
# #T_ed7eb_row7_col6 {
#   background-color: #66bd70;
#   color: #f1f1f1;
# }
# #T_ed7eb_row8_col6, #T_ed7eb_row11_col6, #T_ed7eb_row31_col6, #T_ed7eb_row35_col6, #T_ed7eb_row44_col6, #T_ed7eb_row48_col6, #T_ed7eb_row80_col6, #T_ed7eb_row81_col6, #T_ed7eb_row88_col6 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_ed7eb_row9_col6 {
#   background-color: #2a8d49;
#   color: #f1f1f1;
# }
# #T_ed7eb_row13_col5, #T_ed7eb_row13_col6, #T_ed7eb_row72_col5, #T_ed7eb_row72_col6, #T_ed7eb_row78_col5, #T_ed7eb_row78_col6, #T_ed7eb_row93_col5, #T_ed7eb_row93_col6, #T_ed7eb_row97_col5, #T_ed7eb_row97_col6 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_ed7eb_row14_col6, #T_ed7eb_row84_col6 {
#   background-color: #ddf1a6;
#   color: #000000;
# }
# #T_ed7eb_row15_col6, #T_ed7eb_row20_col6, #T_ed7eb_row67_col6, #T_ed7eb_row75_col6 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_ed7eb_row17_col6, #T_ed7eb_row29_col6, #T_ed7eb_row57_col6, #T_ed7eb_row61_col6, #T_ed7eb_row86_col6, #T_ed7eb_row87_col6, #T_ed7eb_row89_col6, #T_ed7eb_row92_col6 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# #T_ed7eb_row22_col6, #T_ed7eb_row39_col6, #T_ed7eb_row94_col6, #T_ed7eb_row99_col6 {
#   background-color: #5fba6c;
#   color: #f1f1f1;
# }
# #T_ed7eb_row24_col6, #T_ed7eb_row28_col6, #T_ed7eb_row32_col6, #T_ed7eb_row53_col6, #T_ed7eb_row66_col6, #T_ed7eb_row76_col6, #T_ed7eb_row85_col6, #T_ed7eb_row91_col6 {
#   background-color: #a7db8c;
#   color: #000000;
# }
# #T_ed7eb_row25_col6, #T_ed7eb_row50_col6 {
#   background-color: #026a38;
#   color: #f1f1f1;
# }
# #T_ed7eb_row27_col5, #T_ed7eb_row39_col5, #T_ed7eb_row47_col5, #T_ed7eb_row58_col5, #T_ed7eb_row99_col5 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_ed7eb_row27_col6, #T_ed7eb_row59_col6, #T_ed7eb_row69_col6, #T_ed7eb_row74_col6, #T_ed7eb_row98_col6 {
#   background-color: #3ba358;
#   color: #f1f1f1;
# }
# #T_ed7eb_row33_col6 {
#   background-color: #f7fcbc;
#   color: #000000;
# }
# #T_ed7eb_row34_col6, #T_ed7eb_row45_col6, #T_ed7eb_row70_col6 {
#   background-color: #83cb7d;
#   color: #000000;
# }
# #T_ed7eb_row36_col6, #T_ed7eb_row62_col6 {
#   background-color: #f9fdc5;
#   color: #000000;
# }
# #T_ed7eb_row47_col6, #T_ed7eb_row58_col6 {
#   background-color: #1a7d40;
#   color: #f1f1f1;
# }
# #T_ed7eb_row50_col5 {
#   background-color: #15793e;
#   color: #f1f1f1;
# }
# #T_ed7eb_row51_col6, #T_ed7eb_row65_col6 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_ed7eb_row52_col6 {
#   background-color: #b5e092;
#   color: #000000;
# }
# #T_ed7eb_row54_col5, #T_ed7eb_row54_col6 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_ed7eb_row56_col6 {
#   background-color: #56b568;
#   color: #f1f1f1;
# }
# #T_ed7eb_row64_col5 {
#   background-color: #2f934d;
#   color: #f1f1f1;
# }
# #T_ed7eb_row64_col6 {
#   background-color: #208242;
#   color: #f1f1f1;
# }
# #T_ed7eb_row73_col6 {
#   background-color: #7ec97b;
#   color: #000000;
# }
# #T_ed7eb_row79_col6 {
#   backgroun
#   Top-1 accuracy : 24.0%
#   Mean Hits@n%   : 30.21%

# %% [markdown]
# ## Method comparison table

# %%
display(method_comparison_df.style
    .set_caption('Method Comparison — Top-1 Accuracy & Mean Hits@n%')
    .set_table_styles([{'selector': 'caption', 'props': 'font-size: 12px; width: 600px; padding-bottom: 10px;'}])
    .background_gradient(subset=['Hits@n%', 'Top-1 Accuracy%'], cmap='YlGn')
    .format({'Hits@n%': '{:.2f}', 'Top-1 Accuracy%': '{:.1f}'})
    .highlight_max(subset=['Hits@n%', 'Top-1 Accuracy%'],
                   props='font-weight: bold; border: 2px solid green')
)
# Out:
# <style type="text/css">
# #T_e7917 caption {
#   font-size: 12px;
#   width: 600px;
#   padding-bottom: 10px;
# }
# #T_e7917_row0_col1, #T_e7917_row0_col2 {
#   background-color: #004529;
#   color: #f1f1f1;
#   font-weight: bold;
#   border: 2px solid green;
# }
# #T_e7917_row1_col1 {
#   background-color: #13773d;
#   color: #f1f1f1;
# }
# #T_e7917_row1_col2 {
#   background-color: #005830;
#   color: #f1f1f1;
# }
# #T_e7917_row2_col1 {
#   background-color: #5fba6c;
#   color: #f1f1f1;
# }
# #T_e7917_row2_col2 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_e7917_row3_col1, #T_e7917_row3_col2 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_e7917">
#   <caption>Method Comparison — Top-1 Accuracy & Mean Hits@n%</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7917_level0_col0" class="col_heading level0 col0" >Method</th>
#       <th id="T_e7917_level0_col1" class="col_heading level0 col1" >Hits@n%</th>
#       <th id="T_e7917_level0_col2" class="col_heading level0 col2" >Top-1 Accuracy%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7917_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7917_row0_col0" class="data row0 col0" >minilm</td>
#       <td id="T_e7917_row0_col1" class="data row0 col1" >35.90</td>
#       <td id="T_e7917_row0_col2" class="data row0 col2" >33.0</td>
#     </tr>
#     <tr>
#       <th id="T_e7917_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7917_row1_col0" class="data row1 col0" >tfidf</td>
#       <td id="T_e7917_row1_col1" class="data row1 col1" >33.41</td>
#       <td id="T_e7917_row1_col2" class="data row1 col2" >32.0</td>
#     </tr>
#     <tr>
#       <th id="T_e7917_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e7917_row2_col0" class="data row2 col0" >specter2</td>
#       <td id="T_e7917_row2_col1" class="data row2 col1" >30.21</td>
#       <td id="T_e7917_row2_col2" class="data row2 col2" >24.0</td>
#     </tr>
#     <tr>
#       <th id="T_e7917_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e7917_row3_col0" class="data row3 col0" >bm25</td>
#       <td id="T_e7917_row3_col1" class="data row3 col1" >23.09</td>
#       <td id="T_e7917_row3_col2" class="data row3 col2" >18.0</td>
#     </tr>
#   </tbody>
# </table>
